# %% [markdown]
# <a href="https://colab.research.google.com/github/zackives/upenn-cis-2450/blob/main/6_Module_3_Query_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture Module 3: Making Choices about Data Processing
#
# ## LinkedIn Social Analysis
#
# Our next module explores concepts in:
#
# * Algorithmic implications of design choices
# * Techniques for indexing, parallelism, and sequence
#
# It sets the stage for Module 3, which focuses on cloud/cluster-compute data processing.

# %%
# !wget -nc https://storage.googleapis.com/penn-cis5450/linkedin_anon.jsonl
# Out:
# --2024-09-17 14:46:32--  https://storage.googleapis.com/penn-cis5450/linkedin_anon.jsonl
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.207, 108.177.98.207, 74.125.197.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179851696 (172M) [application/octet-stream]
# Saving to: ‘linkedin_anon.jsonl’
#
# linkedin_anon.jsonl 100%[===================>] 171.52M   150MB/s    in 1.1s
#
# 2024-09-17 14:46:33 (150 MB/s) - ‘linkedin_anon.jsonl’ saved [179851696/179851696]

# %% [markdown]
# ## Access Patterns
#
# Let's create two data structures, an integer list and a dictionary (hash map).  Each will have the same data.

# %%
intlist = []
for i in range(0,5000000):
  intlist.append((i+1,'a value'))

intdict = {}
for i in range(0,5000000):
  intdict[i] = ((i+1,'a value'))

# %%
# %%time
count = 0
for i in range(0,len(intlist)):
  count += intlist[i][0]
# Out:
# CPU times: user 1.55 s, sys: 21.9 ms, total: 1.57 s
# Wall time: 3.23 s

# %%
# %%time
count = 0
for i in range(0,len(intdict)):
  count += intdict[i][0]
# Out:
# CPU times: user 1.62 s, sys: 15.8 ms, total: 1.64 s
# Wall time: 2.22 s

# %%
# %%time
# All 50,000+ records from linkedin
linked_in = open('linkedin_anon.jsonl')

copied_data = open('linkedin_anon_copy.jsonl','w', buffering=4)

count = 0
for repeat in range(0,10):
  linked_in.seek(0)
  for line in linked_in:
    count += 1
    copied_data.write(line)

print (f"Copied {count} records")
# Out:
# Copied 500000 records
# CPU times: user 2.58 s, sys: 4.55 s, total: 7.13 s
# Wall time: 15.4 s

# %%
# %%time
# All 50,000+ records from linkedin
linked_in = open('linkedin_anon.jsonl')

copied_data = open('linkedin_anon_copy.jsonl','w', buffering=4096)

count = 0
for repeat in range(0,10):
  linked_in.seek(0)
  for line in linked_in:
    count += 1
    copied_data.write(line)

print (f"Copied {count} records")
# Out:
# Copied 500000 records
# CPU times: user 2.34 s, sys: 3.77 s, total: 6.12 s
# Wall time: 10.5 s

# %% [markdown]
# # Big Data Takes a Long Time to Process
#
# Now that we've seen how to do fairly complex queries over data in relations, we'll "pop back" to our big data example, which is the LinkedIn dataset.  Recall that we had a segment of the LinkedIn input file in our previous examples earlier in this module.

# %%
# !pip3 install lxml
# !pip3 install duckdb
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (0.10.3)

# %%
import pandas as pd
import numpy as np

# JSON parsing
import json

# HTML parsing
from lxml import etree
import urllib

# DuckDB RDBMS
import duckdb

# Time conversions
import time

# %%
# %%time
# 50,000 records from linkedin
linked_in = open('linkedin_anon.jsonl')

people = []

for line in linked_in:
    person = json.loads(line)
    people.append(person)

people_df = pd.DataFrame(people)
people_df[people_df['industry'] == 'Medical Devices']
# Out:
# CPU times: user 4.65 s, sys: 716 ms, total: 5.36 s
# Wall time: 12.3 s
#                           _id  \
# 0                 moist-vodka
# 161                   icy-bug
# 335          pleasant-capital
# 364             sour-database
# 467        rectilinear-canyon
# ...                       ...
# 49045        congruent-enamel
# 49180              kind-locus
# 49450             lower-prior
# 49683  deterministic-ligature
# 49994            tense-spline
#
#                                                     name  \
# 0      {'family_name': 'Post', 'given_name': 'Belvede...
# 161    {'family_name': 'Boyle', 'given_name': 'Simoni...
# 335    {'family_name': 'Fleming', 'given_name': 'Alfr...
# 364    {'family_name': 'Donald', 'given_name': 'Belve...
# 467      {'family_name': 'Lyon', 'given_name': 'Alfred'}
# ...                                                  ...
# 49045  {'family_name': 'Murdoch', 'given_name': 'Cadb...
# 49180  {'family_name': 'Douglas', 'given_name': 'Bert...
# 49450  {'family_name': 'Carmichael', 'given_name': 'J...
# 49683  {'family_name': 'Murray', 'given_name': 'Figaro'}
# 49994  {'family_name': 'Cunningham', 'given_name': 'M...
#
#                                  locality  \
# 0                           United States
# 161                                 China
# 335                Greater Nashville Area
# 364              Rochester, New York Area
# 467        Orange County, California Area
# ...                                   ...
# 49045                Greater Atlanta Area
# 49180              Dallas/Fort Worth Area
# 49450          Greater New York City Area
# 49683                Greater Chicago Area
# 49994  Tampa/St. Petersburg, Florida Area
#
#                                                   skills         industry  \
# 0      [Key Account Development, Strategic Planning, ...  Medical Devices
# 161                         [ISO 13485, Medical Devices]  Medical Devices
# 335                                                 None  Medical Devices
# 364    [Process Validation, Quality Systems, ISO 1348...  Medical Devices
# 467    [Licensing, New Business Development, Relation...  Medical Devices
# ...                                                  ...              ...
# 49045                [Managed Care, Sales Effectiveness]  Medical Devices
# 49180  [Personnel Management, Accounting, Employee Re...  Medical Devices
# 49450                                               None  Medical Devices
# 49683  [Process Development, Manufacturing, Product D...  Medical Devices
# 49994                                               None  Medical Devices
#
#                                                  summary  \
# 0      SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 161                                                 None
# 335    Whether achieving new highs in medical sales, ...
# 364    Change agent and proactive leader that drives ...
# 467    Contact –email: johnstroh@verizon.netmobile: 7...
# ...                                                  ...
# 49045  15 years of proven success in sales, sales tra...
# 49180                                               None
# 49450  Currently, Director of Human Resources at Life...
# 49683  I am a diverse, versatile, and quick to learn ...
# 49994  Strategic Healthcare Leader with proven experi...
#
#                                                      url  \
# 0                https://www.linkedin.com/in/moist-vodka
# 161                  https://www.linkedin.com/in/icy-bug
# 335         https://www.linkedin.com/in/pleasant-capital
# 364            https://www.linkedin.com/in/sour-database
# 467       https://www.linkedin.com/in/rectilinear-canyon
# ...                                                  ...
# 49045       https://www.linkedin.com/in/congruent-enamel
# 49180             https://www.linkedin.com/in/kind-locus
# 49450            https://www.linkedin.com/in/lower-prior
# 49683  https://www.linkedin.com/in/deterministic-liga...
# 49994           https://www.linkedin.com/in/tense-spline
#
#                                                education  \
# 0                                                   None
# 161    [{'start': '1998', 'end': '2001', 'name': 'Ton...
# 335    [{'start': '1992', 'major': 'Criminal Justice,...
# 364    [{'start': '2012', 'end': '2012', 'name': 'Smi...
# 467    [{'start': '1978', 'major': 'Graduate Business...
# ...                                                  ...
# 49045  [{'start': '1995', 'major': 'Biology, Chemistr...
# 49180  [{'major': 'Healthcare Management', 'end': '20...
# 49450  [{'start': '2009', 'end': '2009', 'name': 'Pen...
# 49683  [{'start': '2009', 'end': '2013', 'name': 'Ind...
# 49994    [{'name': 'University of Florida', 'desc': ''}]
#
#                                                    group  interval  \
# 0                                                   None       NaN
# 161    {'affilition': ['Beckman Coulter', 'Biomedical...       0.0
# 335    {'member': 'National Football League Players A...      32.0
# 364    {'member': 'ISPE, ASQ, PDA', 'affilition': ['A...      45.0
# 467    {'member': 'Council Member
# OCTANe Biomedical L...      25.0
# ...                                                  ...       ...
# 49045  {'affilition': ['Abbott Alumni', 'Abbott Labor...      36.0
# 49180                                               None      26.0
# 49450  {'member': 'SHRM, World at Work', 'affilition'...      24.0
# 49683                                               None      17.0
# 49994  {'affilition': ['Democratic GAIN', 'Medical De...      12.0
#
#                                               experience  \
# 0                                                   None
# 161    [{'org': 'Beckman Coulter Laboratory Systems S...
# 335    [{'org': 'Intuitive Surgical', 'title': 'Clini...
# 364    [{'org': 'Ortho Clinical Diagnostics', 'title'...
# 467    [{'org': 'Nanospectra Biosciences', 'desc': 'A...
# ...                                                  ...
# 49045  [{'org': 'Anesthesia Healthcare Partners® (AHP...
# 49180  [{'org': 'St. Jude Medical', 'title': 'Sr. Man...
# 49450  [{'org': 'LifeCell Corporation', 'title': 'Dir...
# 49683  [{'org': 'Covidien', 'end': 'Present', 'start'...
# 49994  [{'org': 'Skeletal Kinetics', 'end': 'Present'...
#
#                                              specilities  \
# 0                                                   None
# 161                                                 None
# 335    Customer Service, Sales Growth, Direct Sales, ...
# 364                                                 None
# 467                                                 None
# ...                                                  ...
# 49045  Situational Leadership. Strong Customer-Needs-...
# 49180                                               None
# 49450                                               None
# 49683                                               None
# 49994  Competitive analysis, Concept marketing, Physi...
#
#                                                   events  \
# 0                                                   None
# 161    [{'from': 'Beckman Coulter', 'to': 'Beckman Co...
# 335    [{'from': 'National Football League', 'to': 'C...
# 364    [{'from': 'Steris', 'to': 'Calgon Vestal', 'ti...
# 467    [{'from': 'AREAS OF INTEREST & EXPERTISE', 'to...
# ...                                                  ...
# 49045  [{'from': 'Abbott Laboratories', 'to': 'Sanofi...
# 49180  [{'from': 'Gables Residential', 'to': 'Matrix ...
# 49450  [{'from': 'Johnson & Johnson Corporate', 'to':...
# 49683  [{'from': 'Global Powertrain Congress', 'to': ...
# 49994  [{'from': 'NuVasive', 'to': 'Skeletal Kinetics...
#
#                                                interests  \
# 0                                                   None
# 161                                                 None
# 335                                                 None
# 364                                                 None
# 467    John Stroh – President, CEO, COO, CFO, Directo...
# ...                                                  ...
# 49045                                               None
# 49180                                               None
# 49450             golf, skiing, traveling with my family
# 49683                                               None
# 49994                                               None
#
#                                                   honors
# 0                                                   None
# 161                                                 None
# 335    [MERCK & CO., INC:, • Award of Excellence-2009...
# 364                          [CQA, CQM, Sr. Member, ASQ]
# 467    [Judge of the Business Plan Competition at the...
# ...                                                  ...
# 49045                                               None
# 49180                                               None
# 49450  [J&J Standard of Leadership Award 2007, 2004, ...
# 49683                                               None
# 49994                                               None
#
# [237 rows x 15 columns]

# %%
# %%time
# 500,000 records from linkedin
linked_in = open('linkedin_anon.jsonl')

people = []

for line in linked_in:
    person = json.loads(line)
    if 'industry' in person and person['industry'] == 'Medical Devices':
        people.append(person)

people_df = pd.DataFrame(people)
people_df
# Out:
# CPU times: user 2.66 s, sys: 73.4 ms, total: 2.73 s
# Wall time: 5.31 s
#                         _id  \
# 0               moist-vodka
# 1                   icy-bug
# 2          pleasant-capital
# 3             sour-database
# 4        rectilinear-canyon
# ..                      ...
# 232        congruent-enamel
# 233              kind-locus
# 234             lower-prior
# 235  deterministic-ligature
# 236            tense-spline
#
#                                                   name  \
# 0    {'family_name': 'Post', 'given_name': 'Belvede...
# 1    {'family_name': 'Boyle', 'given_name': 'Simoni...
# 2    {'family_name': 'Fleming', 'given_name': 'Alfr...
# 3    {'family_name': 'Donald', 'given_name': 'Belve...
# 4      {'family_name': 'Lyon', 'given_name': 'Alfred'}
# ..                                                 ...
# 232  {'family_name': 'Murdoch', 'given_name': 'Cadb...
# 233  {'family_name': 'Douglas', 'given_name': 'Bert...
# 234  {'family_name': 'Carmichael', 'given_name': 'J...
# 235  {'family_name': 'Murray', 'given_name': 'Figaro'}
# 236  {'family_name': 'Cunningham', 'given_name': 'M...
#
#                                locality  \
# 0                         United States
# 1                                 China
# 2                Greater Nashville Area
# 3              Rochester, New York Area
# 4        Orange County, California Area
# ..                                  ...
# 232                Greater Atlanta Area
# 233              Dallas/Fort Worth Area
# 234          Greater New York City Area
# 235                Greater Chicago Area
# 236  Tampa/St. Petersburg, Florida Area
#
#                                                 skills         industry  \
# 0    [Key Account Development, Strategic Planning, ...  Medical Devices
# 1                         [ISO 13485, Medical Devices]  Medical Devices
# 2                                                 None  Medical Devices
# 3    [Process Validation, Quality Systems, ISO 1348...  Medical Devices
# 4    [Licensing, New Business Development, Relation...  Medical Devices
# ..                                                 ...              ...
# 232                [Managed Care, Sales Effectiveness]  Medical Devices
# 233  [Personnel Management, Accounting, Employee Re...  Medical Devices
# 234                                               None  Medical Devices
# 235  [Process Development, Manufacturing, Product D...  Medical Devices
# 236                                               None  Medical Devices
#
#                                                summary  \
# 0    SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 1                                                 None
# 2    Whether achieving new highs in medical sales, ...
# 3    Change agent and proactive leader that drives ...
# 4    Contact –email: johnstroh@verizon.netmobile: 7...
# ..                                                 ...
# 232  15 years of proven success in sales, sales tra...
# 233                                               None
# 234  Currently, Director of Human Resources at Life...
# 235  I am a diverse, versatile, and quick to learn ...
# 236  Strategic Healthcare Leader with proven experi...
#
#                                                    url  \
# 0              https://www.linkedin.com/in/moist-vodka
# 1                  https://www.linkedin.com/in/icy-bug
# 2         https://www.linkedin.com/in/pleasant-capital
# 3            https://www.linkedin.com/in/sour-database
# 4       https://www.linkedin.com/in/rectilinear-canyon
# ..                                                 ...
# 232       https://www.linkedin.com/in/congruent-enamel
# 233             https://www.linkedin.com/in/kind-locus
# 234            https://www.linkedin.com/in/lower-prior
# 235  https://www.linkedin.com/in/deterministic-liga...
# 236           https://www.linkedin.com/in/tense-spline
#
#                                              education  \
# 0                                                 None
# 1    [{'start': '1998', 'end': '2001', 'name': 'Ton...
# 2    [{'start': '1992', 'major': 'Criminal Justice,...
# 3    [{'start': '2012', 'end': '2012', 'name': 'Smi...
# 4    [{'start': '1978', 'major': 'Graduate Business...
# ..                                                 ...
# 232  [{'start': '1995', 'major': 'Biology, Chemistr...
# 233  [{'major': 'Healthcare Management', 'end': '20...
# 234  [{'start': '2009', 'end': '2009', 'name': 'Pen...
# 235  [{'start': '2009', 'end': '2013', 'name': 'Ind...
# 236    [{'name': 'University of Florida', 'desc': ''}]
#
#                                                  group  interval  \
# 0                                                 None       NaN
# 1    {'affilition': ['Beckman Coulter', 'Biomedical...       0.0
# 2    {'member': 'National Football League Players A...      32.0
# 3    {'member': 'ISPE, ASQ, PDA', 'affilition': ['A...      45.0
# 4    {'member': 'Council Member
# OCTANe Biomedical L...      25.0
# ..                                                 ...       ...
# 232  {'affilition': ['Abbott Alumni', 'Abbott Labor...      36.0
# 233                                               None      26.0
# 234  {'member': 'SHRM, World at Work', 'affilition'...      24.0
# 235                                               None      17.0
# 236  {'affilition': ['Democratic GAIN', 'Medical De...      12.0
#
#                                             experience  \
# 0                                                 None
# 1    [{'org': 'Beckman Coulter Laboratory Systems S...
# 2    [{'org': 'Intuitive Surgical', 'title': 'Clini...
# 3    [{'org': 'Ortho Clinical Diagnostics', 'title'...
# 4    [{'org': 'Nanospectra Biosciences', 'desc': 'A...
# ..                                                 ...
# 232  [{'org': 'Anesthesia Healthcare Partners® (AHP...
# 233  [{'org': 'St. Jude Medical', 'title': 'Sr. Man...
# 234  [{'org': 'LifeCell Corporation', 'title': 'Dir...
# 235  [{'org': 'Covidien', 'end': 'Present', 'start'...
# 236  [{'org': 'Skeletal Kinetics', 'end': 'Present'...
#
#                                            specilities  \
# 0                                                 None
# 1                                                 None
# 2    Customer Service, Sales Growth, Direct Sales, ...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 232  Situational Leadership. Strong Customer-Needs-...
# 233                                               None
# 234                                               None
# 235                                               None
# 236  Competitive analysis, Concept marketing, Physi...
#
#                                                 events  \
# 0                                                 None
# 1    [{'from': 'Beckman Coulter', 'to': 'Beckman Co...
# 2    [{'from': 'National Football League', 'to': 'C...
# 3    [{'from': 'Steris', 'to': 'Calgon Vestal', 'ti...
# 4    [{'from': 'AREAS OF INTEREST & EXPERTISE', 'to...
# ..                                                 ...
# 232  [{'from': 'Abbott Laboratories', 'to': 'Sanofi...
# 233  [{'from': 'Gables Residential', 'to': 'Matrix ...
# 234  [{'from': 'Johnson & Johnson Corporate', 'to':...
# 235  [{'from': 'Global Powertrain Congress', 'to': ...
# 236  [{'from': 'NuVasive', 'to': 'Skeletal Kinetics...
#
#                                              interests  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4    John Stroh – President, CEO, COO, CFO, Directo...
# ..                                                 ...
# 232                                               None
# 233                                               None
# 234             golf, skiing, traveling with my family
# 235                                               None
# 236                                               None
#
#                                                 honors
# 0                                                 None
# 1                                                 None
# 2    [MERCK & CO., INC:, • Award of Excellence-2009...
# 3                          [CQA, CQM, Sr. Member, ASQ]
# 4    [Judge of the Business Plan Competition at the...
# ..                                                 ...
# 232                                               None
# 233                                               None
# 234  [J&J Standard of Leadership Award 2007, 2004, ...
# 235                                               None
# 236                                               None
#
# [237 rows x 15 columns]

# %% [markdown]
# ## SQL query without an index
#
# SQL databases will automatically "push down" selection and projection where feasible.  They also don't need to parse.
#
# Let's load people_df into tables as per our prior notebook.

# %%
'''
Simple code to pull out data from JSON and load into DuckDB.
'''
import ast

linked_in = open('linkedin_anon.jsonl')

START = 0
LIMIT = 50000

def get_df(rel):
    ret = pd.DataFrame(rel)
    return ret

lines = []
i = 1
for line in linked_in:
    if i > START + LIMIT:
        break
    elif i >= START:
        person = json.loads(line)

        lines.append(person)
    i = i + 1

people_df = get_df(pd.DataFrame(lines))

# %%
people_df
# Out:
#                         _id  \
# 0               moist-vodka
# 1           adagio-catalyst
# 2                tart-acorn
# 3        objective-riesling
# 4      generative-amberjack
# ...                     ...
# 49995         glowing-flush
# 49996        grouchy-flight
# 49997            dense-bell
# 49998           brave-hoops
# 49999       fixed-partition
#
#                                                     name  \
# 0      {'family_name': 'Post', 'given_name': 'Belvede...
# 1       {'family_name': 'Watt', 'given_name': 'Brunton'}
# 2      {'family_name': 'Hannay', 'given_name': 'Passe...
# 3      {'family_name': 'Carnegie', 'given_name': 'Pas...
# 4      {'family_name': 'Duncan', 'given_name': 'Merri...
# ...                                                  ...
# 49995  {'family_name': 'Kincaid', 'given_name': 'Pass...
# 49996  {'family_name': 'Ogilvy', 'given_name': 'Bulli...
# 49997  {'family_name': 'Macdougall', 'given_name': 'B...
# 49998  {'family_name': 'Forsyth', 'given_name': 'Cadb...
# 49999  {'family_name': 'Donald', 'given_name': 'Alfred'}
#
#                          locality  \
# 0                   United States
# 1           Antwerp Area, Belgium
# 2       San Francisco, California
# 3          San Francisco Bay Area
# 4             Chennai Area, India
# ...                           ...
# 49995        Greater Chicago Area
# 49996        Greater Atlanta Area
# 49997        Calgary, Canada Area
# 49998      San Francisco Bay Area
# 49999  Greater New York City Area
#
#                                                   skills  \
# 0      [Key Account Development, Strategic Planning, ...
# 1                        [Molecular Biology, Biomarkers]
# 2      [DNA, Nanotechnology, Molecular Biology, Softw...
# 3                                                   None
# 4      [Program Management, French, Avionics, Embedde...
# ...                                                  ...
# 49995  [Spanish-speaking, Cicerone-Certified Beer Ser...
# 49996                                               None
# 49997  [Project Management, Electrical Engineering, M...
# 49998  [Corporate Social Responsibility, Public Polic...
# 49999                                               None
#
#                                   industry  \
# 0                          Medical Devices
# 1                          Pharmaceuticals
# 2                                 Research
# 3      Information Technology and Services
# 4                     Aviation & Aerospace
# ...                                    ...
# 49995            Marketing and Advertising
# 49996                   Financial Services
# 49997                               Design
# 49998                        Public Policy
# 49999  Public Relations and Communications
#
#                                                  summary  \
# 0      SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 1      Ph.D. scientist with background in cancer rese...
# 2      I am interested in inventing new methods to co...
# 3      OBJECTIVE<Primary> Work on an interesting and ...
# 4      Experience in Avionics Systems, Embedded Syste...
# ...                                                  ...
# 49995  Sales and marketing professional specializing ...
# 49996  Accomplished business development manager expe...
# 49997  Brad Gibson is a recognized expert in power qu...
# 49998  Brad Kane's multi-faceted career in the govern...
# 49999  Client Experience:CONSUMER TECH: foursquare, O...
#
#                                                     url  \
# 0               https://www.linkedin.com/in/moist-vodka
# 1           https://www.linkedin.com/in/adagio-catalyst
# 2                https://www.linkedin.com/in/tart-acorn
# 3        https://www.linkedin.com/in/objective-riesling
# 4      https://www.linkedin.com/in/generative-amberjack
# ...                                                 ...
# 49995         https://www.linkedin.com/in/glowing-flush
# 49996        https://www.linkedin.com/in/grouchy-flight
# 49997            https://www.linkedin.com/in/dense-bell
# 49998           https://www.linkedin.com/in/brave-hoops
# 49999       https://www.linkedin.com/in/fixed-partition
#
#                                                education  \
# 0                                                   None
# 1      [{'start': '2008', 'major': 'Economics', 'end'...
# 2      [{'major': 'Biophysics', 'end': '2009', 'name'...
# 3                                                   None
# 4      [{'start': '1988', 'end': '1989', 'name': 'Eco...
# ...                                                  ...
# 49995  [{'start': '2007', 'major': 'PR and Advertisin...
# 49996  [{'major': 'Marketing Focus', 'end': '2008', '...
# 49997  [{'major': 'Engineering Physics (Solid State E...
# 49998  [{'major': 'Law', 'end': '1984', 'name': 'Univ...
# 49999  [{'start': '1993', 'end': '1997', 'name': 'Uni...
#
#                                                    group  interval  \
# 0                                                   None       NaN
# 1      {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 2                                                   None       0.0
# 3      {'affilition': ['Big Data, Low Latency', 'Expe...       5.0
# 4      {'member': 'Member of Project Management Insti...       NaN
# ...                                                  ...       ...
# 49995                                               None       5.0
# 49996  {'member': 'Sigma Chi Fraternity', 'affilition...      14.0
# 49997  {'member': 'IEEE, APEGGA, APEGBC, PEO, APEGS, ...      42.0
# 49998  {'affilition': ['Association for Public Policy...      26.0
# 49999  {'affilition': ['PRSA Travel & Tourism Section...      16.0
#
#                                               experience  \
# 0                                                   None
# 1      [{'org': 'Johnson and Johnson', 'title': 'Seni...
# 2      [{'org': 'UCSF', 'title': 'Assistant Professor...
# 3      [{'org': '<Online Recruiting Company>', 'desc'...
# 4                                                   None
# ...                                                  ...
# 49995  [{'org': 'Louis Glunz Beer Inc.', 'title': 'On...
# 49996  [{'org': 'Georgia-Pacific LLC', 'title': 'Acco...
# 49997  [{'org': 'DIALOG', 'desc': 'Electrical Enginee...
# 49998  [{'org': 'The Bipartisan Bridge', 'title': 'Ex...
# 49999  [{'org': 'M Booth & Associates', 'desc': 'Dire...
#
#                                              specilities  \
# 0                                                   None
# 1      Biomarkers in Oncology, Cancer Genomics, Molec...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 49995                                               None
# 49996                                               None
# 49997  Data center design, high reliability power, po...
# 49998  Brad has led initiatives, public policy, and p...
# 49999  Development of strategic, awareness-generating...
#
#                                                   events  \
# 0                                                   None
# 1      [{'from': 'Sahlgrenska University Hospital', '...
# 2      [{'from': 'Wyss Institute for Biologically Ins...
# 3      [{'from': '<Employee Benefits, Administration ...
# 4                                                   None
# ...                                                  ...
# 49995  [{'from': 'Peet's Coffee and Tea', 'to': 'Expl...
# 49996  [{'from': 'Bayer Advanced', 'to': 'BBDO', 'tit...
# 49997  [{'from': 'Current Thinking Inc.', 'to': 'The ...
# 49998  [{'from': 'Congresswoman Cardiss Collins', 'to...
# 49999  [{'from': 'Four Seasons Hotels and Resorts', '...
#
#                                                interests  \
# 0                                                   None
# 1                                                   None
# 2                      personal genomics, nanotechnology
# 3                                                   None
# 4                          Literature, Philosophy, Music
# ...                                                  ...
# 49995  craft beer industry, coffee industry, running,...
# 49996                                               None
# 49997                                               None
# 49998                                               None
# 49999                                               None
#
#                                                  honors
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 49995                                              None
# 49996                             [National Deans List]
# 49997                                              None
# 49998                                              None
# 49999  [Named to the "15 to Watch Hot List" by PR News]
#
# [50000 rows x 15 columns]

# %%
def get_nested_dict(rel, name):
  # This evaluates the string that describes the dictionary, as a dictionary
  # definition
  ret = rel.copy()
  # ret[name] = rel[name].map(lambda x: ast.literal_eval(x) if len(x) else np.NaN)
  ret = ret.dropna()
  # This joins rows on the index
  return ret.drop(columns=name).join(pd.DataFrame(ret[name].tolist()))

def get_nested_list(rel, name):
  ret = rel.copy()
  ret = ret.dropna().explode(name).dropna()
  ret = ret.join(pd.DataFrame(ret[name].tolist())).drop(columns=name).drop_duplicates()
  return ret.rename(columns={0: name})

def get_nested_list_dict(rel, name):
  ret = rel.copy()

  ret = ret.dropna().explode(name)

  exploded_pairs = pd.DataFrame(ret.apply(lambda x: {'_id': x['_id']} | x[name] if isinstance(x[name], dict) else {'_id': x['_id']}, axis=1).tolist())

  return ret.merge(exploded_pairs, on='_id').drop(columns=name)
  #pd.DataFrame(ret[name].tolist())).drop(columns=name).drop_duplicates()

# Take the lists, drop any blank strings
specialties_df = people_df[['_id','specilities']].explode('specilities').rename(columns={'_id': 'person'})
specialties_df.dropna(inplace=True)
interests_df = people_df[['_id','interests']].explode('interests').rename(columns={'_id': 'person'})
interests_df.dropna(inplace=True)

names_df = get_nested_dict(people_df[['_id','name']], 'name')

education_df = get_nested_list_dict(people_df[['_id','education']], 'education')
experience_df = get_nested_list_dict(people_df[['_id','experience']], 'experience')
skills_df = get_nested_list(people_df[['_id','skills']], 'skills')
honors_df = get_nested_list(people_df[['_id','honors']], 'honors')
events_df = get_nested_list_dict(people_df[['_id','events']], 'events')

groups_df = get_nested_dict(people_df[['_id','group']], 'group')

people_only_df = people_df.drop(columns=['name','education','group','skills','experience','honors','events','specilities','interests'])

# %%
## This is just to reset things so we don't have an index
conn = duckdb.connect('linkedin.db')
conn.execute('BEGIN TRANSACTION')
conn.execute('DROP TABLE IF EXISTS people')
conn.execute('DROP INDEX IF EXISTS people_industry')
conn.execute('CREATE TABLE people AS SELECT * FROM people_df')
conn.execute('CREATE TABLE education AS SELECT * FROM education_df')
conn.execute('CREATE TABLE experience AS SELECT * FROM experience_df')
conn.execute('CREATE TABLE skills AS SELECT * FROM skills_df')
conn.execute('CREATE TABLE honors AS SELECT * FROM honors_df')
conn.execute('CREATE TABLE events AS SELECT * FROM events_df')
conn.execute('CREATE TABLE groups AS SELECT * FROM groups_df')
conn.execute('CREATE TABLE specialties AS SELECT * FROM specialties_df')
conn.execute('CREATE TABLE interests AS SELECT * FROM interests_df')
conn.execute('COMMIT')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
# %%time

conn.sql("""
  SELECT *
  FROM people JOIN experience ON people._id = experience._id
  WHERE industry='Medical Devices'""")
# Out:
# CPU times: user 1.45 ms, sys: 0 ns, total: 1.45 ms
# Wall time: 9.73 ms
# ┌────────────────┬──────────────────────┬──────────────────────┬───┬─────────┬────────────────┬──────────────────────┐
# │      _id       │         name         │       locality       │ … │   end   │     start      │         desc         │
# │    varchar     │ struct(family_name…  │       varchar        │   │ varchar │    varchar     │       varchar        │
# ├────────────────┼──────────────────────┼──────────────────────┼───┼─────────┼────────────────┼──────────────────────┤
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ Present │ January 2012   │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ November 2009  │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ June 2007      │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ Present │ January 2012   │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ November 2009  │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ June 2007      │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ Present │ January 2012   │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ November 2009  │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ June 2007      │ NULL                 │
# │ fresh-linkage  │ {'family_name': Mo…  │ Greater Chicago Area │ … │ Present │ June 2005      │ NULL                 │
# │      ·         │          ·           │          ·           │ · │  ·      │     ·          │  ·                   │
# │      ·         │          ·           │          ·           │ · │  ·      │     ·          │  ·                   │
# │      ·         │          ·           │          ·           │ · │  ·      │     ·          │  ·                   │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ November 2001  │ Responsible for Co…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ 1989           │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ Present │ January 2012   │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ October 2009   │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ February 2007  │ HR Business Partne…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ 2007           │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ 2005           │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ July 2006      │ Served as internal…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ October 2005   │ Responsible for Co…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ September 2005 │ Responsible for Co…  │
# ├────────────────┴──────────────────────┴──────────────────────┴───┴─────────┴────────────────┴──────────────────────┤
# │ 7860 rows (20 shown)                                                                          21 columns (6 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Let's build an index now...
#
# Our data is very small, so the index probably won't speed anything up at this scale. But it can be created and the database will use it *transparently*!

# %%
conn.execute('BEGIN TRANSACTION')
conn.execute('DROP INDEX IF EXISTS people_industry')
conn.execute("CREATE INDEX people_industry ON people(industry)")
conn.execute('COMMIT')

# %%
# %%time
# Treat the view as a table, see what's there
conn.sql("""
 CREATE VIEW people_medicine AS
  SELECT *
  FROM people JOIN experience ON people._id = experience._id
  WHERE industry='Medical Devices'""")

conn.sql("""
  SELECT *
  FROM people_medicine""")

# In our tests, this was 5x faster!
# Out:
# CPU times: user 2.41 ms, sys: 903 µs, total: 3.32 ms
# Wall time: 8.38 ms
# ┌────────────────┬──────────────────────┬──────────────────────┬───┬─────────┬────────────────┬──────────────────────┐
# │      _id       │         name         │       locality       │ … │   end   │     start      │         desc         │
# │    varchar     │ struct(family_name…  │       varchar        │   │ varchar │    varchar     │       varchar        │
# ├────────────────┼──────────────────────┼──────────────────────┼───┼─────────┼────────────────┼──────────────────────┤
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ Present │ January 2012   │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ November 2009  │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ June 2007      │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ Present │ January 2012   │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ November 2009  │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ June 2007      │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ Present │ January 2012   │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ November 2009  │ NULL                 │
# │ boxy-seasoning │ {'family_name': Dr…  │ Greater San Diego …  │ … │ NULL    │ June 2007      │ NULL                 │
# │ fresh-linkage  │ {'family_name': Mo…  │ Greater Chicago Area │ … │ Present │ June 2005      │ NULL                 │
# │      ·         │          ·           │          ·           │ · │  ·      │     ·          │  ·                   │
# │      ·         │          ·           │          ·           │ · │  ·      │     ·          │  ·                   │
# │      ·         │          ·           │          ·           │ · │  ·      │     ·          │  ·                   │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ November 2001  │ Responsible for Co…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ 1989           │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ Present │ January 2012   │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ October 2009   │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ February 2007  │ HR Business Partne…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ 2007           │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ 2005           │ NULL                 │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ July 2006      │ Served as internal…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ October 2005   │ Responsible for Co…  │
# │ lower-prior    │ {'family_name': Ca…  │ Greater New York C…  │ … │ NULL    │ September 2005 │ Responsible for Co…  │
# ├────────────────┴──────────────────────┴──────────────────────┴───┴─────────┴────────────────┴──────────────────────┤
# │ 7860 rows (20 shown)                                                                          21 columns (6 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# %%time

conn.sql("""
  SELECT name.given_name, name.family_name
  FROM people
  WHERE name.given_name='Jeeves'""")
# Out:
# CPU times: user 861 µs, sys: 0 ns, total: 861 µs
# Wall time: 870 µs
# ┌────────────┬─────────────┐
# │ given_name │ family_name │
# │  varchar   │   varchar   │
# ├────────────┼─────────────┤
# │ Jeeves     │ Boyle       │
# │ Jeeves     │ Maclean     │
# │ Jeeves     │ Riddell     │
# │ Jeeves     │ Blair       │
# │ Jeeves     │ Macduff     │
# │ Jeeves     │ Riddell     │
# │ Jeeves     │ Rollo       │
# │ Jeeves     │ Davidson    │
# │ Jeeves     │ Kennedy     │
# │ Jeeves     │ Lough       │
# │   ·        │   ·         │
# │   ·        │   ·         │
# │   ·        │   ·         │
# │ Jeeves     │ Donald      │
# │ Jeeves     │ Fleet       │
# │ Jeeves     │ Jardine     │
# │ Jeeves     │ Sinclair    │
# │ Jeeves     │ Fergusson   │
# │ Jeeves     │ Burnett     │
# │ Jeeves     │ Buchanan    │
# │ Jeeves     │ Fleet       │
# │ Jeeves     │ Riddell     │
# │ Jeeves     │ Lough       │
# ├────────────┴─────────────┤
# │   3133 rows (20 shown)   │
# └──────────────────────────┘

# %%
people_df2 = conn.sql('select * from people limit 500').df()
experience_df2 = conn.sql('select * from experience limit 5000').df()
skills_df2 = conn.sql('select * from skills limit 8000').df()

print ("%d people"%len(people_df2))
print ("%d experiences"%len(experience_df2))
print ("%d skills"%len(skills_df2))
# Out:
# 500 people
# 5000 experiences
# 8000 skills

# %%
def merge(S,T,l_on,r_on):
    ret = []
    count = 0
    s_pos = S.columns.get_loc(l_on)
    t_pos = T.columns.get_loc(r_on)
    for s_index in range(0, len(S)):
        for t_index in range(0, len(T)):
            count = count + 1
            if S.iat[s_index, s_pos] == T.iat[t_index, t_pos]:
              ret.append(S.iloc[s_index].to_dict() | T.iloc[t_index].to_dict())

    print('Merge compared %d tuples'%count)
    return pd.DataFrame(ret)

# %%
# %%time
# Here's a test join, with people and their experiences.  We can see how many
# comparisons are made

merge(people_df2, experience_df2, '_id', '_id')
# Out:
# Merge compared 2500000 tuples
# CPU times: user 1min 58s, sys: 368 ms, total: 1min 58s
# Wall time: 2min 1s
#                   _id                                               name  \
# 0     adagio-catalyst   {'family_name': 'Watt', 'given_name': 'Brunton'}
# 1     adagio-catalyst   {'family_name': 'Watt', 'given_name': 'Brunton'}
# 2     adagio-catalyst   {'family_name': 'Watt', 'given_name': 'Brunton'}
# 3     adagio-catalyst   {'family_name': 'Watt', 'given_name': 'Brunton'}
# 4     adagio-catalyst   {'family_name': 'Watt', 'given_name': 'Brunton'}
# ...               ...                                                ...
# 4995    gentle-sensor  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4996    gentle-sensor  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4997    gentle-sensor  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4998    gentle-sensor  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4999    gentle-sensor  {'family_name': 'Bruce', 'given_name': 'Barrym...
#
#                    locality  \
# 0     Antwerp Area, Belgium
# 1     Antwerp Area, Belgium
# 2     Antwerp Area, Belgium
# 3     Antwerp Area, Belgium
# 4     Antwerp Area, Belgium
# ...                     ...
# 4995     Austin, Texas Area
# 4996     Austin, Texas Area
# 4997     Austin, Texas Area
# 4998     Austin, Texas Area
# 4999     Austin, Texas Area
#
#                                                  skills  \
# 0                       [Molecular Biology, Biomarkers]
# 1                       [Molecular Biology, Biomarkers]
# 2                       [Molecular Biology, Biomarkers]
# 3                       [Molecular Biology, Biomarkers]
# 4                       [Molecular Biology, Biomarkers]
# ...                                                 ...
# 4995  [IT Management, Disaster Recovery, System Admi...
# 4996  [IT Management, Disaster Recovery, System Admi...
# 4997  [IT Management, Disaster Recovery, System Admi...
# 4998  [IT Management, Disaster Recovery, System Admi...
# 4999  [IT Management, Disaster Recovery, System Admi...
#
#                                  industry  \
# 0                         Pharmaceuticals
# 1                         Pharmaceuticals
# 2                         Pharmaceuticals
# 3                         Pharmaceuticals
# 4                         Pharmaceuticals
# ...                                   ...
# 4995  Information Technology and Services
# 4996  Information Technology and Services
# 4997  Information Technology and Services
# 4998  Information Technology and Services
# 4999  Information Technology and Services
#
#                                                 summary  \
# 0     Ph.D. scientist with background in cancer rese...
# 1     Ph.D. scientist with background in cancer rese...
# 2     Ph.D. scientist with background in cancer rese...
# 3     Ph.D. scientist with background in cancer rese...
# 4     Ph.D. scientist with background in cancer rese...
# ...                                                 ...
# 4995  IT Services Manager and Implementation special...
# 4996  IT Services Manager and Implementation special...
# 4997  IT Services Manager and Implementation special...
# 4998  IT Services Manager and Implementation special...
# 4999  IT Services Manager and Implementation special...
#
#                                               url  \
# 0     https://www.linkedin.com/in/adagio-catalyst
# 1     https://www.linkedin.com/in/adagio-catalyst
# 2     https://www.linkedin.com/in/adagio-catalyst
# 3     https://www.linkedin.com/in/adagio-catalyst
# 4     https://www.linkedin.com/in/adagio-catalyst
# ...                                           ...
# 4995    https://www.linkedin.com/in/gentle-sensor
# 4996    https://www.linkedin.com/in/gentle-sensor
# 4997    https://www.linkedin.com/in/gentle-sensor
# 4998    https://www.linkedin.com/in/gentle-sensor
# 4999    https://www.linkedin.com/in/gentle-sensor
#
#                                               education  \
# 0     [{'key': ['start', 'major', 'end', 'name', 'de...
# 1     [{'key': ['start', 'major', 'end', 'name', 'de...
# 2     [{'key': ['start', 'major', 'end', 'name', 'de...
# 3     [{'key': ['start', 'major', 'end', 'name', 'de...
# 4     [{'key': ['start', 'major', 'end', 'name', 'de...
# ...                                                 ...
# 4995  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4996  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4997  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4998  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4999  [{'key': ['major', 'name', 'degree', 'desc'], ...
#
#                                                   group  interval  \
# 0     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 1     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 2     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 3     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 4     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# ...                                                 ...       ...
# 4995  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4996  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4997  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4998  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4999  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
#
#                                              experience  \
# 0     [{'key': ['org', 'title', 'end', 'start', 'des...
# 1     [{'key': ['org', 'title', 'end', 'start', 'des...
# 2     [{'key': ['org', 'title', 'end', 'start', 'des...
# 3     [{'key': ['org', 'title', 'end', 'start', 'des...
# 4     [{'key': ['org', 'title', 'end', 'start', 'des...
# ...                                                 ...
# 4995  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4996  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4997  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4998  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4999  [{'key': ['org', 'desc', 'end', 'start', 'titl...
#
#                                             specilities  \
# 0     Biomarkers in Oncology, Cancer Genomics, Molec...
# 1     Biomarkers in Oncology, Cancer Genomics, Molec...
# 2     Biomarkers in Oncology, Cancer Genomics, Molec...
# 3     Biomarkers in Oncology, Cancer Genomics, Molec...
# 4     Biomarkers in Oncology, Cancer Genomics, Molec...
# ...                                                 ...
# 4995  IT Management, disaster recovery, computer for...
# 4996  IT Management, disaster recovery, computer for...
# 4997  IT Management, disaster recovery, computer for...
# 4998  IT Management, disaster recovery, computer for...
# 4999  IT Management, disaster recovery, computer for...
#
#                                                  events  \
# 0     [{'from': 'Sahlgrenska University Hospital', '...
# 1     [{'from': 'Sahlgrenska University Hospital', '...
# 2     [{'from': 'Sahlgrenska University Hospital', '...
# 3     [{'from': 'Sahlgrenska University Hospital', '...
# 4     [{'from': 'Sahlgrenska University Hospital', '...
# ...                                                 ...
# 4995  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4996  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4997  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4998  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4999  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
#
#                                           interests  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 4995  Stock Market, Playing with the kiddos, Gaming
# 4996  Stock Market, Playing with the kiddos, Gaming
# 4997  Stock Market, Playing with the kiddos, Gaming
# 4998  Stock Market, Playing with the kiddos, Gaming
# 4999  Stock Market, Playing with the kiddos, Gaming
#
#                                                  honors  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4995  [Most Billable Person 2006 (On-Site Computer S...
# 4996  [Most Billable Person 2006 (On-Site Computer S...
# 4997  [Most Billable Person 2006 (On-Site Computer S...
# 4998  [Most Billable Person 2006 (On-Site Computer S...
# 4999  [Most Billable Person 2006 (On-Site Computer S...
#
#                                          org  \
# 0                        Johnson and Johnson
# 1             Albert Einstein Medical Center
# 2                        Columbia University
# 3     Memorial Sloan Kettering Cancer Center
# 4            Sahlgrenska University Hospital
# ...                                      ...
# 4995                           ANCGroup, INC
# 4996              On-Site Computer Solutions
# 4997                                 PC Guru
# 4998                                    Dell
# 4999                     Formulated IT Svcs.
#
#                                         title      end           start  \
# 0       Senior Scientist, Oncology Biomarkers  Present   November 2009
# 1     Associate at Dept of Molecular Genetics     None  September 2008
# 2                Associate Research Scientist     None     August 2006
# 3               Post Doctoral Research Fellow     None    January 2003
# 4                          Research Scientist     None   November 2001
# ...                                       ...      ...             ...
# 4995                 Chief Operations Officer     None    January 2008
# 4996                      IT Services Manager     None   November 2005
# 4997                          General Manager     None            2004
# 4998                         Sr. EOL Engineer     None            2002
# 4999                              Sr. Partner     None    January 2001
#
#                                                    desc
# 0     Biomarker Leader for compounds in clinical dev...
# 1                          Single Cell Gene expression.
# 2     Work on peptide to restore wt p53 function in ...
# 3             Molecular profiling of colorectal cancer.
# 4     Cancer Research at Dept of Surgery.Molecular p...
# ...                                                 ...
# 4995  COO for a growing IT Consulting and Security F...
# 4996  Working as a VCIO for a company generating ove...
# 4997  Worked as General Manager for 2 offices. Respo...
# 4998  Sold high-end SANS, NAS, Blade Servers, EMC, C...
# 4999  * Designed and supervised the creation of 802....
#
# [5000 rows x 20 columns]

# %%
# Let's find all people (by ID) who have Marketing as a skill

mbio_df = skills_df2[skills_df2['skills'] == 'Molecular Biology'].reset_index()[['_id']]
mbio_df
# Out:
#                _id
# 0    proper-strain
# 1  ancient-cluster
# 2   metallic-shark

# %%
# %%time
merge(merge(people_df2, experience_df2, '_id', '_id'), mbio_df, '_id', '_id')
# Out:
# Merge compared 2500000 tuples
# Merge compared 15000 tuples
# CPU times: user 1min 54s, sys: 278 ms, total: 1min 55s
# Wall time: 1min 56s
#              _id                                               name  \
# 0  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 1  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 2  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 3  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 4  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 5  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 6  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 7  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 8  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
#
#              locality                                             skills  \
# 0  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 1  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 2  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 3  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 4  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 5  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 6  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 7  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 8  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
#
#    industry                                            summary  \
# 0  Internet  Conception de charte graphique pour des sites ...
# 1  Internet  Conception de charte graphique pour des sites ...
# 2  Internet  Conception de charte graphique pour des sites ...
# 3  Internet  Conception de charte graphique pour des sites ...
# 4  Internet  Conception de charte graphique pour des sites ...
# 5  Internet  Conception de charte graphique pour des sites ...
# 6  Internet  Conception de charte graphique pour des sites ...
# 7  Internet  Conception de charte graphique pour des sites ...
# 8  Internet  Conception de charte graphique pour des sites ...
#
#                                          url  \
# 0  https://www.linkedin.com/in/proper-strain
# 1  https://www.linkedin.com/in/proper-strain
# 2  https://www.linkedin.com/in/proper-strain
# 3  https://www.linkedin.com/in/proper-strain
# 4  https://www.linkedin.com/in/proper-strain
# 5  https://www.linkedin.com/in/proper-strain
# 6  https://www.linkedin.com/in/proper-strain
# 7  https://www.linkedin.com/in/proper-strain
# 8  https://www.linkedin.com/in/proper-strain
#
#                                            education group  interval  \
# 0  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 1  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 2  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 3  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 4  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 5  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 6  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 7  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 8  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
#
#                                           experience  \
# 0  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 1  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 2  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 3  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 4  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 5  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 6  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 7  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 8  [{'key': ['org', 'title', 'end', 'start'], 'va...
#
#                                          specilities  \
# 0  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 1  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 2  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 3  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 4  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 5  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 6  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 7  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 8  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
#
#                                               events interests  honors  \
# 0  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 1  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 2  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 3  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 4  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 5  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 6  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 7  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 8  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
#
#                    org                        title      end       start  desc
# 0             01design                        Owner  Present  March 2005  None
# 1  Team Partners Group                    Webmaster     None   June 1998  None
# 2              Cyperus  Chargé des relations presse     None  March 1995  None
# 3             01design                        Owner  Present  March 2005  None
# 4  Team Partners Group                    Webmaster     None   June 1998  None
# 5              Cyperus  Chargé des relations presse     None  March 1995  None
# 6             01design                        Owner  Present  March 2005  None
# 7  Team Partners Group                    Webmaster     None   June 1998  None
# 8              Cyperus  Chargé des relations presse     None  March 1995  None

# %%
# %%time
merge(merge(people_df2, mbio_df, '_id', '_id'), experience_df2, '_id', '_id')
# Out:
# Merge compared 1500 tuples
# Merge compared 5000 tuples
# CPU times: user 230 ms, sys: 82 µs, total: 230 ms
# Wall time: 231 ms
#              _id                                               name  \
# 0  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 1  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 2  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 3  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 4  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 5  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 6  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 7  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
# 8  proper-strain  {'family_name': 'Strange', 'given_name': 'Jenk...
#
#              locality                                             skills  \
# 0  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 1  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 2  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 3  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 4  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 5  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 6  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 7  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
# 8  Paris Area, France  [JavaScript, HTML, CSS, WYSIWYG layout tools, ...
#
#    industry                                            summary  \
# 0  Internet  Conception de charte graphique pour des sites ...
# 1  Internet  Conception de charte graphique pour des sites ...
# 2  Internet  Conception de charte graphique pour des sites ...
# 3  Internet  Conception de charte graphique pour des sites ...
# 4  Internet  Conception de charte graphique pour des sites ...
# 5  Internet  Conception de charte graphique pour des sites ...
# 6  Internet  Conception de charte graphique pour des sites ...
# 7  Internet  Conception de charte graphique pour des sites ...
# 8  Internet  Conception de charte graphique pour des sites ...
#
#                                          url  \
# 0  https://www.linkedin.com/in/proper-strain
# 1  https://www.linkedin.com/in/proper-strain
# 2  https://www.linkedin.com/in/proper-strain
# 3  https://www.linkedin.com/in/proper-strain
# 4  https://www.linkedin.com/in/proper-strain
# 5  https://www.linkedin.com/in/proper-strain
# 6  https://www.linkedin.com/in/proper-strain
# 7  https://www.linkedin.com/in/proper-strain
# 8  https://www.linkedin.com/in/proper-strain
#
#                                            education group  interval  \
# 0  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 1  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 2  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 3  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 4  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 5  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 6  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 7  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
# 8  [{'key': ['major', 'end', 'name', 'degree', 's...  None      19.0
#
#                                           experience  \
# 0  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 1  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 2  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 3  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 4  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 5  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 6  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 7  [{'key': ['org', 'title', 'end', 'start'], 'va...
# 8  [{'key': ['org', 'title', 'end', 'start'], 'va...
#
#                                          specilities  \
# 0  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 1  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 2  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 3  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 4  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 5  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 6  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 7  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
# 8  XML, HTML, JavaScript, usability, CSS, WYSIWYG...
#
#                                               events interests  honors  \
# 0  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 1  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 2  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 3  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 4  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 5  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 6  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 7  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
# 8  [{'from': 'Cyperus', 'to': 'Team Partners Grou...      None     NaN
#
#                    org                        title      end       start  desc
# 0             01design                        Owner  Present  March 2005  None
# 1  Team Partners Group                    Webmaster     None   June 1998  None
# 2              Cyperus  Chargé des relations presse     None  March 1995  None
# 3             01design                        Owner  Present  March 2005  None
# 4  Team Partners Group                    Webmaster     None   June 1998  None
# 5              Cyperus  Chargé des relations presse     None  March 1995  None
# 6             01design                        Owner  Present  March 2005  None
# 7  Team Partners Group                    Webmaster     None   June 1998  None
# 8              Cyperus  Chargé des relations presse     None  March 1995  None

# %%
# %%time

conn.sql("""select distinct s._id,s.skills from people p join skills s on p._id=s._id join
                  experience ex on s._id=ex._id and s.skills='Molecular Biology'""")
# Out:
# CPU times: user 3.21 ms, sys: 10 µs, total: 3.22 ms
# Wall time: 3.21 ms
# ┌─────────────────┬───────────────────┐
# │       _id       │      skills       │
# │     varchar     │      varchar      │
# ├─────────────────┼───────────────────┤
# │ ancient-cluster │ Molecular Biology │
# │ metallic-shark  │ Molecular Biology │
# │ honest-margin   │ Molecular Biology │
# │ honest-truss    │ Molecular Biology │
# │ organic-table   │ Molecular Biology │
# │ proper-strain   │ Molecular Biology │
# │ matte-render    │ Molecular Biology │
# └─────────────────┴───────────────────┘

# %%
# %%time

conn.sql("""select distinct s._id,s.skills from skills s join
                  experience ex on s._id=ex._id join people p on p._id=s._id where s.skills='Molecular Biology'""")
# Out:
# CPU times: user 846 µs, sys: 0 ns, total: 846 µs
# Wall time: 1.16 ms
# ┌─────────────────┬───────────────────┐
# │       _id       │      skills       │
# │     varchar     │      varchar      │
# ├─────────────────┼───────────────────┤
# │ ancient-cluster │ Molecular Biology │
# │ metallic-shark  │ Molecular Biology │
# │ honest-margin   │ Molecular Biology │
# │ honest-truss    │ Molecular Biology │
# │ proper-strain   │ Molecular Biology │
# │ matte-render    │ Molecular Biology │
# │ organic-table   │ Molecular Biology │
# └─────────────────┴───────────────────┘

# %%
conn.sql("select count(distinct _id) from skills where skills='Molecular Biology'")
# Out:
# ┌─────────────────────┐
# │ count(DISTINCT _id) │
# │        int64        │
# ├─────────────────────┤
# │                   8 │
# └─────────────────────┘

# %%
# Join using a *hash map*
# from keys to (single) values
def merge_map(S,T,l_on,r_on):
    ret = []
    T_map = {}
    count = 0
    # Take each value in the r_on field, and
    # make a map entry for it
    t_pos = T.columns.get_loc(r_on)
    for t_index in range(0, len(T)):
        # Make sure we aren't overwriting an entry!
        if (T.iat[t_index,t_pos] not in T_map):
          T_map[T.iat[t_index,t_pos]] = [T.loc[t_index]]
        else:
          T_map[T.iat[t_index,t_pos]].append(T.loc[t_index])
        count = count + 1

    # Now find matches
    S2 = S.reset_index().drop(columns=['index'])
    for s_index in range(0, len(S2)):
        count = count + 1
        if S2.loc[s_index, l_on] in T_map:
          for item in T_map[S2.loc[s_index, l_on]]:
            ret.append(S2.loc[s_index].to_dict() | item.drop(labels=r_on).to_dict())

    print('Merge compared %d tuples'%count)
    return pd.DataFrame(ret)

# %%
# %%time

# Here's a test join, with people and their experiences.  We can see how many
# comparisons are made
merge_map(experience_df2, people_df2, '_id', '_id')
# Out:
# Merge compared 5500 tuples
# CPU times: user 3.64 s, sys: 8.35 ms, total: 3.65 s
# Wall time: 4.25 s
#                   _id                                     org  \
# 0     adagio-catalyst                     Johnson and Johnson
# 1     adagio-catalyst          Albert Einstein Medical Center
# 2     adagio-catalyst                     Columbia University
# 3     adagio-catalyst  Memorial Sloan Kettering Cancer Center
# 4     adagio-catalyst         Sahlgrenska University Hospital
# ...               ...                                     ...
# 4995    gentle-sensor                           ANCGroup, INC
# 4996    gentle-sensor              On-Site Computer Solutions
# 4997    gentle-sensor                                 PC Guru
# 4998    gentle-sensor                                    Dell
# 4999    gentle-sensor                     Formulated IT Svcs.
#
#                                         title      end           start  \
# 0       Senior Scientist, Oncology Biomarkers  Present   November 2009
# 1     Associate at Dept of Molecular Genetics     None  September 2008
# 2                Associate Research Scientist     None     August 2006
# 3               Post Doctoral Research Fellow     None    January 2003
# 4                          Research Scientist     None   November 2001
# ...                                       ...      ...             ...
# 4995                 Chief Operations Officer     None    January 2008
# 4996                      IT Services Manager     None   November 2005
# 4997                          General Manager     None            2004
# 4998                         Sr. EOL Engineer     None            2002
# 4999                              Sr. Partner     None    January 2001
#
#                                                    desc  \
# 0     Biomarker Leader for compounds in clinical dev...
# 1                          Single Cell Gene expression.
# 2     Work on peptide to restore wt p53 function in ...
# 3             Molecular profiling of colorectal cancer.
# 4     Cancer Research at Dept of Surgery.Molecular p...
# ...                                                 ...
# 4995  COO for a growing IT Consulting and Security F...
# 4996  Working as a VCIO for a company generating ove...
# 4997  Worked as General Manager for 2 offices. Respo...
# 4998  Sold high-end SANS, NAS, Blade Servers, EMC, C...
# 4999  * Designed and supervised the creation of 802....
#
#                                                    name  \
# 0      {'family_name': 'Watt', 'given_name': 'Brunton'}
# 1      {'family_name': 'Watt', 'given_name': 'Brunton'}
# 2      {'family_name': 'Watt', 'given_name': 'Brunton'}
# 3      {'family_name': 'Watt', 'given_name': 'Brunton'}
# 4      {'family_name': 'Watt', 'given_name': 'Brunton'}
# ...                                                 ...
# 4995  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4996  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4997  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4998  {'family_name': 'Bruce', 'given_name': 'Barrym...
# 4999  {'family_name': 'Bruce', 'given_name': 'Barrym...
#
#                    locality  \
# 0     Antwerp Area, Belgium
# 1     Antwerp Area, Belgium
# 2     Antwerp Area, Belgium
# 3     Antwerp Area, Belgium
# 4     Antwerp Area, Belgium
# ...                     ...
# 4995     Austin, Texas Area
# 4996     Austin, Texas Area
# 4997     Austin, Texas Area
# 4998     Austin, Texas Area
# 4999     Austin, Texas Area
#
#                                                  skills  \
# 0                       [Molecular Biology, Biomarkers]
# 1                       [Molecular Biology, Biomarkers]
# 2                       [Molecular Biology, Biomarkers]
# 3                       [Molecular Biology, Biomarkers]
# 4                       [Molecular Biology, Biomarkers]
# ...                                                 ...
# 4995  [IT Management, Disaster Recovery, System Admi...
# 4996  [IT Management, Disaster Recovery, System Admi...
# 4997  [IT Management, Disaster Recovery, System Admi...
# 4998  [IT Management, Disaster Recovery, System Admi...
# 4999  [IT Management, Disaster Recovery, System Admi...
#
#                                  industry  \
# 0                         Pharmaceuticals
# 1                         Pharmaceuticals
# 2                         Pharmaceuticals
# 3                         Pharmaceuticals
# 4                         Pharmaceuticals
# ...                                   ...
# 4995  Information Technology and Services
# 4996  Information Technology and Services
# 4997  Information Technology and Services
# 4998  Information Technology and Services
# 4999  Information Technology and Services
#
#                                                 summary  \
# 0     Ph.D. scientist with background in cancer rese...
# 1     Ph.D. scientist with background in cancer rese...
# 2     Ph.D. scientist with background in cancer rese...
# 3     Ph.D. scientist with background in cancer rese...
# 4     Ph.D. scientist with background in cancer rese...
# ...                                                 ...
# 4995  IT Services Manager and Implementation special...
# 4996  IT Services Manager and Implementation special...
# 4997  IT Services Manager and Implementation special...
# 4998  IT Services Manager and Implementation special...
# 4999  IT Services Manager and Implementation special...
#
#                                               url  \
# 0     https://www.linkedin.com/in/adagio-catalyst
# 1     https://www.linkedin.com/in/adagio-catalyst
# 2     https://www.linkedin.com/in/adagio-catalyst
# 3     https://www.linkedin.com/in/adagio-catalyst
# 4     https://www.linkedin.com/in/adagio-catalyst
# ...                                           ...
# 4995    https://www.linkedin.com/in/gentle-sensor
# 4996    https://www.linkedin.com/in/gentle-sensor
# 4997    https://www.linkedin.com/in/gentle-sensor
# 4998    https://www.linkedin.com/in/gentle-sensor
# 4999    https://www.linkedin.com/in/gentle-sensor
#
#                                               education  \
# 0     [{'key': ['start', 'major', 'end', 'name', 'de...
# 1     [{'key': ['start', 'major', 'end', 'name', 'de...
# 2     [{'key': ['start', 'major', 'end', 'name', 'de...
# 3     [{'key': ['start', 'major', 'end', 'name', 'de...
# 4     [{'key': ['start', 'major', 'end', 'name', 'de...
# ...                                                 ...
# 4995  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4996  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4997  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4998  [{'key': ['major', 'name', 'degree', 'desc'], ...
# 4999  [{'key': ['major', 'name', 'degree', 'desc'], ...
#
#                                                   group  interval  \
# 0     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 1     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 2     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 3     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# 4     {'affilition': ['ASMALLWORLD.net', 'Biomarker ...      20.0
# ...                                                 ...       ...
# 4995  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4996  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4997  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4998  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
# 4999  {'member': 'AOPA', 'affilition': ['# 1 Group f...      16.0
#
#                                              experience  \
# 0     [{'key': ['org', 'title', 'end', 'start', 'des...
# 1     [{'key': ['org', 'title', 'end', 'start', 'des...
# 2     [{'key': ['org', 'title', 'end', 'start', 'des...
# 3     [{'key': ['org', 'title', 'end', 'start', 'des...
# 4     [{'key': ['org', 'title', 'end', 'start', 'des...
# ...                                                 ...
# 4995  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4996  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4997  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4998  [{'key': ['org', 'desc', 'end', 'start', 'titl...
# 4999  [{'key': ['org', 'desc', 'end', 'start', 'titl...
#
#                                             specilities  \
# 0     Biomarkers in Oncology, Cancer Genomics, Molec...
# 1     Biomarkers in Oncology, Cancer Genomics, Molec...
# 2     Biomarkers in Oncology, Cancer Genomics, Molec...
# 3     Biomarkers in Oncology, Cancer Genomics, Molec...
# 4     Biomarkers in Oncology, Cancer Genomics, Molec...
# ...                                                 ...
# 4995  IT Management, disaster recovery, computer for...
# 4996  IT Management, disaster recovery, computer for...
# 4997  IT Management, disaster recovery, computer for...
# 4998  IT Management, disaster recovery, computer for...
# 4999  IT Management, disaster recovery, computer for...
#
#                                                  events  \
# 0     [{'from': 'Sahlgrenska University Hospital', '...
# 1     [{'from': 'Sahlgrenska University Hospital', '...
# 2     [{'from': 'Sahlgrenska University Hospital', '...
# 3     [{'from': 'Sahlgrenska University Hospital', '...
# 4     [{'from': 'Sahlgrenska University Hospital', '...
# ...                                                 ...
# 4995  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4996  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4997  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4998  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
# 4999  [{'from': 'AMD', 'to': 'Formulated IT Svcs.', ...
#
#                                           interests  \
# 0                                              None
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# ...                                             ...
# 4995  Stock Market, Playing with the kiddos, Gaming
# 4996  Stock Market, Playing with the kiddos, Gaming
# 4997  Stock Market, Playing with the kiddos, Gaming
# 4998  Stock Market, Playing with the kiddos, Gaming
# 4999  Stock Market, Playing with the kiddos, Gaming
#
#                                                  honors
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4995  [Most Billable Person 2006 (On-Site Computer S...
# 4996  [Most Billable Person 2006 (On-Site Computer S...
# 4997  [Most Billable Person 2006 (On-Site Computer S...
# 4998  [Most Billable Person 2006 (On-Site Computer S...
# 4999  [Most Billable Person 2006 (On-Site Computer S...
#
# [5000 rows x 20 columns]

# %% [markdown]
# ## Exercise

# %%
# %%writefile notebook-config.yaml
#
# grader_api_url: 'https://23whrwph9h.execute-api.us-east-1.amazonaws.com/default/Grader23'
# grader_api_key: 'flfkE736fA6Z8GxMDJe2q8Kfk8UDqjsG3GVqOFOa'
# Out:
# Writing notebook-config.yaml

# %%
# !pip3 install penngrader-client
# Out:
# Collecting penngrader-client
#   Downloading penngrader_client-0.5.2-py3-none-any.whl.metadata (15 kB)
# Collecting dill (from penngrader-client)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from penngrader-client) (6.0.2)
# Downloading penngrader_client-0.5.2-py3-none-any.whl (10 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: dill, penngrader-client
# Successfully installed dill-0.3.8 penngrader-client-0.5.2

# %%
#PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO
#TO ASSIGN POINTS TO YOU IN OUR BACKEND
STUDENT_ID = 99999999 # YOUR PENN-ID GOES HERE AS AN INTEGER##PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO

# %%
# %set_env HW_ID=cis2450_fall24_HW9
# Out:
# env: HW_ID=cis2450_fall24_HW9

# %%
import os
from penngrader.grader import *

grader = PennGrader('notebook-config.yaml', os.environ['HW_ID'], STUDENT_ID, STUDENT_ID)
# Out:
# PennGrader initialized with Student ID: 99999999
#
# Make sure this correct or we will not be able to store your grade

# %% [markdown]
# Take the following query and use the `merge` or `merge_map` functions to execute it.  You can use Pandas to pre-apply or post-apply any filter conditions (selections) on dataframes.
#
# ```
# SELECT _id, skills
# FROM people_df2 p JOIN skills_df2 s ON p._id = s._id
# WHERE industry = 'Pharmaceutical'
# ```

# %%
# TODO: compute results_df as per the above

# %%
grader.grade('pharma', results_df)
# Out:
# Correct! You earned 1/1 points. You are a star!
#
# Your submission has been successfully recorded in the gradebook.
