# %% [markdown]
# <a href="https://colab.research.google.com/github/zackives/upenn-cis-2450/blob/main/7_Module_2_Part_III_Better_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Better SQL - How to Understand, Write, and Debug
#
# It's easy to write SQL queries that become very challenging to debug.
#
# In this Notebook, we'll try to summarize some of the subtleties of different SQL constructs, how they relate, and how we might debug.

# %%
# !wget -nc https://storage.googleapis.com/penn-cis5450/linkedin_anon.jsonl
# Out:
# --2024-09-21 15:17:44--  https://storage.googleapis.com/penn-cis5450/linkedin_anon.jsonl
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.199.207, 74.125.142.207, 74.125.195.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.199.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 179851696 (172M) [application/octet-stream]
# Saving to: ‘linkedin_anon.jsonl’
#
# linkedin_anon.jsonl 100%[===================>] 171.52M   112MB/s    in 1.5s
#
# 2024-09-21 15:17:45 (112 MB/s) - ‘linkedin_anon.jsonl’ saved [179851696/179851696]

# %%
# !pip3 install lxml
# !pip3 install duckdb
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (1.1.0)

# %% [markdown]
# ## Setting up a sample database
#
# All of this is to load up our LinkedIn data...

# %%
import pandas as pd
import numpy as np

# JSON parsing
import json

# HTML parsing
from lxml import etree
import urllib

# DuckDB RDBMS
import duckdb

# Polars big data package
import polars

# Time conversions
import time

# %%
'''
Simple code to pull out data from JSON and load into DuckDB.
'''
import ast

linked_in = open('linkedin_anon.jsonl')
people_df = pd.read_json('linkedin_anon.jsonl', lines=True)

# %%
def get_nested_dict(rel, name):
  # This evaluates the string that describes the dictionary, as a dictionary
  # definition
  ret = rel.copy()
  # ret[name] = rel[name].map(lambda x: ast.literal_eval(x) if len(x) else np.NaN)
  ret = ret.dropna()
  # This joins rows on the index
  return ret.drop(columns=name).join(pd.DataFrame(ret[name].tolist()))

def get_nested_list(rel, name):
  ret = rel.copy()
  ret = ret.dropna().explode(name).dropna()
  ret = ret.join(pd.DataFrame(ret[name].tolist())).drop(columns=name).drop_duplicates()
  return ret.rename(columns={0: name})

def get_nested_list_dict(rel, name):
  ret = rel.copy()

  ret = ret.dropna().explode(name)

  exploded_pairs = pd.DataFrame(ret.apply(lambda x: {'_id': x['_id']} | x[name] if isinstance(x[name], dict) else {'_id': x['_id']}, axis=1).tolist())

  return ret.merge(exploded_pairs, on='_id').drop(columns=name)
  #pd.DataFrame(ret[name].tolist())).drop(columns=name).drop_duplicates()

# Take the lists, drop any blank strings
specialties_df = people_df[['_id','specilities']].explode('specilities').rename(columns={'_id': 'person'})
specialties_df.dropna(inplace=True)
interests_df = people_df[['_id','interests']].explode('interests').rename(columns={'_id': 'person'})
interests_df.dropna(inplace=True)

names_df = get_nested_dict(people_df[['_id','name']], 'name')

education_df = get_nested_list_dict(people_df[['_id','education']], 'education')
experience_df = get_nested_list_dict(people_df[['_id','experience']], 'experience')
skills_df = get_nested_list(people_df[['_id','skills']], 'skills')
honors_df = get_nested_list(people_df[['_id','honors']], 'honors')
events_df = get_nested_list_dict(people_df[['_id','events']], 'events')

groups_df = get_nested_dict(people_df[['_id','group']], 'group')

people_only_df = people_df.drop(columns=['name','education','group','skills','experience','honors','events','specilities','interests']).\
  merge(names_df, on='_id')

# %%
## This is just to reset things so we don't have an index
conn = duckdb.connect('linkedin.db')
conn.execute('BEGIN TRANSACTION')
conn.execute('DROP TABLE IF EXISTS people')
conn.execute('DROP TABLE IF EXISTS education')
conn.execute('DROP TABLE IF EXISTS experience')
conn.execute('DROP TABLE IF EXISTS skills')
conn.execute('DROP TABLE IF EXISTS honors')
conn.execute('DROP TABLE IF EXISTS events')
conn.execute('DROP TABLE IF EXISTS groups')
conn.execute('DROP TABLE IF EXISTS specialties')
conn.execute('DROP TABLE IF EXISTS interests')
conn.execute('DROP INDEX IF EXISTS people_industry')
conn.execute('CREATE TABLE people AS SELECT * FROM people_only_df')
conn.execute('CREATE TABLE education AS SELECT * FROM education_df')
conn.execute('CREATE TABLE experience AS SELECT * FROM experience_df')
conn.execute('CREATE TABLE skills AS SELECT * FROM skills_df')
conn.execute('CREATE TABLE honors AS SELECT * FROM honors_df')
conn.execute('CREATE TABLE events AS SELECT * FROM events_df')
conn.execute('CREATE TABLE groups AS SELECT * FROM groups_df')
conn.execute('CREATE TABLE specialties AS SELECT * FROM specialties_df')
conn.execute('CREATE TABLE interests AS SELECT * FROM interests_df')
conn.execute('COMMIT')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# ## Penngrader setup

# %%
# %%writefile notebook-config.yaml
#
# grader_api_url: 'https://23whrwph9h.execute-api.us-east-1.amazonaws.com/default/Grader23'
# grader_api_key: 'flfkE736fA6Z8GxMDJe2q8Kfk8UDqjsG3GVqOFOa'
# Out:
# Writing notebook-config.yaml

# %%
# !pip3 install penngrader-client
# Out:
# Collecting penngrader-client
#   Downloading penngrader_client-0.5.2-py3-none-any.whl.metadata (15 kB)
# Collecting dill (from penngrader-client)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from penngrader-client) (6.0.2)
# Downloading penngrader_client-0.5.2-py3-none-any.whl (10 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: dill, penngrader-client
# Successfully installed dill-0.3.8 penngrader-client-0.5.2

# %%
#PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO
#TO ASSIGN POINTS TO YOU IN OUR BACKEND
STUDENT_ID = 99999999 # YOUR PENN-ID GOES HERE AS AN INTEGER##PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO

# %%
# %set_env HW_ID=cis2450_fall24_HW9
# Out:
# env: HW_ID=cis2450_fall24_HW9

# %%
import os
from penngrader.grader import *

grader = PennGrader('notebook-config.yaml', os.environ['HW_ID'], STUDENT_ID, STUDENT_ID)
# Out:
# PennGrader initialized with Student ID: 99999999
#
# Make sure this correct or we will not be able to store your grade

# %% [markdown]
# ## Validating the database setup

# %%
conn.sql("""
SELECT DISTINCT industry
FROM people
WHERE industry IS NOT NULL
""").df()
# Out:
#                                  industry
# 0                         Medical Devices
# 1                         Pharmaceuticals
# 2                                Research
# 3     Information Technology and Services
# 4                      Telecommunications
# ...                                   ...
# 1504              Çevre Koruma Hizmetleri
# 1505                  Învățământ superior
# 1506                        Biyoteknoloji
# 1507                 Медицинская практика
# 1508                            Pemborong
#
# [1509 rows x 1 columns]

# %%
conn.sql("""
SELECT DISTINCT skills
FROM skills
""").df()
# Out:
#                     skills
# 0       Strategic Planning
# 1          Market Planning
# 2              Negotiation
# 3              Forecasting
# 4         Sales Management
# ...                    ...
# 8451          Free to Play
# 8452  Time Series Analysis
# 8453     Company Valuation
# 8454              SAS Base
# 8455        Play Framework
#
# [8456 rows x 1 columns]

# %% [markdown]
# ### Queries with Joins
#
# How many People have skills related to Biology and work in Tech?

# %%
conn.sql('select * from people').df()
# Out:
#                         _id                    locality  \
# 0               moist-vodka               United States
# 1           adagio-catalyst       Antwerp Area, Belgium
# 2                tart-acorn   San Francisco, California
# 3        objective-riesling      San Francisco Bay Area
# 4      generative-amberjack         Chennai Area, India
# ...                     ...                         ...
# 51817         glowing-flush        Greater Chicago Area
# 51818        grouchy-flight        Greater Atlanta Area
# 51819            dense-bell        Calgary, Canada Area
# 51820           brave-hoops      San Francisco Bay Area
# 51821       fixed-partition  Greater New York City Area
#
#                                   industry  \
# 0                          Medical Devices
# 1                          Pharmaceuticals
# 2                                 Research
# 3      Information Technology and Services
# 4                     Aviation & Aerospace
# ...                                    ...
# 51817            Marketing and Advertising
# 51818                   Financial Services
# 51819                               Design
# 51820                        Public Policy
# 51821  Public Relations and Communications
#
#                                                  summary  \
# 0      SALES MANAGEMENT / BUSINESS DEVELOPMENT / PROJ...
# 1      Ph.D. scientist with background in cancer rese...
# 2      I am interested in inventing new methods to co...
# 3      OBJECTIVE<Primary> Work on an interesting and ...
# 4      Experience in Avionics Systems, Embedded Syste...
# ...                                                  ...
# 51817  Sales and marketing professional specializing ...
# 51818  Accomplished business development manager expe...
# 51819  Brad Gibson is a recognized expert in power qu...
# 51820  Brad Kane's multi-faceted career in the govern...
# 51821  Client Experience:CONSUMER TECH: foursquare, O...
#
#                                                     url  interval family_name  \
# 0               https://www.linkedin.com/in/moist-vodka       NaN        Post
# 1           https://www.linkedin.com/in/adagio-catalyst      20.0        Watt
# 2                https://www.linkedin.com/in/tart-acorn       0.0      Hannay
# 3        https://www.linkedin.com/in/objective-riesling       5.0    Carnegie
# 4      https://www.linkedin.com/in/generative-amberjack       NaN      Duncan
# ...                                                 ...       ...         ...
# 51817         https://www.linkedin.com/in/glowing-flush       5.0     Kincaid
# 51818        https://www.linkedin.com/in/grouchy-flight      14.0      Ogilvy
# 51819            https://www.linkedin.com/in/dense-bell      42.0  Macdougall
# 51820           https://www.linkedin.com/in/brave-hoops      26.0     Forsyth
# 51821       https://www.linkedin.com/in/fixed-partition      16.0      Donald
#
#          given_name
# 0         Belvedere
# 1           Brunton
# 2      Passepartout
# 3      Passepartout
# 4          Merriman
# ...             ...
# 51817  Passepartout
# 51818     Bullimore
# 51819     Barrymore
# 51820       Cadbury
# 51821        Alfred
#
# [51822 rows x 8 columns]

# %% [markdown]
# # Understanding UNION, INTERSECTION, Cartesian Product, and JOIN
#
# Recall that relations are *sets of tuples* and that the Relational Algebra is a set of operations over sets of tuples.  SELECT filters tuples, PROJECT changes (projects out of) their schema, etc.
#
# Recall that sets have three common operators:
#
# 1. UNION
# 2. INTERSECTION
# 3. CARTESIAN PRODUCT

# %% [markdown]
# (Recall that by default database tables allow duplicates.  We can always use `SELECT DISTINCT` to get true sets.)

# %% [markdown]
# ## UNION and WHERE c1() OR c2()
#
# In a way, UNION is the simplest operation, conceptually. We take two sets of tuples (with the same schema!) and put them together.
#
# We can do this, for instance, to collect sets of items that satisfy either of two different conditions.

# %%
display(conn.sql("""
  SELECT DISTINCT _id, given_name, family_name
  FROM people
  WHERE lower(industry) LIKE '%bio%'
  UNION
  SELECT DISTINCT _id, given_name, family_name
  FROM people
  WHERE lower(industry) LIKE '%tech%'
""").df())
# Out:
#                         _id    given_name family_name
# 0              rosy-nucleus     Leporello   Forrester
# 1            quick-subfloor     Belvedere      Howard
# 2           intense-phalanx        Figaro      Hannay
# 3                 boxy-cove        Figaro     Riddell
# 4           abstract-nickel  Passepartout    Campbell
# ...                     ...           ...         ...
# 6556          novel-century     Bertuccio   Fergusson
# 6557      scared-luminosity       Cadbury     Maclean
# 6558             wise-bight        Figaro        Greg
# 6559            tender-peak       Brunton       Akins
# 6560  straight-installation        Figaro         Hay
#
# [6561 rows x 3 columns]

# %% [markdown]
# Because UNION combines sets, we can interchangeably go between different union "branches" and *disjunction* (`OR`) in our queries:
#
# ```
#  SELECT *
#  FROM S
#  WHERE c1(S)
# UNION
#  SELECT *
#  FROM S
#  WHERE c2(S)
#  ```
#
#  vs
#
#  ```
#  SELECT *
#  FROM S
#  WHERE c1(S) OR c2(S)
# ```

# %% [markdown]
# ### Exercise
#
# Given the above: try writing the above query about bio and tech people as a single SELECT with an OR:

# %%
# TODO
result_df = # TODO

display(result_df)

# %%
if not isinstance(result_df, pd.DataFrame):
  raise TypeError("Value in results_df must be a pandas DataFrame")
grader.grade('sql_or', result_df)
# Out:
# Correct! You earned 1/1 points. You are a star!
#
# Your submission has been successfully recorded in the gradebook.

# %% [markdown]
# ## Multisets and UNION
#
# What if I want to *count* how many rows there are with people who have these skills? If so, I may want *multisets* or *bags*.  Here I don't use `DISTINCT`.

# %%
display(conn.sql("""
  SELECT count(_id)
  FROM people
  WHERE lower(industry) LIKE '%bio%' OR lower(industry) LIKE '%tech%'
""").df())
# Out:
#    count(_id)
# 0        6594

# %% [markdown]
# I can also assemble sub-results via UNION, but if I want "bag union" I need to say UNION ALL.

# %%
display(conn.sql("""
  SELECT COUNT(*)
  FROM (
    SELECT _id, given_name, family_name
    FROM people
    WHERE lower(industry) LIKE '%bio%'
    UNION ALL
    SELECT _id, given_name, family_name
    FROM people
    WHERE lower(industry) LIKE '%tech%'
  )
""").df())
# Out:
#    count_star()
# 0          6857

# %% [markdown]
# ### Question for discussion
#
# *Why is this not the same?  What could we do to fix it?  You are welcome to discuss with your peers or on Ed Discussion.*

# %% [markdown]
# ## JOIN is a Cartesian Product

# %% [markdown]
# Again connecting to set operations: JOIN is a special case of CARTESIAN PRODUCT, namely a CARTESIAN PRODUCT followed by SELECT (which is the join condition).

# %%
display(conn.sql("""
  SELECT DISTINCT _id, given_name, family_name
  FROM people NATURAL JOIN skills
""").df())

display(conn.sql("""
  SELECT DISTINCT people._id, given_name, family_name
  FROM people CROSS JOIN skills
  WHERE people._id = skills._id
""").df())
# Out:
#                         _id    given_name family_name
# 0                tart-acorn  Passepartout      Hannay
# 1      generative-amberjack      Merriman      Duncan
# 2           arctic-investor      Merriman       Rollo
# 3               cold-reveal     Barrymore     Kincaid
# 4          afraid-collision      Merriman      Hunter
# ...                     ...           ...         ...
# 38142           joint-atoll       Cadbury  Macalister
# 38143       resultant-coach     Bertuccio     Kincaid
# 38144         glowing-flush  Passepartout     Kincaid
# 38145            dense-bell     Barrymore  Macdougall
# 38146           brave-hoops       Cadbury     Forsyth
#
# [38147 rows x 3 columns]
#                      _id given_name family_name
# 0            moist-vodka  Belvedere        Post
# 1        adagio-catalyst    Brunton        Watt
# 2          salty-section     Figaro        Watt
# 3      sensitive-estuary   Merriman     Macneil
# 4             rich-laser     Figaro    Spalding
# ...                  ...        ...         ...
# 38142      happy-circuit  Simonides       Brown
# 38143         calm-block     Figaro      Macnab
# 38144    piercing-tetrad    Brunton      Hunter
# 38145   espressivo-media    Brunton      Dundas
# 38146       flat-leading    Cadbury       Lewis
#
# [38147 rows x 3 columns]

# %% [markdown]
# ### Join and Intersection
#
# Sometimes you are asked for sets of items that jointly satisfy conditions.  If you just want to return the basic items, this can be accomplished with an INTERSECTion:

# %%
conn.sql("""
  SELECT DISTINCT _id, given_name, family_name
  FROM people NATURAL JOIN skills
  WHERE lower(skills.skills) LIKE '%bio%'
  INTERSECT
  SELECT DISTINCT _id, given_name, family_name
  FROM people NATURAL JOIN experience
  WHERE lower(industry) LIKE '%technology%'
""").df()
# Out:
#                   _id given_name family_name
# 0     foggy-frontlist  Simonides       Scott
# 1           meek-pear      Poole      Hunter
# 2  vertical-alignment      Poole    Lockhart
# 3           meek-pear    Cadbury     Haldane
# 4  extremal-generator  Barrymore     Haldane

# %% [markdown]
# But also with a join:

# %%
conn.sql("""
  SELECT DISTINCT _id, given_name, family_name
  FROM people NATURAL JOIN skills NATURAL JOIN experience
  WHERE lower(skills.skills) LIKE '%bio%' AND
   lower(industry) LIKE '%technology%'
""").df()
# Out:
#                   _id given_name family_name
# 0     foggy-frontlist  Simonides       Scott
# 1           meek-pear      Poole      Hunter
# 2           meek-pear    Cadbury     Haldane
# 3  vertical-alignment      Poole    Lockhart
# 4  extremal-generator  Barrymore     Haldane

# %%
conn.sql("""
  SELECT DISTINCT _id, given_name, family_name
  FROM people NATURAL JOIN skills NATURAL JOIN experience
  WHERE lower(skills.skills) LIKE '%bio%' AND
   lower(industry) LIKE '%technology%'
""").df()
# Out:
#                   _id given_name family_name
# 0     foggy-frontlist  Simonides       Scott
# 1           meek-pear      Poole      Hunter
# 2  vertical-alignment      Poole    Lockhart
# 3           meek-pear    Cadbury     Haldane
# 4  extremal-generator  Barrymore     Haldane

# %% [markdown]
# So why would I use one vs the other?
#
# 1. Remember that INTERSECTION only returns items from the set that satisfy the condition. You can't, for instance, include combinations of fields that match.
# 2. If your checks-for-relationships span multiple tables, then that is *inherently* a join.
# 3. Remember that JOIN will be default produce a multiset (you can SELECT DISTINCT to remove).

# %%
conn.sql("""
  SELECT DISTINCT _id, given_name, family_name, skills, industry
  FROM people NATURAL JOIN skills NATURAL JOIN experience
  WHERE lower(skills.skills) LIKE '%bio%' AND
   lower(industry) LIKE '%technology%'
""").df()
# Out:
#                   _id given_name family_name                  skills  \
# 0           meek-pear      Poole      Hunter           Biotechnology
# 1           meek-pear    Cadbury     Haldane           Biotechnology
# 2  extremal-generator  Barrymore     Haldane  Biomedical Engineering
# 3  vertical-alignment      Poole    Lockhart   Computational Biology
# 4     foggy-frontlist  Simonides       Scott           Biotechnology
#
#                               industry
# 0  Information Technology and Services
# 1  Information Technology and Services
# 2  Information Technology and Services
# 3  Information Technology and Services
# 4  Information Technology and Services

# %% [markdown]
# ## Python Comprehensions vs SQL ... and Conditionals
#
# SQL is a bit like Python [list comprehensions](https://www.programiz.com/python-programming/list-comprehension).  In Python, we can create a new list from the members of another collection, using list-builder (square-bracket) notation, and the *for* keyword.
#
# Intuitively, the list comprehension is heavily inspired by set-builder notation in discrete mathematics. Perhaps you've seen mathematical expressions like this:
#
# $$\{x | x \in S \wedge x < 5\}$$
#
# Suppose $S$ were a list and not a set.  You could imagine extending to a list-builder notation like this:
#
# $$[x | x \in S \wedge x < 5]$$
#
# Indeed, that's roughly what Python does as a list comprehension:
#
# ```
# [x for x in S]
# ```
#
# Now let's connect this to DataFrames, which are really lists of tuples. We can, if we want to, iterate over the set of rows in a dataframe, and pull out the name from the content in a list:

# %%
[x[1]['name'] for x in people_df.iterrows()]
# Out:
# [{'family_name': 'Post', 'given_name': 'Belvedere'},
#  {'family_name': 'Watt', 'given_name': 'Brunton'},
#  {'family_name': 'Hannay', 'given_name': 'Passepartout'},
#  {'family_name': 'Carnegie', 'given_name': 'Passepartout'},
#  {'family_name': 'Duncan', 'given_name': 'Merriman'},
#  {'family_name': 'Watt', 'given_name': 'Figaro'},
#  {'family_name': 'Graham', 'given_name': 'Leporello'},
#  {'family_name': 'Macneil', 'given_name': 'Merriman'},
#  {'family_name': 'Rollo', 'given_name': 'Merriman'},
#  {'family_name': 'Spalding', 'given_name': 'Figaro'},
#  {'family_name': 'Kincaid', 'given_name': 'Barrymore'},
#  {'family_name': 'Hunter', 'given_name': 'Merriman'},
#  {'family_name': 'Burnett', 'given_name': 'Merriman'},
#  {'family_name': 'Haig', 'given_name': 'Belvedere'},
#  {'family_name': 'Howard', 'given_name': 'Poole'},
#  {'family_name': 'Primrose', 'given_name': 'Belvedere'},
#  {'family_name': 'Hamilton', 'given_name': 'Brunton'},
#  {'family_name': 'Barclay', 'given_name': 'Cadbury'},
#  {'family_name': 'Buchanan', 'given_name': 'Figaro'},
#  {'family_name': 'Allen', 'given_name': 'Brunton'},
#  {'family_name': 'Morr', 'given_name': 'Barrymore'},
#  {'family_name': 'Cumming', 'given_name': 'Leporello'},
#  {'family_name': 'Sutherland', 'given_name': 'Poole'},
#  {'family_name': 'Hamilton', 'given_name': 'Barkley'},
#  {'family_name': 'Macmillan', 'given_name': 'Barrymore'},
#  {'family_name': 'Mackenzie', 'given_name': 'Bullimore'},
#  {'family_name': 'Strange', 'given_name': 'Jenkins'},
#  {'family_name': 'Nesbitt', 'given_name': 'Passepartout'},
#  {'family_name': 'Boyd', 'given_name': 'Simonides'},
#  {'family_name': 'Malcolm', 'given_name': 'Figaro'},
#  {'family_name': 'Macintyre', 'given_name': 'Belvedere'},
#  {'family_name': 'Mackay', 'given_name': 'Bertuccio'},
#  {'family_name': 'Fleming', 'given_name': 'Barkley'},
#  {'family_name': 'Gordon', 'given_name': 'Bullimore'},
#  {'family_name': 'Lindsay', 'given_name': 'Brunton'},
#  {'family_name': 'Mair', 'given_name': 'Alfred'},
#  {'family_name': 'Mackay', 'given_name': 'Barkley'},
#  {'family_name': 'Campbell', 'given_name': 'Poole'},
#  {'family_name': 'Carmichael', 'given_name': 'Leporello'},
#  {'family_name': 'Innes', 'given_name': 'Merriman'},
#  {'family_name': 'Stuart', 'given_name': 'Leporello'},
#  {'family_name': 'Macdonnell', 'given_name': 'Leporello'},
#  {'family_name': 'Ramsay', 'given_name': 'Barrymore'},
#  {'family_name': 'Beckham', 'given_name': 'Leporello'},
#  {'family_name': 'Kennedy', 'given_name': 'Barkley'},
#  {'family_name': 'Boyle', 'given_name': 'Jeeves'},
#  {'family_name': 'Sterling', 'given_name': 'Belvedere'},
#  {'family_name': 'Burnett', 'given_name': 'Belvedere'},
#  {'family_name': 'Macfarlane', 'given_name': 'Leporello'},
#  {'family_name': 'Maclean', 'given_name': 'Jeeves'},
#  {'family_name': 'Dewar', 'given_name': 'Bertuccio'},
#  {'family_name': 'Gordon', 'given_name': 'Belvedere'},
#  {'family_name': 'Finlay', 'given_name': 'Barkley'},
#  {'family_name': 'Mcmullen', 'given_name': 'Simonides'},
#  {'family_name': 'Howard', 'given_name': 'Jenkins'},
#  {'family_name': 'Dewar', 'given_name': 'Belvedere'},
#  {'family_name': 'Hay', 'given_name': 'Simonides'},
#  {'family_name': 'Montgomery', 'given_name': 'Passepartout'},
#  {'family_name': 'Murray', 'given_name': 'Simonides'},
#  {'family_name': 'Post', 'given_name': 'Belvedere'},
#  {'family_name': 'Hunter', 'given_name': 'Jenkins'},
#  {'family_name': 'Fergusson', 'given_name': 'Brunton'},
#  {'family_name': 'Post', 'given_name': 'Passepartout'},
#  {'family_name': 'Agnew', 'given_name': 'Leporello'},
#  {'family_name': 'Riddell', 'given_name': 'Jeeves'},
#  {'family_name': 'Stuart', 'given_name': 'Merriman'},
#  {'family_name': 'Forbes', 'given_name': 'Passepartout'},
#  {'family_name': 'Forbes', 'given_name': 'Jenkins'},
#  {'family_name': 'Lockhart', 'given_name': 'Barkley'},
#  {'family_name': 'Chisholm', 'given_name': 'Figaro'},
#  {'family_name': 'Crichton', 'given_name': 'Belvedere'},
#  {'family_name': 'Napier', 'given_name': 'Bertuccio'},
#  {'family_name': 'Henderson', 'given_name': 'Simonides'},
#  {'family_name': 'Charteris', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macmillan', 'given_name': 'Merriman'},
#  {'family_name': 'Boyd', 'given_name': 'Cadbury'},
#  {'family_name': 'Stewart', 'given_name': 'Barrymore'},
#  {'family_name': 'Armstrong', 'given_name': 'Bertuccio'},
#  {'family_name': 'Innes', 'given_name': 'Barrymore'},
#  {'family_name': 'Boyd', 'given_name': 'Passepartout'},
#  {'family_name': 'Baird', 'given_name': 'Simonides'},
#  {'family_name': 'Allen', 'given_name': 'Leporello'},
#  {'family_name': 'Greg', 'given_name': 'Brunton'},
#  {'family_name': 'Allen', 'given_name': 'Bertuccio'},
#  {'family_name': 'Blair', 'given_name': 'Cadbury'},
#  {'family_name': 'Stuart', 'given_name': 'Barkley'},
#  {'family_name': 'Post', 'given_name': 'Jenkins'},
#  {'family_name': 'Armstrong', 'given_name': 'Passepartout'},
#  {'family_name': 'Robertson', 'given_name': 'Alfred'},
#  {'family_name': 'Cunningham', 'given_name': 'Cadbury'},
#  {'family_name': 'Macintyre', 'given_name': 'Merriman'},
#  {'family_name': 'Livingstone', 'given_name': 'Leporello'},
#  {'family_name': 'Moffat', 'given_name': 'Merriman'},
#  {'family_name': 'Kincaid', 'given_name': 'Merriman'},
#  {'family_name': 'Blair', 'given_name': 'Jeeves'},
#  {'family_name': 'Bruce', 'given_name': 'Barrymore'},
#  {'family_name': 'Sterling', 'given_name': 'Simonides'},
#  {'family_name': 'Riddell', 'given_name': 'Leporello'},
#  {'family_name': 'Fleming', 'given_name': 'Cadbury'},
#  {'family_name': 'Lough', 'given_name': 'Leporello'},
#  {'family_name': 'Lyon', 'given_name': 'Jenkins'},
#  {'family_name': 'Haldane', 'given_name': 'Leporello'},
#  {'family_name': 'Macdonnell', 'given_name': 'Alfred'},
#  {'family_name': 'Moffat', 'given_name': 'Leporello'},
#  {'family_name': 'Macneil', 'given_name': 'Brunton'},
#  {'family_name': 'Lamont', 'given_name': 'Merriman'},
#  {'family_name': 'Blair', 'given_name': 'Passepartout'},
#  {'family_name': 'Rose', 'given_name': 'Bertuccio'},
#  {'family_name': 'Buchanan', 'given_name': 'Bullimore'},
#  {'family_name': 'Baird', 'given_name': 'Belvedere'},
#  {'family_name': 'Harris', 'given_name': 'Leporello'},
#  {'family_name': 'Boyd', 'given_name': 'Jenkins'},
#  {'family_name': 'Macarthur', 'given_name': 'Poole'},
#  {'family_name': 'Henry', 'given_name': 'Simonides'},
#  {'family_name': 'Macintyre', 'given_name': 'Leporello'},
#  {'family_name': 'Mackay', 'given_name': 'Bullimore'},
#  {'family_name': 'Hannay', 'given_name': 'Poole'},
#  {'family_name': 'Livingstone', 'given_name': 'Figaro'},
#  {'family_name': 'Kennedy', 'given_name': 'Merriman'},
#  {'family_name': 'Shaw', 'given_name': 'Barrymore'},
#  {'family_name': 'Malcolm', 'given_name': 'Bullimore'},
#  {'family_name': 'Macdonald', 'given_name': 'Alfred'},
#  {'family_name': 'Macfarlane', 'given_name': 'Belvedere'},
#  {'family_name': 'Lyon', 'given_name': 'Alfred'},
#  {'family_name': 'Nicolson', 'given_name': 'Poole'},
#  {'family_name': 'Dunbar', 'given_name': 'Leporello'},
#  {'family_name': 'Irvine', 'given_name': 'Cadbury'},
#  {'family_name': 'Innes', 'given_name': 'Merriman'},
#  {'family_name': 'Murray', 'given_name': 'Figaro'},
#  {'family_name': 'Lamont', 'given_name': 'Barrymore'},
#  {'family_name': 'Macduff', 'given_name': 'Jeeves'},
#  {'family_name': 'Lennox', 'given_name': 'Barkley'},
#  {'family_name': 'Campbell', 'given_name': 'Alfred'},
#  {'family_name': 'Forsyth', 'given_name': 'Leporello'},
#  {'family_name': 'Douglas', 'given_name': 'Alfred'},
#  {'family_name': 'Creel', 'given_name': 'Poole'},
#  {'family_name': 'Fleet', 'given_name': 'Figaro'},
#  {'family_name': 'Sinclair', 'given_name': 'Bertuccio'},
#  {'family_name': 'Hunter', 'given_name': 'Cadbury'},
#  {'family_name': 'Dundas', 'given_name': 'Poole'},
#  {'family_name': 'Moffat', 'given_name': 'Jenkins'},
#  {'family_name': 'Rose', 'given_name': 'Poole'},
#  {'family_name': 'Hamilton', 'given_name': 'Simonides'},
#  {'family_name': 'Lamont', 'given_name': 'Bertuccio'},
#  {'family_name': 'Innes', 'given_name': 'Passepartout'},
#  {'family_name': 'Lennox', 'given_name': 'Jenkins'},
#  {'family_name': 'Dunbar', 'given_name': 'Barrymore'},
#  {'family_name': 'Rollo', 'given_name': 'Leporello'},
#  {'family_name': 'Lough', 'given_name': 'Jenkins'},
#  {'family_name': 'Fergusson', 'given_name': 'Simonides'},
#  {'family_name': 'Riddell', 'given_name': 'Jeeves'},
#  {'family_name': 'Sinclair', 'given_name': 'Figaro'},
#  {'family_name': 'Macdougall', 'given_name': 'Brunton'},
#  {'family_name': 'Burnett', 'given_name': 'Brunton'},
#  {'family_name': 'Maclean', 'given_name': 'Merriman'},
#  {'family_name': 'Gunn', 'given_name': 'Figaro'},
#  {'family_name': 'Ramsay', 'given_name': 'Passepartout'},
#  {'family_name': 'Allen', 'given_name': 'Leporello'},
#  {'family_name': 'Buchanan', 'given_name': 'Merriman'},
#  {'family_name': 'Robertson', 'given_name': 'Leporello'},
#  {'family_name': 'Wheatley', 'given_name': 'Passepartout'},
#  {'family_name': 'Boyle', 'given_name': 'Simonides'},
#  {'family_name': 'Macnab', 'given_name': 'Barrymore'},
#  {'family_name': 'Akins', 'given_name': 'Passepartout'},
#  {'family_name': 'Irvine', 'given_name': 'Bullimore'},
#  {'family_name': 'Strange', 'given_name': 'Bullimore'},
#  {'family_name': 'Rose', 'given_name': 'Bullimore'},
#  {'family_name': 'Murdoch', 'given_name': 'Merriman'},
#  {'family_name': 'Chisholm', 'given_name': 'Bullimore'},
#  {'family_name': 'Rollo', 'given_name': 'Jeeves'},
#  {'family_name': 'Duncan', 'given_name': 'Poole'},
#  {'family_name': 'Lewis', 'given_name': 'Bullimore'},
#  {'family_name': 'Davidson', 'given_name': 'Jeeves'},
#  {'family_name': 'Scott', 'given_name': 'Cadbury'},
#  {'family_name': 'Kennedy', 'given_name': 'Jeeves'},
#  {'family_name': 'Allen', 'given_name': 'Leporello'},
#  {'family_name': 'Beckham', 'given_name': 'Alfred'},
#  {'family_name': 'Lough', 'given_name': 'Jeeves'},
#  {'family_name': 'Ross', 'given_name': 'Poole'},
#  {'family_name': 'Wallace', 'given_name': 'Merriman'},
#  {'family_name': 'Lough', 'given_name': 'Bullimore'},
#  {'family_name': 'Innes', 'given_name': 'Leporello'},
#  {'family_name': 'Charteris', 'given_name': 'Passepartout'},
#  {'family_name': 'Lough', 'given_name': 'Simonides'},
#  {'family_name': 'Mackenzie', 'given_name': 'Barkley'},
#  {'family_name': 'Cameron', 'given_name': 'Leporello'},
#  {'family_name': 'Stewart', 'given_name': 'Passepartout'},
#  {'family_name': 'Cameron', 'given_name': 'Belvedere'},
#  {'family_name': 'Leslie', 'given_name': 'Cadbury'},
#  {'family_name': 'Macnab', 'given_name': 'Cadbury'},
#  {'family_name': 'Harris', 'given_name': 'Barkley'},
#  {'family_name': 'Lamont', 'given_name': 'Poole'},
#  {'family_name': 'Buchanan', 'given_name': 'Jenkins'},
#  {'family_name': 'Ross', 'given_name': 'Passepartout'},
#  {'family_name': 'Lockhart', 'given_name': 'Simonides'},
#  {'family_name': 'Stuart', 'given_name': 'Bullimore'},
#  {'family_name': 'Boyle', 'given_name': 'Figaro'},
#  {'family_name': 'Malcolm', 'given_name': 'Barkley'},
#  {'family_name': 'Dunbar', 'given_name': 'Poole'},
#  {'family_name': 'Crichton', 'given_name': 'Bertuccio'},
#  {'family_name': 'Hamilton', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macdonnell', 'given_name': 'Alfred'},
#  {'family_name': 'Mackay', 'given_name': 'Jenkins'},
#  {'family_name': 'Wallace', 'given_name': 'Barrymore'},
#  {'family_name': 'Ross', 'given_name': 'Cadbury'},
#  {'family_name': 'Greg', 'given_name': 'Poole'},
#  {'family_name': 'Macdougall', 'given_name': 'Brunton'},
#  {'family_name': 'Fergusson', 'given_name': 'Merriman'},
#  {'family_name': 'Akins', 'given_name': 'Jeeves'},
#  {'family_name': 'Dunbar', 'given_name': 'Barrymore'},
#  {'family_name': 'Lewis', 'given_name': 'Barrymore'},
#  {'family_name': 'Murdoch', 'given_name': 'Brunton'},
#  {'family_name': 'Barclay', 'given_name': 'Belvedere'},
#  {'family_name': 'Crichton', 'given_name': 'Barrymore'},
#  {'family_name': 'Leslie', 'given_name': 'Bertuccio'},
#  {'family_name': 'Gunn', 'given_name': 'Bullimore'},
#  {'family_name': 'Campbell', 'given_name': 'Merriman'},
#  {'family_name': 'Haig', 'given_name': 'Figaro'},
#  {'family_name': 'Wood', 'given_name': 'Brunton'},
#  {'family_name': 'Macalister', 'given_name': 'Passepartout'},
#  {'family_name': 'Lennox', 'given_name': 'Merriman'},
#  {'family_name': 'Harris', 'given_name': 'Brunton'},
#  {'family_name': 'Carmichael', 'given_name': 'Brunton'},
#  {'family_name': 'Shaw', 'given_name': 'Leporello'},
#  {'family_name': 'Haldane', 'given_name': 'Cadbury'},
#  {'family_name': 'Gordon', 'given_name': 'Cadbury'},
#  {'family_name': 'Duncan', 'given_name': 'Jenkins'},
#  {'family_name': 'Douglas', 'given_name': 'Belvedere'},
#  {'family_name': 'Douglas', 'given_name': 'Brunton'},
#  {'family_name': 'Macdonnell', 'given_name': 'Simonides'},
#  {'family_name': 'Howard', 'given_name': 'Brunton'},
#  {'family_name': 'Allen', 'given_name': 'Jenkins'},
#  {'family_name': 'Hannay', 'given_name': 'Brunton'},
#  {'family_name': 'Ross', 'given_name': 'Figaro'},
#  {'family_name': 'Brodie', 'given_name': 'Simonides'},
#  {'family_name': 'Macnab', 'given_name': 'Merriman'},
#  {'family_name': 'Sterling', 'given_name': 'Bertuccio'},
#  {'family_name': 'Brown', 'given_name': 'Jeeves'},
#  {'family_name': 'Sutherland', 'given_name': 'Barkley'},
#  {'family_name': 'Brodie', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macneil', 'given_name': 'Bertuccio'},
#  {'family_name': 'Keith', 'given_name': 'Bullimore'},
#  {'family_name': 'Hope', 'given_name': 'Belvedere'},
#  {'family_name': 'Strange', 'given_name': 'Jeeves'},
#  {'family_name': 'Macfarlane', 'given_name': 'Alfred'},
#  {'family_name': 'Malcolm', 'given_name': 'Belvedere'},
#  {'family_name': 'Lindsay', 'given_name': 'Passepartout'},
#  {'family_name': 'Nicolson', 'given_name': 'Figaro'},
#  {'family_name': 'Hamilton', 'given_name': 'Belvedere'},
#  {'family_name': 'Spalding', 'given_name': 'Cadbury'},
#  {'family_name': 'Cunningham', 'given_name': 'Passepartout'},
#  {'family_name': 'Cumming', 'given_name': 'Leporello'},
#  {'family_name': 'Fleet', 'given_name': 'Passepartout'},
#  {'family_name': 'Livingstone', 'given_name': 'Figaro'},
#  {'family_name': 'Robertson', 'given_name': 'Jeeves'},
#  {'family_name': 'Dunbar', 'given_name': 'Brunton'},
#  {'family_name': 'Macleod', 'given_name': 'Figaro'},
#  {'family_name': 'Blair', 'given_name': 'Passepartout'},
#  {'family_name': 'Montgomery', 'given_name': 'Cadbury'},
#  {'family_name': 'Glengarry', 'given_name': 'Simonides'},
#  {'family_name': 'Dunbar', 'given_name': 'Cadbury'},
#  {'family_name': 'Cumming', 'given_name': 'Bullimore'},
#  {'family_name': 'Lewis', 'given_name': 'Passepartout'},
#  {'family_name': 'Gunn', 'given_name': 'Alfred'},
#  {'family_name': 'Hay', 'given_name': 'Cadbury'},
#  {'family_name': 'Sinclair', 'given_name': 'Bertuccio'},
#  {'family_name': 'Allen', 'given_name': 'Alfred'},
#  {'family_name': 'Watt', 'given_name': 'Cadbury'},
#  {'family_name': 'Dundas', 'given_name': 'Bertuccio'},
#  {'family_name': 'Kincaid', 'given_name': 'Merriman'},
#  {'family_name': 'Morr', 'given_name': 'Bullimore'},
#  {'family_name': 'Brodie', 'given_name': 'Passepartout'},
#  {'family_name': 'Watt', 'given_name': 'Alfred'},
#  {'family_name': 'Kerr', 'given_name': 'Poole'},
#  {'family_name': 'Maclean', 'given_name': 'Bertuccio'},
#  {'family_name': 'Dundas', 'given_name': 'Bullimore'},
#  {'family_name': 'Macintyre', 'given_name': 'Bertuccio'},
#  {'family_name': 'Lyon', 'given_name': 'Passepartout'},
#  {'family_name': 'Wood', 'given_name': 'Simonides'},
#  {'family_name': 'Kincaid', 'given_name': 'Cadbury'},
#  {'family_name': 'Kerr', 'given_name': 'Jenkins'},
#  {'family_name': 'Lamont', 'given_name': 'Brunton'},
#  {'family_name': 'Rose', 'given_name': 'Bertuccio'},
#  {'family_name': 'Sinclair', 'given_name': 'Cadbury'},
#  {'family_name': 'Primrose', 'given_name': 'Jeeves'},
#  {'family_name': 'Watt', 'given_name': 'Jenkins'},
#  {'family_name': 'Gunn', 'given_name': 'Figaro'},
#  {'family_name': 'Macarthur', 'given_name': 'Jenkins'},
#  {'family_name': 'Murray', 'given_name': 'Barkley'},
#  {'family_name': 'Wheatley', 'given_name': 'Passepartout'},
#  {'family_name': 'Forrester', 'given_name': 'Leporello'},
#  {'family_name': 'Lindsay', 'given_name': 'Poole'},
#  {'family_name': 'Duncan', 'given_name': 'Cadbury'},
#  {'family_name': 'Montgomery', 'given_name': 'Jenkins'},
#  {'family_name': 'Fergusson', 'given_name': 'Passepartout'},
#  {'family_name': 'Baird', 'given_name': 'Jeeves'},
#  {'family_name': 'Forsyth', 'given_name': 'Poole'},
#  {'family_name': 'Napier', 'given_name': 'Figaro'},
#  {'family_name': 'Akins', 'given_name': 'Jenkins'},
#  {'family_name': 'Rose', 'given_name': 'Leporello'},
#  {'family_name': 'Grant', 'given_name': 'Jenkins'},
#  {'family_name': 'Henry', 'given_name': 'Brunton'},
#  {'family_name': 'Maclaren', 'given_name': 'Bullimore'},
#  {'family_name': 'Hay', 'given_name': 'Merriman'},
#  {'family_name': 'Macalister', 'given_name': 'Belvedere'},
#  {'family_name': 'Carnegie', 'given_name': 'Belvedere'},
#  {'family_name': 'Lennox', 'given_name': 'Barkley'},
#  {'family_name': 'Chattan', 'given_name': 'Bullimore'},
#  {'family_name': 'Ross', 'given_name': 'Bertuccio'},
#  {'family_name': 'Chisholm', 'given_name': 'Poole'},
#  {'family_name': 'Harris', 'given_name': 'Jenkins'},
#  {'family_name': 'Macmillan', 'given_name': 'Belvedere'},
#  {'family_name': 'Keen', 'given_name': 'Passepartout'},
#  {'family_name': 'Lennox', 'given_name': 'Cadbury'},
#  {'family_name': 'Douglas', 'given_name': 'Belvedere'},
#  {'family_name': 'Mackenzie', 'given_name': 'Merriman'},
#  {'family_name': 'Blair', 'given_name': 'Poole'},
#  {'family_name': 'Crichton', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macdonald', 'given_name': 'Jenkins'},
#  {'family_name': 'Sterling', 'given_name': 'Belvedere'},
#  {'family_name': 'Macalister', 'given_name': 'Barkley'},
#  {'family_name': 'Grant', 'given_name': 'Alfred'},
#  {'family_name': 'Macdougall', 'given_name': 'Barrymore'},
#  {'family_name': 'Brown', 'given_name': 'Passepartout'},
#  {'family_name': 'Sinclair', 'given_name': 'Simonides'},
#  {'family_name': 'Oliphant', 'given_name': 'Alfred'},
#  {'family_name': 'Drummond', 'given_name': 'Merriman'},
#  {'family_name': 'Maclean', 'given_name': 'Merriman'},
#  {'family_name': 'Henderson', 'given_name': 'Poole'},
#  {'family_name': 'Macduff', 'given_name': 'Merriman'},
#  {'family_name': 'Montgomery', 'given_name': 'Brunton'},
#  {'family_name': 'Sterling', 'given_name': 'Belvedere'},
#  {'family_name': 'Davidson', 'given_name': 'Brunton'},
#  {'family_name': 'Lough', 'given_name': 'Bertuccio'},
#  {'family_name': 'Campbell', 'given_name': 'Figaro'},
#  {'family_name': 'Fleming', 'given_name': 'Alfred'},
#  {'family_name': 'Fleming', 'given_name': 'Passepartout'},
#  {'family_name': 'Haig', 'given_name': 'Barkley'},
#  {'family_name': 'Macdougall', 'given_name': 'Alfred'},
#  {'family_name': 'Duncan', 'given_name': 'Alfred'},
#  {'family_name': 'Forbes', 'given_name': 'Bullimore'},
#  {'family_name': 'Morr', 'given_name': 'Passepartout'},
#  {'family_name': 'Montgomery', 'given_name': 'Barrymore'},
#  {'family_name': 'Henderson', 'given_name': 'Simonides'},
#  {'family_name': 'Cumming', 'given_name': 'Jenkins'},
#  {'family_name': 'Jardine', 'given_name': 'Jenkins'},
#  {'family_name': 'Blair', 'given_name': 'Belvedere'},
#  {'family_name': 'Creel', 'given_name': 'Leporello'},
#  {'family_name': 'Macneil', 'given_name': 'Poole'},
#  {'family_name': 'Maclaren', 'given_name': 'Barrymore'},
#  {'family_name': 'Moffat', 'given_name': 'Belvedere'},
#  {'family_name': 'Elliott', 'given_name': 'Figaro'},
#  {'family_name': 'Creel', 'given_name': 'Jenkins'},
#  {'family_name': 'Moffat', 'given_name': 'Barkley'},
#  {'family_name': 'Douglas', 'given_name': 'Bertuccio'},
#  {'family_name': 'Nicolson', 'given_name': 'Barrymore'},
#  {'family_name': 'Oliphant', 'given_name': 'Belvedere'},
#  {'family_name': 'Chattan', 'given_name': 'Brunton'},
#  {'family_name': 'Boyd', 'given_name': 'Simonides'},
#  {'family_name': 'Wallace', 'given_name': 'Bullimore'},
#  {'family_name': 'Dunbar', 'given_name': 'Belvedere'},
#  {'family_name': 'Dewar', 'given_name': 'Barrymore'},
#  {'family_name': 'Dunbar', 'given_name': 'Barrymore'},
#  {'family_name': 'Cumming', 'given_name': 'Passepartout'},
#  {'family_name': 'Donald', 'given_name': 'Belvedere'},
#  {'family_name': 'Moffat', 'given_name': 'Brunton'},
#  {'family_name': 'Duncan', 'given_name': 'Figaro'},
#  {'family_name': 'Allen', 'given_name': 'Belvedere'},
#  {'family_name': 'Macnab', 'given_name': 'Cadbury'},
#  {'family_name': 'Mackay', 'given_name': 'Bullimore'},
#  {'family_name': 'Blair', 'given_name': 'Alfred'},
#  {'family_name': 'Watt', 'given_name': 'Bullimore'},
#  {'family_name': 'Gordon', 'given_name': 'Bullimore'},
#  {'family_name': 'Leslie', 'given_name': 'Merriman'},
#  {'family_name': 'Wood', 'given_name': 'Simonides'},
#  {'family_name': 'Burnett', 'given_name': 'Merriman'},
#  {'family_name': 'Kincaid', 'given_name': 'Figaro'},
#  {'family_name': 'Stuart', 'given_name': 'Jenkins'},
#  {'family_name': 'Creel', 'given_name': 'Poole'},
#  {'family_name': 'Carnegie', 'given_name': 'Merriman'},
#  {'family_name': 'Spalding', 'given_name': 'Poole'},
#  {'family_name': 'Russell', 'given_name': 'Belvedere'},
#  {'family_name': 'Post', 'given_name': 'Merriman'},
#  {'family_name': 'Akins', 'given_name': 'Bullimore'},
#  {'family_name': 'Armstrong', 'given_name': 'Barkley'},
#  {'family_name': 'Fleet', 'given_name': 'Barkley'},
#  {'family_name': 'Fergusson', 'given_name': 'Passepartout'},
#  {'family_name': 'Morr', 'given_name': 'Alfred'},
#  {'family_name': 'Napier', 'given_name': 'Cadbury'},
#  {'family_name': 'Grierson', 'given_name': 'Barrymore'},
#  {'family_name': 'Hannay', 'given_name': 'Figaro'},
#  {'family_name': 'Boyle', 'given_name': 'Jenkins'},
#  {'family_name': 'Munro', 'given_name': 'Passepartout'},
#  {'family_name': 'Munro', 'given_name': 'Cadbury'},
#  {'family_name': 'Cumming', 'given_name': 'Bullimore'},
#  {'family_name': 'Allen', 'given_name': 'Barkley'},
#  {'family_name': 'Munro', 'given_name': 'Jeeves'},
#  {'family_name': 'Keen', 'given_name': 'Bertuccio'},
#  {'family_name': 'Post', 'given_name': 'Leporello'},
#  {'family_name': 'Chisholm', 'given_name': 'Cadbury'},
#  {'family_name': 'Dunbar', 'given_name': 'Alfred'},
#  {'family_name': 'Lindsay', 'given_name': 'Barkley'},
#  {'family_name': 'Napier', 'given_name': 'Merriman'},
#  {'family_name': 'Robertson', 'given_name': 'Merriman'},
#  {'family_name': 'Napier', 'given_name': 'Simonides'},
#  {'family_name': 'Cumming', 'given_name': 'Brunton'},
#  {'family_name': 'Post', 'given_name': 'Passepartout'},
#  {'family_name': 'Mackay', 'given_name': 'Jenkins'},
#  {'family_name': 'Campbell', 'given_name': 'Passepartout'},
#  {'family_name': 'Grant', 'given_name': 'Passepartout'},
#  {'family_name': 'Keen', 'given_name': 'Jeeves'},
#  {'family_name': 'Spalding', 'given_name': 'Passepartout'},
#  {'family_name': 'Armstrong', 'given_name': 'Bullimore'},
#  {'family_name': 'Cameron', 'given_name': 'Cadbury'},
#  {'family_name': 'Armstrong', 'given_name': 'Belvedere'},
#  {'family_name': 'Cumming', 'given_name': 'Jeeves'},
#  {'family_name': 'Post', 'given_name': 'Merriman'},
#  {'family_name': 'Lindsay', 'given_name': 'Cadbury'},
#  {'family_name': 'Fleet', 'given_name': 'Bullimore'},
#  {'family_name': 'Napier', 'given_name': 'Barkley'},
#  {'family_name': 'Rose', 'given_name': 'Barkley'},
#  {'family_name': 'Stewart', 'given_name': 'Jenkins'},
#  {'family_name': 'Forbes', 'given_name': 'Bullimore'},
#  {'family_name': 'Robertson', 'given_name': 'Passepartout'},
#  {'family_name': 'Anderson', 'given_name': 'Passepartout'},
#  {'family_name': 'Montgomery', 'given_name': 'Jenkins'},
#  {'family_name': 'Mair', 'given_name': 'Belvedere'},
#  {'family_name': 'Stuart', 'given_name': 'Passepartout'},
#  {'family_name': 'Maclean', 'given_name': 'Simonides'},
#  {'family_name': 'Grant', 'given_name': 'Bertuccio'},
#  {'family_name': 'Lockhart', 'given_name': 'Belvedere'},
#  {'family_name': 'Haig', 'given_name': 'Leporello'},
#  {'family_name': 'Drummond', 'given_name': 'Poole'},
#  {'family_name': 'Irvine', 'given_name': 'Bullimore'},
#  {'family_name': 'Strange', 'given_name': 'Bullimore'},
#  {'family_name': 'Beckham', 'given_name': 'Bullimore'},
#  {'family_name': 'Stewart', 'given_name': 'Alfred'},
#  {'family_name': 'Primrose', 'given_name': 'Belvedere'},
#  {'family_name': 'Mackay', 'given_name': 'Belvedere'},
#  {'family_name': 'Sutherland', 'given_name': 'Figaro'},
#  {'family_name': 'Grant', 'given_name': 'Merriman'},
#  {'family_name': 'Chisholm', 'given_name': 'Belvedere'},
#  {'family_name': 'Kennedy', 'given_name': 'Belvedere'},
#  {'family_name': 'Fleming', 'given_name': 'Leporello'},
#  {'family_name': 'Montgomery', 'given_name': 'Merriman'},
#  {'family_name': 'Sterling', 'given_name': 'Poole'},
#  {'family_name': 'Kerr', 'given_name': 'Bertuccio'},
#  {'family_name': 'Dunbar', 'given_name': 'Simonides'},
#  {'family_name': 'Matheson', 'given_name': 'Bertuccio'},
#  {'family_name': 'Murray', 'given_name': 'Barkley'},
#  {'family_name': 'Gunn', 'given_name': 'Merriman'},
#  {'family_name': 'Sinclair', 'given_name': 'Merriman'},
#  {'family_name': 'Sinclair', 'given_name': 'Jenkins'},
#  {'family_name': 'Oliphant', 'given_name': 'Barrymore'},
#  {'family_name': 'Ogilvy', 'given_name': 'Brunton'},
#  {'family_name': 'Baird', 'given_name': 'Cadbury'},
#  {'family_name': 'Duncan', 'given_name': 'Jeeves'},
#  {'family_name': 'Sterling', 'given_name': 'Figaro'},
#  {'family_name': 'Wood', 'given_name': 'Jeeves'},
#  {'family_name': 'Chisholm', 'given_name': 'Simonides'},
#  {'family_name': 'Cunningham', 'given_name': 'Passepartout'},
#  {'family_name': 'Macauley', 'given_name': 'Jenkins'},
#  {'family_name': 'Kerr', 'given_name': 'Bullimore'},
#  {'family_name': 'Moffat', 'given_name': 'Belvedere'},
#  {'family_name': 'Lewis', 'given_name': 'Belvedere'},
#  {'family_name': 'Lewis', 'given_name': 'Barkley'},
#  {'family_name': 'Davidson', 'given_name': 'Bullimore'},
#  {'family_name': 'Lyon', 'given_name': 'Alfred'},
#  {'family_name': 'Hamilton', 'given_name': 'Jenkins'},
#  {'family_name': 'Keen', 'given_name': 'Barkley'},
#  {'family_name': 'Boyle', 'given_name': 'Cadbury'},
#  {'family_name': 'Kerr', 'given_name': 'Alfred'},
#  {'family_name': 'Napier', 'given_name': 'Bertuccio'},
#  {'family_name': 'Mair', 'given_name': 'Bertuccio'},
#  {'family_name': 'Hay', 'given_name': 'Jenkins'},
#  {'family_name': 'Livingstone', 'given_name': 'Simonides'},
#  {'family_name': 'Sterling', 'given_name': 'Belvedere'},
#  {'family_name': 'Lennox', 'given_name': 'Barrymore'},
#  {'family_name': 'Wheatley', 'given_name': 'Passepartout'},
#  {'family_name': 'Brodie', 'given_name': 'Jeeves'},
#  {'family_name': 'Henderson', 'given_name': 'Merriman'},
#  {'family_name': 'Macalister', 'given_name': 'Figaro'},
#  {'family_name': 'Macneil', 'given_name': 'Barkley'},
#  {'family_name': 'Hunter', 'given_name': 'Bullimore'},
#  {'family_name': 'Baird', 'given_name': 'Barkley'},
#  {'family_name': 'Macarthur', 'given_name': 'Jenkins'},
#  {'family_name': 'Riddell', 'given_name': 'Alfred'},
#  {'family_name': 'Macintyre', 'given_name': 'Leporello'},
#  {'family_name': 'Beckham', 'given_name': 'Jenkins'},
#  {'family_name': 'Lyon', 'given_name': 'Passepartout'},
#  {'family_name': 'Anderson', 'given_name': 'Barkley'},
#  {'family_name': 'Macduff', 'given_name': 'Simonides'},
#  {'family_name': 'Haig', 'given_name': 'Jenkins'},
#  {'family_name': 'Sterling', 'given_name': 'Alfred'},
#  {'family_name': 'Sutherland', 'given_name': 'Cadbury'},
#  {'family_name': 'Murray', 'given_name': 'Barrymore'},
#  {'family_name': 'Livingstone', 'given_name': 'Leporello'},
#  {'family_name': 'Macauley', 'given_name': 'Jeeves'},
#  {'family_name': 'Hannay', 'given_name': 'Alfred'},
#  {'family_name': 'Wallace', 'given_name': 'Belvedere'},
#  {'family_name': 'Brown', 'given_name': 'Simonides'},
#  {'family_name': 'Macpherson', 'given_name': 'Alfred'},
#  {'family_name': 'Sterling', 'given_name': 'Alfred'},
#  {'family_name': 'Finlay', 'given_name': 'Poole'},
#  {'family_name': 'Haig', 'given_name': 'Cadbury'},
#  {'family_name': 'Scott', 'given_name': 'Belvedere'},
#  {'family_name': 'Livingstone', 'given_name': 'Cadbury'},
#  {'family_name': 'Shaw', 'given_name': 'Merriman'},
#  {'family_name': 'Lewis', 'given_name': 'Jeeves'},
#  {'family_name': 'Boyd', 'given_name': 'Belvedere'},
#  {'family_name': 'Fleet', 'given_name': 'Poole'},
#  {'family_name': 'Macmillan', 'given_name': 'Merriman'},
#  {'family_name': 'Baird', 'given_name': 'Jeeves'},
#  {'family_name': 'Macpherson', 'given_name': 'Barrymore'},
#  {'family_name': 'Cameron', 'given_name': 'Bullimore'},
#  {'family_name': 'Malcolm', 'given_name': 'Brunton'},
#  {'family_name': 'Henderson', 'given_name': 'Jeeves'},
#  {'family_name': 'Dunbar', 'given_name': 'Jeeves'},
#  {'family_name': 'Lindsay', 'given_name': 'Barrymore'},
#  {'family_name': 'Sinclair', 'given_name': 'Bullimore'},
#  {'family_name': 'Chisholm', 'given_name': 'Figaro'},
#  {'family_name': 'Scott', 'given_name': 'Jeeves'},
#  {'family_name': 'Dewar', 'given_name': 'Leporello'},
#  {'family_name': 'Lyon', 'given_name': 'Alfred'},
#  {'family_name': 'Morr', 'given_name': 'Barrymore'},
#  {'family_name': 'Wheatley', 'given_name': 'Brunton'},
#  {'family_name': 'Duncan', 'given_name': 'Cadbury'},
#  {'family_name': 'Akins', 'given_name': 'Leporello'},
#  {'family_name': 'Dundas', 'given_name': 'Barkley'},
#  {'family_name': 'Brown', 'given_name': 'Barkley'},
#  {'family_name': 'Wheatley', 'given_name': 'Merriman'},
#  {'family_name': 'Oliphant', 'given_name': 'Jeeves'},
#  {'family_name': 'Haig', 'given_name': 'Brunton'},
#  {'family_name': 'Dunbar', 'given_name': 'Bullimore'},
#  {'family_name': 'Cumming', 'given_name': 'Poole'},
#  {'family_name': 'Fleet', 'given_name': 'Barrymore'},
#  {'family_name': 'Buchanan', 'given_name': 'Jenkins'},
#  {'family_name': 'Cameron', 'given_name': 'Alfred'},
#  {'family_name': 'Duncan', 'given_name': 'Jeeves'},
#  {'family_name': 'Crichton', 'given_name': 'Passepartout'},
#  {'family_name': 'Davidson', 'given_name': 'Barrymore'},
#  {'family_name': 'Baird', 'given_name': 'Leporello'},
#  {'family_name': 'Spalding', 'given_name': 'Belvedere'},
#  {'family_name': 'Sutherland', 'given_name': 'Leporello'},
#  {'family_name': 'Macpherson', 'given_name': 'Bertuccio'},
#  {'family_name': 'Cunningham', 'given_name': 'Barkley'},
#  {'family_name': 'Hay', 'given_name': 'Jeeves'},
#  {'family_name': 'Greg', 'given_name': 'Belvedere'},
#  {'family_name': 'Moffat', 'given_name': 'Brunton'},
#  {'family_name': 'Stuart', 'given_name': 'Cadbury'},
#  {'family_name': 'Wallace', 'given_name': 'Poole'},
#  {'family_name': 'Cochrane', 'given_name': 'Passepartout'},
#  {'family_name': 'Hunter', 'given_name': 'Brunton'},
#  {'family_name': 'Macduff', 'given_name': 'Bullimore'},
#  {'family_name': 'Ramsay', 'given_name': 'Simonides'},
#  {'family_name': 'Cochrane', 'given_name': 'Belvedere'},
#  {'family_name': 'Leslie', 'given_name': 'Bullimore'},
#  {'family_name': 'Spalding', 'given_name': 'Brunton'},
#  {'family_name': 'Mackay', 'given_name': 'Jeeves'},
#  {'family_name': 'Forrester', 'given_name': 'Alfred'},
#  {'family_name': 'Crichton', 'given_name': 'Jenkins'},
#  {'family_name': 'Ramsay', 'given_name': 'Jenkins'},
#  {'family_name': 'Shaw', 'given_name': 'Barkley'},
#  {'family_name': 'Macpherson', 'given_name': 'Passepartout'},
#  {'family_name': 'Forrester', 'given_name': 'Leporello'},
#  {'family_name': 'Macpherson', 'given_name': 'Jeeves'},
#  {'family_name': 'Allen', 'given_name': 'Leporello'},
#  {'family_name': 'Brown', 'given_name': 'Merriman'},
#  {'family_name': 'Guthrie', 'given_name': 'Leporello'},
#  {'family_name': 'Guthrie', 'given_name': 'Leporello'},
#  {'family_name': 'Macpherson', 'given_name': 'Bullimore'},
#  {'family_name': 'Hannay', 'given_name': 'Cadbury'},
#  {'family_name': 'Boyd', 'given_name': 'Brunton'},
#  {'family_name': 'Macdougall', 'given_name': 'Belvedere'},
#  {'family_name': 'Boyd', 'given_name': 'Jenkins'},
#  {'family_name': 'Carnegie', 'given_name': 'Passepartout'},
#  {'family_name': 'Mair', 'given_name': 'Barkley'},
#  {'family_name': 'Lyon', 'given_name': 'Poole'},
#  {'family_name': 'Mackenzie', 'given_name': 'Barkley'},
#  {'family_name': 'Russell', 'given_name': 'Belvedere'},
#  {'family_name': 'Rose', 'given_name': 'Passepartout'},
#  {'family_name': 'Gunn', 'given_name': 'Alfred'},
#  {'family_name': 'Mcmullen', 'given_name': 'Alfred'},
#  {'family_name': 'Spalding', 'given_name': 'Belvedere'},
#  {'family_name': 'Macintyre', 'given_name': 'Jenkins'},
#  {'family_name': 'Strange', 'given_name': 'Simonides'},
#  {'family_name': 'Macintyre', 'given_name': 'Figaro'},
#  {'family_name': 'Scott', 'given_name': 'Bullimore'},
#  {'family_name': 'Lough', 'given_name': 'Jeeves'},
#  {'family_name': 'Kennedy', 'given_name': 'Bullimore'},
#  {'family_name': 'Lennox', 'given_name': 'Brunton'},
#  {'family_name': 'Kerr', 'given_name': 'Leporello'},
#  {'family_name': 'Scott', 'given_name': 'Jenkins'},
#  {'family_name': 'Creel', 'given_name': 'Belvedere'},
#  {'family_name': 'Agnew', 'given_name': 'Bertuccio'},
#  {'family_name': 'Hannay', 'given_name': 'Leporello'},
#  {'family_name': 'Burnett', 'given_name': 'Alfred'},
#  {'family_name': 'Carnegie', 'given_name': 'Passepartout'},
#  {'family_name': 'Lockhart', 'given_name': 'Passepartout'},
#  {'family_name': 'Macintyre', 'given_name': 'Simonides'},
#  {'family_name': 'Macarthur', 'given_name': 'Cadbury'},
#  {'family_name': 'Forsyth', 'given_name': 'Merriman'},
#  {'family_name': 'Fergusson', 'given_name': 'Barkley'},
#  {'family_name': 'Haldane', 'given_name': 'Barrymore'},
#  {'family_name': 'Macarthur', 'given_name': 'Bullimore'},
#  {'family_name': 'Fraser', 'given_name': 'Leporello'},
#  {'family_name': 'Russell', 'given_name': 'Bullimore'},
#  {'family_name': 'Becker', 'given_name': 'Brunton'},
#  {'family_name': 'Graham', 'given_name': 'Barkley'},
#  {'family_name': 'Lewis', 'given_name': 'Bullimore'},
#  {'family_name': 'Macdonnell', 'given_name': 'Bertuccio'},
#  {'family_name': 'Robertson', 'given_name': 'Barkley'},
#  {'family_name': 'Henderson', 'given_name': 'Barkley'},
#  {'family_name': 'Sutherland', 'given_name': 'Cadbury'},
#  {'family_name': 'Grierson', 'given_name': 'Barrymore'},
#  {'family_name': 'Munro', 'given_name': 'Barrymore'},
#  {'family_name': 'Montgomery', 'given_name': 'Cadbury'},
#  {'family_name': 'Wood', 'given_name': 'Jenkins'},
#  {'family_name': 'Baird', 'given_name': 'Leporello'},
#  {'family_name': 'Munro', 'given_name': 'Leporello'},
#  {'family_name': 'Watt', 'given_name': 'Barrymore'},
#  {'family_name': 'Henry', 'given_name': 'Figaro'},
#  {'family_name': 'Robertson', 'given_name': 'Merriman'},
#  {'family_name': 'Cunningham', 'given_name': 'Poole'},
#  {'family_name': 'Wheatley', 'given_name': 'Figaro'},
#  {'family_name': 'Fraser', 'given_name': 'Poole'},
#  {'family_name': 'Mair', 'given_name': 'Jenkins'},
#  {'family_name': 'Fergusson', 'given_name': 'Bullimore'},
#  {'family_name': 'Sutherland', 'given_name': 'Jeeves'},
#  {'family_name': 'Becker', 'given_name': 'Alfred'},
#  {'family_name': 'Macnab', 'given_name': 'Simonides'},
#  {'family_name': 'Chisholm', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macdougall', 'given_name': 'Alfred'},
#  {'family_name': 'Elliott', 'given_name': 'Alfred'},
#  {'family_name': 'Rose', 'given_name': 'Brunton'},
#  {'family_name': 'Stewart', 'given_name': 'Bullimore'},
#  {'family_name': 'Barclay', 'given_name': 'Simonides'},
#  {'family_name': 'Primrose', 'given_name': 'Poole'},
#  {'family_name': 'Grant', 'given_name': 'Leporello'},
#  {'family_name': 'Stewart', 'given_name': 'Alfred'},
#  {'family_name': 'Boyd', 'given_name': 'Barkley'},
#  {'family_name': 'Montgomery', 'given_name': 'Bertuccio'},
#  {'family_name': 'Irvine', 'given_name': 'Passepartout'},
#  {'family_name': 'Fleming', 'given_name': 'Cadbury'},
#  {'family_name': 'Macneil', 'given_name': 'Bullimore'},
#  {'family_name': 'Nicolson', 'given_name': 'Bertuccio'},
#  {'family_name': 'Haldane', 'given_name': 'Jeeves'},
#  {'family_name': 'Cunningham', 'given_name': 'Alfred'},
#  {'family_name': 'Cochrane', 'given_name': 'Barrymore'},
#  {'family_name': 'Irvine', 'given_name': 'Jenkins'},
#  {'family_name': 'Murdoch', 'given_name': 'Barkley'},
#  {'family_name': 'Mair', 'given_name': 'Barkley'},
#  {'family_name': 'Lindsay', 'given_name': 'Bertuccio'},
#  {'family_name': 'Burnett', 'given_name': 'Simonides'},
#  {'family_name': 'Macdonnell', 'given_name': 'Alfred'},
#  {'family_name': 'Malcolm', 'given_name': 'Bullimore'},
#  {'family_name': 'Duncan', 'given_name': 'Bullimore'},
#  {'family_name': 'Macdougall', 'given_name': 'Cadbury'},
#  {'family_name': 'Hamilton', 'given_name': 'Alfred'},
#  {'family_name': 'Robertson', 'given_name': 'Passepartout'},
#  {'family_name': 'Macnab', 'given_name': 'Barkley'},
#  {'family_name': 'Forsyth', 'given_name': 'Leporello'},
#  {'family_name': 'Mackenzie', 'given_name': 'Bertuccio'},
#  {'family_name': 'Charteris', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macarthur', 'given_name': 'Leporello'},
#  {'family_name': 'Wheatley', 'given_name': 'Simonides'},
#  {'family_name': 'Dundas', 'given_name': 'Bullimore'},
#  {'family_name': 'Graham', 'given_name': 'Bertuccio'},
#  {'family_name': 'Leslie', 'given_name': 'Simonides'},
#  {'family_name': 'Napier', 'given_name': 'Poole'},
#  {'family_name': 'Hamilton', 'given_name': 'Bertuccio'},
#  {'family_name': 'Mcmullen', 'given_name': 'Jenkins'},
#  {'family_name': 'Macpherson', 'given_name': 'Brunton'},
#  {'family_name': 'Keen', 'given_name': 'Figaro'},
#  {'family_name': 'Howard', 'given_name': 'Figaro'},
#  {'family_name': 'Lyon', 'given_name': 'Barkley'},
#  {'family_name': 'Mackay', 'given_name': 'Merriman'},
#  {'family_name': 'Burnett', 'given_name': 'Leporello'},
#  {'family_name': 'Burnett', 'given_name': 'Alfred'},
#  {'family_name': 'Macneil', 'given_name': 'Poole'},
#  {'family_name': 'Mackay', 'given_name': 'Cadbury'},
#  {'family_name': 'Bruce', 'given_name': 'Brunton'},
#  {'family_name': 'Forsyth', 'given_name': 'Belvedere'},
#  {'family_name': 'Keith', 'given_name': 'Jeeves'},
#  {'family_name': 'Cochrane', 'given_name': 'Barkley'},
#  {'family_name': 'Carmichael', 'given_name': 'Leporello'},
#  {'family_name': 'Leslie', 'given_name': 'Brunton'},
#  {'family_name': 'Brown', 'given_name': 'Leporello'},
#  {'family_name': 'Mair', 'given_name': 'Cadbury'},
#  {'family_name': 'Fergusson', 'given_name': 'Merriman'},
#  {'family_name': 'Ramsay', 'given_name': 'Figaro'},
#  {'family_name': 'Duncan', 'given_name': 'Poole'},
#  {'family_name': 'Lindsay', 'given_name': 'Leporello'},
#  {'family_name': 'Stuart', 'given_name': 'Poole'},
#  {'family_name': 'Napier', 'given_name': 'Figaro'},
#  {'family_name': 'Macdonnell', 'given_name': 'Simonides'},
#  {'family_name': 'Lamont', 'given_name': 'Poole'},
#  {'family_name': 'Mackenzie', 'given_name': 'Leporello'},
#  {'family_name': 'Hannay', 'given_name': 'Brunton'},
#  {'family_name': 'Macfarlane', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macneil', 'given_name': 'Barkley'},
#  {'family_name': 'Cameron', 'given_name': 'Barkley'},
#  {'family_name': 'Macneil', 'given_name': 'Jenkins'},
#  {'family_name': 'Armstrong', 'given_name': 'Simonides'},
#  {'family_name': 'Ramsay', 'given_name': 'Barkley'},
#  {'family_name': 'Haldane', 'given_name': 'Figaro'},
#  {'family_name': 'Hamilton', 'given_name': 'Cadbury'},
#  {'family_name': 'Munro', 'given_name': 'Bullimore'},
#  {'family_name': 'Macarthur', 'given_name': 'Barkley'},
#  {'family_name': 'Armstrong', 'given_name': 'Jenkins'},
#  {'family_name': 'Matheson', 'given_name': 'Merriman'},
#  {'family_name': 'Grant', 'given_name': 'Merriman'},
#  {'family_name': 'Macnab', 'given_name': 'Jenkins'},
#  {'family_name': 'Douglas', 'given_name': 'Jenkins'},
#  {'family_name': 'Fleet', 'given_name': 'Passepartout'},
#  {'family_name': 'Colville', 'given_name': 'Merriman'},
#  {'family_name': 'Forbes', 'given_name': 'Bertuccio'},
#  {'family_name': 'Bruce', 'given_name': 'Barkley'},
#  {'family_name': 'Gunn', 'given_name': 'Figaro'},
#  {'family_name': 'Brodie', 'given_name': 'Simonides'},
#  {'family_name': 'Russell', 'given_name': 'Merriman'},
#  {'family_name': 'Moffat', 'given_name': 'Cadbury'},
#  {'family_name': 'Forsyth', 'given_name': 'Leporello'},
#  {'family_name': 'Moffat', 'given_name': 'Jeeves'},
#  {'family_name': 'Davidson', 'given_name': 'Barrymore'},
#  {'family_name': 'Macnab', 'given_name': 'Poole'},
#  {'family_name': 'Macdonnell', 'given_name': 'Alfred'},
#  {'family_name': 'Shaw', 'given_name': 'Jeeves'},
#  {'family_name': 'Mackay', 'given_name': 'Cadbury'},
#  {'family_name': 'Lyon', 'given_name': 'Brunton'},
#  {'family_name': 'Moffat', 'given_name': 'Bullimore'},
#  {'family_name': 'Stewart', 'given_name': 'Passepartout'},
#  {'family_name': 'Dunbar', 'given_name': 'Jeeves'},
#  {'family_name': 'Macneil', 'given_name': 'Barrymore'},
#  {'family_name': 'Grant', 'given_name': 'Merriman'},
#  {'family_name': 'Chattan', 'given_name': 'Passepartout'},
#  {'family_name': 'Keith', 'given_name': 'Barrymore'},
#  {'family_name': 'Henry', 'given_name': 'Barrymore'},
#  {'family_name': 'Anderson', 'given_name': 'Merriman'},
#  {'family_name': 'Carmichael', 'given_name': 'Bertuccio'},
#  {'family_name': 'Finlay', 'given_name': 'Merriman'},
#  {'family_name': 'Macarthur', 'given_name': 'Passepartout'},
#  {'family_name': 'Stewart', 'given_name': 'Passepartout'},
#  {'family_name': 'Hunter', 'given_name': 'Belvedere'},
#  {'family_name': 'Baird', 'given_name': 'Poole'},
#  {'family_name': 'Kerr', 'given_name': 'Jenkins'},
#  {'family_name': 'Innes', 'given_name': 'Jeeves'},
#  {'family_name': 'Akins', 'given_name': 'Bertuccio'},
#  {'family_name': 'Strange', 'given_name': 'Jenkins'},
#  {'family_name': 'Henry', 'given_name': 'Bertuccio'},
#  {'family_name': 'Sutherland', 'given_name': 'Figaro'},
#  {'family_name': 'Ramsay', 'given_name': 'Barkley'},
#  {'family_name': 'Charteris', 'given_name': 'Bertuccio'},
#  {'family_name': 'Macleod', 'given_name': 'Alfred'},
#  {'family_name': 'Macauley', 'given_name': 'Barkley'},
#  {'family_name': 'Henry', 'given_name': 'Barrymore'},
#  {'family_name': 'Ross', 'given_name': 'Barrymore'},
#  {'family_name': 'Matheson', 'given_name': 'Bullimore'},
#  {'family_name': 'Nesbitt', 'given_name': 'Cadbury'},
#  {'family_name': 'Sutherland', 'given_name': 'Barkley'},
#  {'family_name': 'Agnew', 'given_name': 'Simonides'},
#  {'family_name': 'Montgomery', 'given_name': 'Jeeves'},
#  {'family_name': 'Lockhart', 'given_name': 'Bullimore'},
#  {'family_name': 'Sterling', 'given_name': 'Cadbury'},
#  {'family_name': 'Macfarlane', 'given_name': 'Cadbury'},
#  {'family_name': 'Stewart', 'given_name': 'Alfred'},
#  {'family_name': 'Strange', 'given_name': 'Figaro'},
#  {'family_name': 'Murdoch', 'given_name': 'Passepartout'},
#  {'family_name': 'Cochrane', 'given_name': 'Bertuccio'},
#  {'family_name': 'Graham', 'given_name': 'Jenkins'},
#  {'family_name': 'Agnew', 'given_name': 'Simonides'},
#  {'family_name': 'Riddell', 'given_name': 'Belvedere'},
#  {'family_name': 'Murdoch', 'given_name': 'Brunton'},
#  {'family_name': 'Cunningham', 'given_name': 'Alfred'},
#  {'family_name': 'Boyd', 'given_name': 'Leporello'},
#  {'family_name': 'Keen', 'given_name': 'Jeeves'},
#  {'family_name': 'Mcmullen', 'given_name': 'Jenkins'},
#  {'family_name': 'Macdonnell', 'given_name': 'Simonides'},
#  {'family_name': 'Gordon', 'given_name': 'Bertuccio'},
#  {'family_name': 'Boyd', 'given_name': 'Cadbury'},
#  {'family_name': 'Sutherland', 'given_name': 'Leporello'},
#  {'family_name': 'Henry', 'given_name': 'Jeeves'},
#  {'family_name': 'Keen', 'given_name': 'Jeeves'},
#  {'family_name': 'Ogilvy', 'given_name': 'Passepartout'},
#  {'family_name': 'Hannay', 'given_name': 'Passepartout'},
#  {'family_name': 'Elliott', 'given_name': 'Brunton'},
#  {'family_name': 'Watt', 'given_name': 'Poole'},
#  {'family_name': 'Fraser', 'given_name': 'Bullimore'},
#  {'family_name': 'Macauley', 'given_name': 'Figaro'},
#  {'family_name': 'Blair', 'given_name': 'Jenkins'},
#  {'family_name': 'Fleming', 'given_name': 'Cadbury'},
#  {'family_name': 'Maclaren', 'given_name': 'Bertuccio'},
#  {'family_name': 'Howard', 'given_name': 'Simonides'},
#  {'family_name': 'Dunbar', 'given_name': 'Bullimore'},
#  {'family_name': 'Hunter', 'given_name': 'Passepartout'},
#  {'family_name': 'Grierson', 'given_name': 'Passepartout'},
#  {'family_name': 'Spalding', 'given_name': 'Figaro'},
#  {'family_name': 'Jardine', 'given_name': 'Passepartout'},
#  {'family_name': 'Murdoch', 'given_name': 'Barrymore'},
#  {'family_name': 'Sutherland', 'given_name': 'Alfred'},
#  {'family_name': 'Howard', 'given_name': 'Simonides'},
#  {'family_name': 'Rose', 'given_name': 'Poole'},
#  {'family_name': 'Macdonnell', 'given_name': 'Poole'},
#  {'family_name': 'Chisholm', 'given_name': 'Figaro'},
#  {'family_name': 'Murdoch', 'given_name': 'Cadbury'},
#  {'family_name': 'Creel', 'given_name': 'Poole'},
#  {'family_name': 'Donald', 'given_name': 'Merriman'},
#  {'family_name': 'Jardine', 'given_name': 'Poole'},
#  {'family_name': 'Macarthur', 'given_name': 'Jenkins'},
#  {'family_name': 'Macdougall', 'given_name': 'Brunton'},
#  {'family_name': 'Macfarlane', 'given_name': 'Leporello'},
#  {'family_name': 'Carmichael', 'given_name': 'Bullimore'},
#  {'family_name': 'Davidson', 'given_name': 'Barkley'},
#  {'family_name': 'Primrose', 'given_name': 'Poole'},
#  {'family_name': 'Murdoch', 'given_name': 'Bertuccio'},
#  {'family_name': 'Cochrane', 'given_name': 'Leporello'},
#  {'family_name': 'Mair', 'given_name': 'Brunton'},
#  {'family_name': 'Barclay', 'given_name': 'Brunton'},
#  {'family_name': 'Glengarry', 'given_name': 'Belvedere'},
#  {'family_name': 'Macintyre', 'given_name': 'Leporello'},
#  {'family_name': 'Forrester', 'given_name': 'Brunton'},
#  {'family_name': 'Buchanan', 'given_name': 'Jenkins'},
#  {'family_name': 'Agnew', 'given_name': 'Cadbury'},
#  {'family_name': 'Sinclair', 'given_name': 'Barrymore'},
#  {'family_name': 'Maclaren', 'given_name': 'Poole'},
#  {'family_name': 'Akins', 'given_name': 'Simonides'},
#  {'family_name': 'Cameron', 'given_name': 'Barrymore'},
#  {'family_name': 'Shaw', 'given_name': 'Barkley'},
#  {'family_name': 'Macarthur', 'given_name': 'Barkley'},
#  {'family_name': 'Oliphant', 'given_name': 'Simonides'},
#  {'family_name': 'Haig', 'given_name': 'Alfred'},
#  {'family_name': 'Fergusson', 'given_name': 'Jeeves'},
#  {'family_name': 'Becker', 'given_name': 'Barkley'},
#  {'family_name': 'Russell', 'given_name': 'Bertuccio'},
#  {'family_name': 'Nesbitt', 'given_name': 'Belvedere'},
#  {'family_name': 'Cunningham', 'given_name': 'Leporello'},
#  {'family_name': 'Keen', 'given_name': 'Bullimore'},
#  {'family_name': 'Moffat', 'given_name': 'Jeeves'},
#  {'family_name': 'Howard', 'given_name': 'Leporello'},
#  {'family_name': 'Oliphant', 'given_name': 'Bertuccio'},
#  {'family_name': 'Anderson', 'given_name': 'Barkley'},
#  {'family_name': 'Macmillan', 'given_name': 'Passepartout'},
#  {'family_name': 'Nicolson', 'given_name': 'Brunton'},
#  {'family_name': 'Greg', 'given_name': 'Passepartout'},
#  {'family_name': 'Hope', 'given_name': 'Simonides'},
#  {'family_name': 'Wallace', 'given_name': 'Leporello'},
#  {'family_name': 'Stewart', 'given_name': 'Leporello'},
#  {'family_name': 'Moffat', 'given_name': 'Barrymore'},
#  {'family_name': 'Macneil', 'given_name': 'Simonides'},
#  {'family_name': 'Wheatley', 'given_name': 'Barkley'},
#  {'family_name': 'Macarthur', 'given_name': 'Bullimore'},
#  {'family_name': 'Howard', 'given_name': 'Jenkins'},
#  {'family_name': 'Macduff', 'given_name': 'Alfred'},
#  {'family_name': 'Harris', 'given_name': 'Simonides'},
#  {'family_name': 'Maclaren', 'given_name': 'Jenkins'},
#  {'family_name': 'Haig', 'given_name': 'Jeeves'},
#  {'family_name': 'Wood', 'given_name': 'Bertuccio'},
#  {'family_name': 'Matheson', 'given_name': 'Leporello'},
#  {'family_name': 'Becker', 'given_name': 'Bertuccio'},
#  {'family_name': 'Napier', 'given_name': 'Figaro'},
#  {'family_name': 'Allen', 'given_name': 'Jeeves'},
#  {'family_name': 'Stuart', 'given_name': 'Bertuccio'},
#  {'family_name': 'Kerr', 'given_name': 'Jeeves'},
#  {'family_name': 'Carnegie', 'given_name': 'Cadbury'},
#  {'family_name': 'Macfarlane', 'given_name': 'Barkley'},
#  {'family_name': 'Brodie', 'given_name': 'Passepartout'},
#  {'family_name': 'Chattan', 'given_name': 'Cadbury'},
#  {'family_name': 'Stewart', 'given_name': 'Leporello'},
#  {'family_name': 'Moffat', 'given_name': 'Passepartout'},
#  {'family_name': 'Macdonnell', 'given_name': 'Bullimore'},
#  {'family_name': 'Macleod', 'given_name': 'Merriman'},
#  {'family_name': 'Forrester', 'given_name': 'Brunton'},
#  {'family_name': 'Forrester', 'given_name': 'Cadbury'},
#  {'family_name': 'Lewis', 'given_name': 'Figaro'},
#  {'family_name': 'Mackenzie', 'given_name': 'Poole'},
#  {'family_name': 'Rose', 'given_name': 'Belvedere'},
#  {'family_name': 'Hannay', 'given_name': 'Simonides'},
#  {'family_name': 'Scott', 'given_name': 'Poole'},
#  {'family_name': 'Macnab', 'given_name': 'Figaro'},
#  {'family_name': 'Anderson', 'given_name': 'Passepartout'},
#  {'family_name': 'Lockhart', 'given_name': 'Cadbury'},
#  {'family_name': 'Agnew', 'given_name': 'Belvedere'},
#  {'family_name': 'Carnegie', 'given_name': 'Jeeves'},
#  {'family_name': 'Stuart', 'given_name': 'Bertuccio'},
#  {'family_name': 'Lindsay', 'given_name': 'Leporello'},
#  {'family_name': 'Primrose', 'given_name': 'Barrymore'},
#  {'family_name': 'Howard', 'given_name': 'Jeeves'},
#  {'family_name': 'Wallace', 'given_name': 'Cadbury'},
#  {'family_name': 'Mackay', 'given_name': 'Jeeves'},
#  {'family_name': 'Lockhart', 'given_name': 'Figaro'},
#  {'family_name': 'Chisholm', 'given_name': 'Simonides'},
#  {'family_name': 'Innes', 'given_name': 'Barkley'},
#  {'family_name': 'Macneil', 'given_name': 'Cadbury'},
#  {'family_name': 'Buchanan', 'given_name': 'Jeeves'},
#  {'family_name': 'Douglas', 'given_name': 'Merriman'},
#  {'family_name': 'Sinclair', 'given_name': 'Barkley'},
#  {'family_name': 'Haig', 'given_name': 'Alfred'},
#  {'family_name': 'Ogilvy', 'given_name': 'Bullimore'},
#  {'family_name': 'Napier', 'given_name': 'Bullimore'},
#  {'family_name': 'Boyd', 'given_name': 'Alfred'},
#  {'family_name': 'Fraser', 'given_name': 'Leporello'},
#  {'family_name': 'Blair', 'given_name': 'Figaro'},
#  {'family_name': 'Mackenzie', 'given_name': 'Poole'},
#  {'family_name': 'Henry', 'given_name': 'Jenkins'},
#  {'family_name': 'Lyon', 'given_name': 'Barrymore'},
#  {'family_name': 'Hannay', 'given_name': 'Bullimore'},
#  {'family_name': 'Ross', 'given_name': 'Jeeves'},
#  {'family_name': 'Post', 'given_name': 'Merriman'},
#  {'family_name': 'Stuart', 'given_name': 'Merriman'},
#  {'family_name': 'Nicolson', 'given_name': 'Barkley'},
#  {'family_name': 'Charteris', 'given_name': 'Jenkins'},
#  {'family_name': 'Fleming', 'given_name': 'Passepartout'},
#  {'family_name': 'Elliott', 'given_name': 'Barkley'},
#  {'family_name': 'Nicolson', 'given_name': 'Belvedere'},
#  {'family_name': 'Riddell', 'given_name': 'Figaro'},
#  {'family_name': 'Beckham', 'given_name': 'Leporello'},
#  {'family_name': 'Macnab', 'given_name': 'Jeeves'},
#  {'family_name': 'Barclay', 'given_name': 'Poole'},
#  {'family_name': 'Lockhart', 'given_name': 'Merriman'},
#  {'family_name': 'Moffat', 'given_name': 'Barkley'},
#  {'family_name': 'Carnegie', 'given_name': 'Figaro'},
#  {'family_name': 'Gunn', 'given_name': 'Merriman'},
#  {'family_name': 'Haldane', 'given_name': 'Leporello'},
#  {'family_name': 'Macintyre', 'given_name': 'Poole'},
#  {'family_name': 'Robertson', 'given_name': 'Poole'},
#  {'family_name': 'Beckham', 'given_name': 'Figaro'},
#  {'family_name': 'Ogilvy', 'given_name': 'Jenkins'},
#  {'family_name': 'Elliott', 'given_name': 'Jeeves'},
#  {'family_name': 'Dewar', 'given_name': 'Leporello'},
#  {'family_name': 'Sutherland', 'given_name': 'Leporello'},
#  {'family_name': 'Henderson', 'given_name': 'Bullimore'},
#  {'family_name': 'Duncan', 'given_name': 'Barrymore'},
#  {'family_name': 'Macauley', 'given_name': 'Jeeves'},
#  {'family_name': 'Gordon', 'given_name': 'Barkley'},
#  {'family_name': 'Duncan', 'given_name': 'Alfred'},
#  {'family_name': 'Armstrong', 'given_name': 'Simonides'},
#  {'family_name': 'Murdoch', 'given_name': 'Brunton'},
#  {'family_name': 'Lamont', 'given_name': 'Poole'},
#  {'family_name': 'Charteris', 'given_name': 'Merriman'},
#  {'family_name': 'Hope', 'given_name': 'Barkley'},
#  {'family_name': 'Cumming', 'given_name': 'Alfred'},
#  {'family_name': 'Kerr', 'given_name': 'Leporello'},
#  {'family_name': 'Armstrong', 'given_name': 'Cadbury'},
#  {'family_name': 'Lyon', 'given_name': 'Belvedere'},
#  {'family_name': 'Mackay', 'given_name': 'Simonides'},
#  {'family_name': 'Henry', 'given_name': 'Brunton'},
#  {'family_name': 'Macnab', 'given_name': 'Jenkins'},
#  {'family_name': 'Oliphant', 'given_name': 'Bullimore'},
#  {'family_name': 'Graham', 'given_name': 'Cadbury'},
#  {'family_name': 'Carmichael', 'given_name': 'Barkley'},
#  {'family_name': 'Lindsay', 'given_name': 'Cadbury'},
#  {'family_name': 'Boyd', 'given_name': 'Brunton'},
#  {'family_name': 'Davidson', 'given_name': 'Jenkins'},
#  {'family_name': 'Ogilvy', 'given_name': 'Jenkins'},
#  {'family_name': 'Post', 'given_name': 'Leporello'},
#  {'family_name': 'Irvine', 'given_name': 'Leporello'},
#  {'family_name': 'Keith', 'given_name': 'Passepartout'},
#  {'family_name': 'Hannay', 'given_name': 'Merriman'},
#  {'family_name': 'Macnab', 'given_name': 'Passepartout'},
#  {'family_name': 'Robertson', 'given_name': 'Merriman'},
#  {'family_name': 'Boyd', 'given_name': 'Belvedere'},
#  {'family_name': 'Fleet', 'given_name': 'Brunton'},
#  {'family_name': 'Macdonald', 'given_name': 'Belvedere'},
#  {'family_name': 'Macpherson', 'given_name': 'Merriman'},
#  {'family_name': 'Crichton', 'given_name': 'Alfred'},
#  {'family_name': 'Graham', 'given_name': 'Alfred'},
#  {'family_name': 'Glengarry', 'given_name': 'Barkley'},
#  {'family_name': 'Ogilvy', 'given_name': 'Cadbury'},
#  {'family_name': 'Rollo', 'given_name': 'Passepartout'},
#  {'family_name': 'Hannay', 'given_name': 'Poole'},
#  {'family_name': 'Forbes', 'given_name': 'Belvedere'},
#  {'family_name': 'Macpherson', 'given_name': 'Jenkins'},
#  {'family_name': 'Anderson', 'given_name': 'Passepartout'},
#  {'family_name': 'Maclaren', 'given_name': 'Passepartout'},
#  {'family_name': 'Macpherson', 'given_name': 'Poole'},
#  {'family_name': 'Agnew', 'given_name': 'Merriman'},
#  {'family_name': 'Howard', 'given_name': 'Passepartout'},
#  {'family_name': 'Moffat', 'given_name': 'Simonides'},
#  {'family_name': 'Forrester', 'given_name': 'Merriman'},
#  {'family_name': 'Wallace', 'given_name': 'Barrymore'},
#  {'family_name': 'Fleet', 'given_name': 'Barrymore'},
#  {'family_name': 'Post', 'given_name': 'Simonides'},
#  {'family_name': 'Buchanan', 'given_name': 'Figaro'},
#  {'family_name': 'Macdonnell', 'given_name': 'Merriman'},
#  {'family_name': 'Drummond', 'given_name': 'Barkley'},
#  {'family_name': 'Robertson', 'given_name': 'Leporello'},
#  {'family_name': 'Ogilvy', 'given_name': 'Belvedere'},
#  {'family_name': 'Macintyre', 'given_name': 'Barkley'},
#  {'family_name': 'Mackay', 'given_name': 'Barkley'},
#  {'family_name': 'Ramsay', 'given_name': 'Belvedere'},
#  {'family_name': 'Howard', 'given_name': 'Poole'},
#  {'family_name': 'Barclay', 'given_name': 'Jenkins'},
#  {'family_name': 'Robertson', 'given_name': 'Barrymore'},
#  {'family_name': 'Mcmullen', 'given_name': 'Merriman'},
#  {'family_name': 'Fergusson', 'given_name': 'Brunton'},
#  {'family_name': 'Strange', 'given_name': 'Jeeves'},
#  {'family_name': 'Elliott', 'given_name': 'Jeeves'},
#  {'family_name': 'Douglas', 'given_name': 'Figaro'},
#  {'family_name': 'Stewart', 'given_name': 'Barrymore'},
#  {'family_name': 'Sterling', 'given_name': 'Belvedere'},
#  ...]

# %% [markdown]
# This is basically the same as, in DuckDB:

# %%
duckdb.sql('select name from people_df')
# Out:
# ┌───────────────────────────────────────────────────────┐
# │                         name                          │
# │    struct(family_name varchar, given_name varchar)    │
# ├───────────────────────────────────────────────────────┤
# │ {'family_name': Post, 'given_name': Belvedere}        │
# │ {'family_name': Watt, 'given_name': Brunton}          │
# │ {'family_name': Hannay, 'given_name': Passepartout}   │
# │ {'family_name': Carnegie, 'given_name': Passepartout} │
# │ {'family_name': Duncan, 'given_name': Merriman}       │
# │ {'family_name': Watt, 'given_name': Figaro}           │
# │ {'family_name': Graham, 'given_name': Leporello}      │
# │ {'family_name': Macneil, 'given_name': Merriman}      │
# │ {'family_name': Rollo, 'given_name': Merriman}        │
# │ {'family_name': Spalding, 'given_name': Figaro}       │
# │                        ·                              │
# │                        ·                              │
# │                        ·                              │
# │ {'family_name': Munro, 'given_name': Simonides}       │
# │ {'family_name': Munro, 'given_name': Bullimore}       │
# │ {'family_name': Macfarlane, 'given_name': Barrymore}  │
# │ {'family_name': Spalding, 'given_name': Cadbury}      │
# │ {'family_name': Lockhart, 'given_name': Leporello}    │
# │ {'family_name': Drummond, 'given_name': Alfred}       │
# │ {'family_name': Rollo, 'given_name': Bullimore}       │
# │ {'family_name': Barclay, 'given_name': Simonides}     │
# │ {'family_name': Hope, 'given_name': Jeeves}           │
# │ {'family_name': Chisholm, 'given_name': Simonides}    │
# ├───────────────────────────────────────────────────────┤
# │             ? rows (>9999 rows, 20 shown)             │
# └───────────────────────────────────────────────────────┘

# %% [markdown]
# We can also add conditionals on this.  Python has a bit of a weird syntax: each value of `x` in the collection needs something to be output, and we can output a different value depending on whether a condition is satisfied.

# %%
[x if not pd.isna(x) and x.find('-') < 6 else '(special)' for x in list(people_df['_id'])]
# Out:
# ['moist-vodka',
#  '(special)',
#  'tart-acorn',
#  '(special)',
#  '(special)',
#  'salty-section',
#  '(special)',
#  '(special)',
#  '(special)',
#  'rich-laser',
#  'cold-reveal',
#  '(special)',
#  'oily-sport',
#  '(special)',
#  '(special)',
#  '(special)',
#  'plain-torpedo',
#  '(special)',
#  'coped-wash',
#  'hard-node',
#  'exact-novel',
#  '(special)',
#  'tart-velocity',
#  '(special)',
#  'fancy-notch',
#  '(special)',
#  '(special)',
#  '(special)',
#  'worn-swallow',
#  '(special)',
#  'pale-pot',
#  'all-architecture',
#  'dry-participant',
#  '(special)',
#  '(special)',
#  '(special)',
#  'sweet-clef',
#  '(special)',
#  'dull-bezier',
#  'nutty-profile',
#  '(special)',
#  'rigid-coconut',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'each-publicist',
#  '(special)',
#  'thin-level',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'basic-wax',
#  '(special)',
#  '(special)',
#  'rude-turbine',
#  'rosy-specialist',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'plain-bosun',
#  'ebony-guitar',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'denim-database',
#  '(special)',
#  'bold-drive',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'ebony-cycle',
#  '(special)',
#  '(special)',
#  'stone-poltergeist',
#  'other-viola',
#  '(special)',
#  '(special)',
#  'worn-canon',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'faint-fencing',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'dry-dust',
#  'glad-sauerkraut',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'quiet-image',
#  '(special)',
#  'each-deadhead',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'clean-stalk',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'gray-card',
#  'grim-inertia',
#  '(special)',
#  'level-pole',
#  '(special)',
#  '(special)',
#  'pale-layer',
#  'slim-sage',
#  'icy-radio',
#  'fixed-chimichanga',
#  'quick-mesh',
#  '(special)',
#  'free-left',
#  '(special)',
#  'tangy-heater',
#  'white-fossa',
#  'rank-perch',
#  '(special)',
#  'glum-bag',
#  '(special)',
#  'coral-submodule',
#  '(special)',
#  '(special)',
#  '(special)',
#  'quick-mortgage',
#  'khaki-envelope',
#  '(special)',
#  '(special)',
#  '(special)',
#  'free-brad',
#  'wood-ski',
#  '(special)',
#  'icy-bug',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'cold-granite',
#  '(special)',
#  '(special)',
#  'old-electron',
#  'camel-flunky',
#  '(special)',
#  '(special)',
#  'steel-range',
#  '(special)',
#  'ash-acorn',
#  '(special)',
#  '(special)',
#  'neat-alloy',
#  'worn-balustrade',
#  'smoky-code',
#  '(special)',
#  'quick-pretzel',
#  '(special)',
#  '(special)',
#  'basic-denouement',
#  '(special)',
#  '(special)',
#  '(special)',
#  'new-shiraz',
#  '(special)',
#  'wood-journal',
#  'joint-portico',
#  'mild-thumbnail',
#  '(special)',
#  'drab-birch',
#  '(special)',
#  'wide-sardine',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'jolly-net',
#  'glum-coral',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'quick-strata',
#  'coped-inventory',
#  '(special)',
#  'ebony-broker',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'brute-force-continent',
#  'cyan-run',
#  '(special)',
#  '(special)',
#  'paper-recursion',
#  '(special)',
#  '(special)',
#  'ash-terrace',
#  '(special)',
#  '(special)',
#  '(special)',
#  'huge-hatchback',
#  '(special)',
#  'bent-decision',
#  'thin-market',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'tiny-canteen',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'tough-chain',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'plumb-curve',
#  'hoary-carton',
#  'novel-chino',
#  '(special)',
#  '(special)',
#  'soft-camembert',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'plumb-interest',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'tangy-supervisor',
#  '(special)',
#  '(special)',
#  'silly-merge',
#  '(special)',
#  '(special)',
#  '(special)',
#  'rich-boondoggle',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'muted-commander',
#  'cold-base',
#  '(special)',
#  'human-glass',
#  '(special)',
#  'brass-solo',
#  'soft-record',
#  'cold-collateral',
#  '(special)',
#  'olive-dialogue',
#  'muted-elbow',
#  '(special)',
#  '(special)',
#  'fixed-pseudonym',
#  '(special)',
#  '(special)',
#  '(special)',
#  'best-camera',
#  '(special)',
#  '(special)',
#  '(special)',
#  'thin-light',
#  'jolly-crypt',
#  'loud-skill',
#  '(special)',
#  'round-karate',
#  '(special)',
#  '(special)',
#  'round-formatting',
#  '(special)',
#  'light-taquito',
#  '(special)',
#  'lean-trie',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'lazy-north',
#  'glass-herb',
#  '(special)',
#  '(special)',
#  '(special)',
#  'snow-message',
#  'livid-caramel',
#  'slow-costume',
#  '(special)',
#  'free-beat',
#  '(special)',
#  'slim-helo',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'icy-suite',
#  '(special)',
#  '(special)',
#  'azure-parkway',
#  '(special)',
#  'right-spam',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'small-changeset',
#  '(special)',
#  'stone-founder',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'mild-copy',
#  '(special)',
#  '(special)',
#  'spry-heater',
#  '(special)',
#  '(special)',
#  'sour-database',
#  'local-exception',
#  '(special)',
#  'mild-monastery',
#  '(special)',
#  '(special)',
#  '(special)',
#  'fat-stack',
#  '(special)',
#  'proud-staff',
#  '(special)',
#  '(special)',
#  'rude-forest',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'great-object',
#  '(special)',
#  '(special)',
#  'baked-light',
#  '(special)',
#  '(special)',
#  'plain-tower',
#  '(special)',
#  '(special)',
#  'zingy-action',
#  '(special)',
#  '(special)',
#  '(special)',
#  'giant-mesa',
#  '(special)',
#  'wide-bamboo',
#  'light-mortar',
#  '(special)',
#  '(special)',
#  'dark-acre',
#  '(special)',
#  'giant-delta',
#  '(special)',
#  'loud-knot',
#  '(special)',
#  'green-bog',
#  '(special)',
#  'dense-puffin',
#  '(special)',
#  '(special)',
#  'salty-radiation',
#  'brute-force-aluminum',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'silly-wave',
#  'fresh-clearance',
#  '(special)',
#  'wan-taco',
#  'plain-rotation',
#  '(special)',
#  '(special)',
#  'moist-margin',
#  '(special)',
#  '(special)',
#  'eager-bulb',
#  '(special)',
#  '(special)',
#  '(special)',
#  'light-monitor',
#  'human-rivulet',
#  '(special)',
#  'jolly-mesh',
#  'giant-fantail',
#  'lead-request',
#  '(special)',
#  '(special)',
#  '(special)',
#  'local-app',
#  'fixed-protagonist',
#  'gray-taking',
#  'grave-puck',
#  'large-chenille',
#  '(special)',
#  'vivid-benefit',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'flat-contingency',
#  '(special)',
#  '(special)',
#  '(special)',
#  'ash-matrix',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'tense-vector',
#  '(special)',
#  '(special)',
#  '(special)',
#  'large-teapot',
#  '(special)',
#  '(special)',
#  'ash-bastion',
#  '(special)',
#  '(special)',
#  'thin-reuben',
#  '(special)',
#  'cruel-automaton',
#  'zingy-transform',
#  '(special)',
#  '(special)',
#  '(special)',
#  'spicy-spirit',
#  '(special)',
#  '(special)',
#  'some-load',
#  '(special)',
#  'fast-poset',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'glad-translation',
#  'calm-scotch',
#  '(special)',
#  'local-information',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'wide-pot',
#  '(special)',
#  '(special)',
#  '(special)',
#  'snowy-pug',
#  '(special)',
#  '(special)',
#  '(special)',
#  'rude-bound',
#  '(special)',
#  '(special)',
#  'neat-touch',
#  '(special)',
#  '(special)',
#  'chewy-fortress',
#  '(special)',
#  'hard-sort',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'bone-sonar',
#  'fixed-ensign',
#  'quick-barbaresco',
#  'black-seller',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'thin-hearth',
#  '(special)',
#  '(special)',
#  'sunny-buoy',
#  '(special)',
#  '(special)',
#  'witty-kernel',
#  'white-window',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'trite-electron',
#  '(special)',
#  '(special)',
#  '(special)',
#  'glass-jog',
#  'tart-kestrel',
#  'faded-road',
#  'tiny-neuron',
#  'jolly-canal',
#  '(special)',
#  '(special)',
#  '(special)',
#  'iron-vertex',
#  'exact-target',
#  '(special)',
#  '(special)',
#  'smart-analog',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'raw-method',
#  '(special)',
#  '(special)',
#  'cold-tarragon',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'tart-expertise',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'cream-casing',
#  'plain-sheave',
#  '(special)',
#  '(special)',
#  'denim-bike',
#  '(special)',
#  'steel-heater',
#  'exact-turpentine',
#  'salty-spirit',
#  'fixed-stem',
#  '(special)',
#  'lead-skirmish',
#  '(special)',
#  '(special)',
#  '(special)',
#  'quiet-boat',
#  '(special)',
#  'bold-asadero',
#  'broad-positron',
#  '(special)',
#  'paper-pergola',
#  '(special)',
#  '(special)',
#  '(special)',
#  'young-delta',
#  '(special)',
#  'tough-surrender',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'shiny-gully',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'novel-torpedo',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'mild-himalayan',
#  'lead-accuracy',
#  'flat-mole',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'plain-formation',
#  '(special)',
#  'solid-rum',
#  '(special)',
#  'round-staff',
#  'thin-house',
#  'cruel-gun',
#  'small-cube',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'exact-buffalo',
#  'agile-amplitude',
#  '(special)',
#  'quiet-cornice',
#  'shy-spear',
#  '(special)',
#  '(special)',
#  '(special)',
#  'hot-spruce',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'raw-volley',
#  'sour-map',
#  'salty-hull',
#  '(special)',
#  '(special)',
#  'wide-sum',
#  '(special)',
#  '(special)',
#  '(special)',
#  'crazy-deque',
#  '(special)',
#  'local-antiquity',
#  'warm-click',
#  'level-headset',
#  '(special)',
#  'fixed-luminosity',
#  '(special)',
#  'joint-hotel',
#  '(special)',
#  'jolly-dado',
#  'hot-change',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'felt-gable',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'timid-roman',
#  '(special)',
#  'quiet-cider',
#  '(special)',
#  '(special)',
#  '(special)',
#  'aged-reader',
#  '(special)',
#  '(special)',
#  '(special)',
#  'rowdy-oasis',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'rosy-nucleus',
#  '(special)',
#  'coped-cornice',
#  'muted-cabernet',
#  '(special)',
#  '(special)',
#  '(special)',
#  'glum-pepper',
#  '(special)',
#  '(special)',
#  'humid-rake',
#  'azure-recourse',
#  '(special)',
#  '(special)',
#  '(special)',
#  'big-glass',
#  'lazy-imperative',
#  'solid-gradient',
#  'cold-castle',
#  'glass-independence',
#  '(special)',
#  'smoky-monitor',
#  '(special)',
#  'best-marsanne',
#  'kind-pocket',
#  '(special)',
#  '(special)',
#  'zingy-polygon',
#  '(special)',
#  '(special)',
#  '(special)',
#  'rapid-segno',
#  'happy-tetrad',
#  'jet-bell',
#  'sour-swift',
#  '(special)',
#  '(special)',
#  '(special)',
#  'sweet-dove',
#  '(special)',
#  'arid-producer',
#  '(special)',
#  '(special)',
#  'mute-screw',
#  'small-bin',
#  '(special)',
#  'stone-suite',
#  'snow-mullion',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'clear-participant',
#  'right-repeat',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'tan-hub',
#  'brave-swatch',
#  'free-action',
#  '(special)',
#  '(special)',
#  '(special)',
#  'sweet-onion',
#  '(special)',
#  'rainy-altitude',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'largo-climax',
#  '(special)',
#  '(special)',
#  '(special)',
#  'cruel-convertible',
#  'coped-vehicle',
#  '(special)',
#  '(special)',
#  '(special)',
#  'red-rice',
#  '(special)',
#  'cruel-map',
#  'soft-lead',
#  '(special)',
#  '(special)',
#  'ripe-script',
#  'free-shoal',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'minty-sauerkraut',
#  'plum-column',
#  '(special)',
#  '(special)',
#  'snow-inlay',
#  '(special)',
#  '(special)',
#  'mild-epoch',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'mean-gravel',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'joint-pollen',
#  'witty-sport',
#  '(special)',
#  'rank-electricity',
#  '(special)',
#  '(special)',
#  'steel-envelope',
#  'round-payment',
#  'drab-sideboard',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'stone-humvee',
#  '(special)',
#  'flat-startup',
#  'lead-fox',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'thick-dragster',
#  '(special)',
#  'steel-argument',
#  '(special)',
#  '(special)',
#  '(special)',
#  'level-mullion',
#  '(special)',
#  'broad-force',
#  '(special)',
#  '(special)',
#  '(special)',
#  'tiny-convolution',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'plain-cevian',
#  'angry-set',
#  '(special)',
#  'cold-haddock',
#  '(special)',
#  '(special)',
#  '(special)',
#  'angry-backstory',
#  'free-sequence',
#  '(special)',
#  'open-partition',
#  'spicy-cider',
#  '(special)',
#  'free-varnish',
#  '(special)',
#  '(special)',
#  'bone-tarragon',
#  '(special)',
#  '(special)',
#  '(special)',
#  'shiny-act',
#  '(special)',
#  'spicy-gun',
#  'grave-hound',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'cruel-muffin',
#  '(special)',
#  'glass-number',
#  '(special)',
#  '(special)',
#  'rigid-darby',
#  'wood-gear',
#  '(special)',
#  '(special)',
#  'plain-refraction',
#  'navy-arrowroot',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'sleek-basis',
#  '(special)',
#  'swift-map',
#  'bone-synth',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'plum-islet',
#  '(special)',
#  'fixed-transform',
#  '(special)',
#  '(special)',
#  '(special)',
#  'cold-channel',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'great-baryon',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'lazy-range',
#  'rust-convection',
#  'quick-yak',
#  '(special)',
#  'snowy-brownstone',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'smoky-taquito',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'lower-cinema',
#  '(special)',
#  'eager-pudding',
#  'quiet-lyrics',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  'vain-time',
#  'iron-capacity',
#  'null-dispersion',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  '(special)',
#  ...]

# %% [markdown]
# SQL also allows for conditions using a `CASE WHEN` syntax.  Note the `position` function in DuckDB SQL returns 1-based, as opposed to 0-based, positions.

# %%
duckdb.sql("""
  SELECT CASE WHEN _id IS NOT NULL AND position('-' IN _id) < 7 then _id else '(special)' end
  FROM people_df
""")
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ CASE  WHEN (((_id IS NOT NULL) AND (main."position"(_id, '-') < 7))) THEN (_id) ELSE '(special)' END │
# │                                               varchar                                                │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ moist-vodka                                                                                          │
# │ (special)                                                                                            │
# │ tart-acorn                                                                                           │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ salty-section                                                                                        │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ rich-laser                                                                                           │
# │     ·                                                                                                │
# │     ·                                                                                                │
# │     ·                                                                                                │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ matte-curve                                                                                          │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# │ (special)                                                                                            │
# ├──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                    ? rows (>9999 rows, 20 shown)                                     │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Exercise
#
# Write a SQL query that replaces all industries without "tech" as a substring with NULL.  Be sure you are case-agnostic in your query, but don't change the case in the result.  Make sure the column is called "industry." Return the results as a dataframe.

# %%
results_df = # TODO

# %%
results_df.dropna()

# %%
if not isinstance(results_df, pd.DataFrame):
  raise TypeError("Value in results_df must be a pandas DataFrame")
elif len(results_df.dropna()) == len(results_df):
  raise RuntimeError('We would expect some nulls!')
grader.grade('sql_case', results_df)
# Out:
# Correct! You earned 1/1 points. You are a star!
#
# Your submission has been successfully recorded in the gradebook.

# %% [markdown]
# ## *Uncorrelated* Subqueries / Table Expressions
#
# Generally, in SQL we can write a *table expression* anywhere we could use a table.  Maybe the simplest way is to consider an expression within the FROM clause.

# %%
conn.sql(
    """
  SELECT *
  FROM (
    SELECT _id, given_name, family_name
    FROM people JOIN (SELECT _id FROM skills WHERE lower(skills) LIKE '%bio%') USING (_id)
  )
"""
)
# Out:
# ┌─────────────────────┬──────────────┬─────────────┐
# │         _id         │  given_name  │ family_name │
# │       varchar       │   varchar    │   varchar   │
# ├─────────────────────┼──────────────┼─────────────┤
# │ proper-strain       │ Jenkins      │ Strange     │
# │ honest-loop         │ Passepartout │ Nesbitt     │
# │ drab-birch          │ Bullimore    │ Stuart      │
# │ proud-brig          │ Simonides    │ Murdoch     │
# │ cold-pivot          │ Merriman     │ Kennedy     │
# │ cheerful-davit      │ Poole        │ Crichton    │
# │ shabby-shepherd     │ Bertuccio    │ Armstrong   │
# │ regular-airwatt     │ Merriman     │ Watt        │
# │ tossed-wave         │ Cadbury      │ Oliphant    │
# │ fermented-coastie   │ Bullimore    │ Lennox      │
# │        ·            │    ·         │   ·         │
# │        ·            │    ·         │   ·         │
# │        ·            │    ·         │   ·         │
# │ rosy-covariance     │ Barkley      │ Drummond    │
# │ global-kayak        │ Alfred       │ Armstrong   │
# │ rigid-convolution   │ Passepartout │ Rollo       │
# │ chestnut-grid       │ Brunton      │ Maclaren    │
# │ blocky-differential │ Barrymore    │ Watt        │
# │ icy-bassoon         │ Alfred       │ Munro       │
# │ violent-jog         │ Jenkins      │ Keith       │
# │ corn-bright         │ Bertuccio    │ Macalister  │
# │ rich-check          │ Jeeves       │ Strange     │
# │ icy-amortization    │ Jeeves       │ Hamilton    │
# ├─────────────────────┴──────────────┴─────────────┤
# │ 90 rows (20 shown)                     3 columns │
# └──────────────────────────────────────────────────┘

# %% [markdown]
# And SQL also allows for IN {table expression} or EXISTS({table expression}) within the WHERE clause.

# %%
conn.sql(
    """
  SELECT *
  FROM (
    SELECT _id, given_name, family_name
    FROM people
    WHERE _id IN (SELECT _id FROM skills WHERE lower(skills) LIKE '%bio%')
  )
"""
)
# Out:
# ┌─────────────────────┬──────────────┬─────────────┐
# │         _id         │  given_name  │ family_name │
# │       varchar       │   varchar    │   varchar   │
# ├─────────────────────┼──────────────┼─────────────┤
# │ proper-strain       │ Jenkins      │ Strange     │
# │ honest-loop         │ Passepartout │ Nesbitt     │
# │ drab-birch          │ Bullimore    │ Stuart      │
# │ proud-brig          │ Simonides    │ Murdoch     │
# │ cold-pivot          │ Merriman     │ Kennedy     │
# │ cheerful-davit      │ Poole        │ Crichton    │
# │ shabby-shepherd     │ Bertuccio    │ Armstrong   │
# │ regular-airwatt     │ Merriman     │ Watt        │
# │ tossed-wave         │ Cadbury      │ Oliphant    │
# │ fermented-coastie   │ Bullimore    │ Lennox      │
# │        ·            │    ·         │   ·         │
# │        ·            │    ·         │   ·         │
# │        ·            │    ·         │   ·         │
# │ rosy-covariance     │ Barkley      │ Drummond    │
# │ global-kayak        │ Alfred       │ Armstrong   │
# │ rigid-convolution   │ Passepartout │ Rollo       │
# │ chestnut-grid       │ Brunton      │ Maclaren    │
# │ blocky-differential │ Barrymore    │ Watt        │
# │ icy-bassoon         │ Alfred       │ Munro       │
# │ violent-jog         │ Jenkins      │ Keith       │
# │ corn-bright         │ Bertuccio    │ Macalister  │
# │ rich-check          │ Jeeves       │ Strange     │
# │ icy-amortization    │ Jeeves       │ Hamilton    │
# ├─────────────────────┴──────────────┴─────────────┤
# │ 90 rows (20 shown)                     3 columns │
# └──────────────────────────────────────────────────┘

# %% [markdown]
# Notice that both of the above queries compute the same thing!  In fact, generally we can accomplish the same thing as *either* of the above two uncorrelated query forms, as a single query with a JOIN.
#
# *Lesson here: think about whether you can simplify your nested queries into a single query that is easier to write / reason about!*

# %%
conn.sql(
    """
  SELECT _id, given_name, family_name
    FROM people JOIN skills USING (_id)
    WHERE lower(skills) LIKE '%bio%'
"""
)
# Out:
# ┌─────────────────────┬──────────────┬─────────────┐
# │         _id         │  given_name  │ family_name │
# │       varchar       │   varchar    │   varchar   │
# ├─────────────────────┼──────────────┼─────────────┤
# │ proper-strain       │ Jenkins      │ Strange     │
# │ honest-loop         │ Passepartout │ Nesbitt     │
# │ drab-birch          │ Bullimore    │ Stuart      │
# │ proud-brig          │ Simonides    │ Murdoch     │
# │ cold-pivot          │ Merriman     │ Kennedy     │
# │ cheerful-davit      │ Poole        │ Crichton    │
# │ shabby-shepherd     │ Bertuccio    │ Armstrong   │
# │ regular-airwatt     │ Merriman     │ Watt        │
# │ tossed-wave         │ Cadbury      │ Oliphant    │
# │ fermented-coastie   │ Bullimore    │ Lennox      │
# │        ·            │    ·         │   ·         │
# │        ·            │    ·         │   ·         │
# │        ·            │    ·         │   ·         │
# │ rosy-covariance     │ Barkley      │ Drummond    │
# │ global-kayak        │ Alfred       │ Armstrong   │
# │ rigid-convolution   │ Passepartout │ Rollo       │
# │ chestnut-grid       │ Brunton      │ Maclaren    │
# │ blocky-differential │ Barrymore    │ Watt        │
# │ icy-bassoon         │ Alfred       │ Munro       │
# │ violent-jog         │ Jenkins      │ Keith       │
# │ corn-bright         │ Bertuccio    │ Macalister  │
# │ rich-check          │ Jeeves       │ Strange     │
# │ icy-amortization    │ Jeeves       │ Hamilton    │
# ├─────────────────────┴──────────────┴─────────────┤
# │ 90 rows (20 shown)                     3 columns │
# └──────────────────────────────────────────────────┘

# %% [markdown]
# ## Correlated Subqueries

# %% [markdown]
# Recall that one way of thinking about SQL queries is that the iterate over all of the tuples in each of the tables in the FROM clause. Each table iterator is given a variable name (if you don't specify one it will be the table's name):
#
# ```
# SELECT *
# FROM people A, skills B
# ```
#
# would iterate over all A and B tuples and consider their combinations. In fact you would get a Cartesian product as a result of this.
#
# We may want to write *subqueries* that test against the values in the iterators.

# %% [markdown]
# ### EXISTS
#
# Perhaps the simplest subquery uses the `EXISTS` predicate in the `WHERE` clause. Within the predicate, we can compute any set-style expression, including a SQL query that returns results.  Naturally, `EXISTS` tests whether we have an empty set or not.
#
# Example: For each person in an industry, we can see if there exists at least one other person with the same first name, in the same industry.

# %%
# %%time
conn.sql("""
  SELECT DISTINCT A.family_name, A.given_name, A.industry
  FROM people A
  WHERE EXISTS (
    SELECT *
    FROM people B
    WHERE A._id != B._id AND
      A.given_name = B.given_name AND
      A.industry = B.industry
  )
""").df()
# Out:
# CPU times: user 96.8 ms, sys: 20 ms, total: 117 ms
# Wall time: 89.5 ms
#       family_name    given_name                             industry
# 0            Watt       Brunton                      Pharmaceuticals
# 1          Hannay  Passepartout                             Research
# 2          Graham     Leporello    Nonprofit Organization Management
# 3           Rollo      Merriman                     Telekomünikasyon
# 4          Hunter      Merriman                      Human Resources
# ...           ...           ...                                  ...
# 37496    Wheatley     Barrymore  Public Relations and Communications
# 37497     Kincaid     Bertuccio                          Real Estate
# 37498  Macdougall     Barrymore                               Design
# 37499     Forsyth       Cadbury                        Public Policy
# 37500      Donald        Alfred  Public Relations and Communications
#
# [37501 rows x 3 columns]

# %% [markdown]
# ### IN
#
# One can also test whether a result exists within a (correlated) subquery.  This should mirror your intuitions for the logical $x \in S$ test one would apply in logic.
#
# Here's a version of the previous query, looking for *all people who aren't the current person in the parent query but have a matching first name*.  Then we test if the industry matches.
# Observe that the results are the same but the query looks very different. What can you say about the *execution time*?

# %%
# %%time
conn.sql("""
  SELECT DISTINCT A.family_name, A.given_name, A.industry
  FROM people A
  WHERE A.industry IN (
    SELECT industry
    FROM people B
    WHERE A._id != B._id
    AND A.given_name = B.given_name
  )
""").df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# CPU times: user 23 s, sys: 48 ms, total: 23.1 s
# Wall time: 23.2 s
#       family_name given_name                                        industry
# 0         Strange    Jenkins                                        Internet
# 1         Burnett  Belvedere                            Government Relations
# 2        Crichton  Belvedere                                       Bankwezen
# 3         Kennedy   Merriman                                         Banking
# 4          Dunbar    Cadbury                              Financial Services
# ...           ...        ...                                             ...
# 37496    Crichton   Merriman  Tehnologia informației și servicii informatice
# 37497     Maclean     Alfred                               Computer Software
# 37498      Ogilvy  Barrymore                       Marketing and Advertising
# 37499      Harris  Leporello                                      E-Learning
# 37500       Boyle    Cadbury                              Building Materials
#
# [37501 rows x 3 columns]

# %% [markdown]
# ### Question for discussion
#
# Can you think of a way to use a *join* to capture the same result above? Hint: you may need to also use `DISTINCT`.  Among the three options which is fastest?

# %% [markdown]
# ### Test against ALL
#
# The `>= ALL()` predicate in the `WHERE` clause allows us to compare against the results of a set -- computed in a subquery.  (In most cases that subquery returns a collection of unary tuples, since we will be comparing a single scalar such as a string or int.)
#
# Example: Let's find, for each industry, the **person/people with the lexicographically greatest last name**. We can do this by seeing if the iterator's last name matches or exceeds *all* last names of people in the same industry.

# %%
conn.sql("""
   SELECT industry, _id, given_name, family_name
   FROM people A
   WHERE family_name >= ALL(
    SELECT family_name
    FROM people B
    WHERE A.industry = B.industry)
  ORDER BY A.industry
""").df()
# Out:
#               industry               _id    given_name family_name
# 0     Accessori e moda      solid-change        Jeeves    Wheatley
# 1     Accessori e moda        camel-diff       Cadbury    Wheatley
# 2           Accounting        short-plan         Poole        Wood
# 3           Accounting         shy-fluid         Poole        Wood
# 4           Accounting     rainy-content         Poole        Wood
# ...                ...               ...           ...         ...
# 1837              None      juicy-repeat        Alfred   Mackenzie
# 1838              None   bounded-lattice        Figaro     Beckham
# 1839              None     courtly-front     Bertuccio     Guthrie
# 1840              None  generous-caption     Simonides     Cumming
# 1841              None   persistent-step  Passepartout  Macdonnell
#
# [1842 rows x 4 columns]

# %% [markdown]
# Of course, if there is `>=ALL()`, you can imagine that there are *other* conditionals that can be tested against `ALL`.

# %% [markdown]
# ## Grouping, HAVING vs WHERE
#
# Sometimes we need to do SQL *grouping* as well as *filtering*.  What's important is to understand whether we are filtering *before* the aggregation (e.g., we eliminate folks we don't want to count) or *after* the aggregation (e.g., we eliminate aggregate groups).
#
# For the former we use `WHERE` as per the usual.  But if we want to filter the *results* of a `GROUP BY` we need to either (1) feed the results into another query as a source in the `FROM` clause and filter, which is often painful; or (2) use the optional SQL HAVING clause.
#
# So, if we want to show in descending order all industries by popularity, as long as the industry is *not* Biotechnology and there are at least 10 people in the industry, we can do the following.

# %%
conn.sql("""
   SELECT industry, COUNT(_id) AS popularity
   FROM people
   WHERE industry <> 'Biotechnology'
   GROUP BY industry
   HAVING COUNT(_id) > 10
   ORDER BY COUNT(_id) DESC
""").df()
# Out:
#                                 industry  popularity
# 0    Information Technology and Services        5627
# 1                      Computer Software        3512
# 2              Marketing and Advertising        2659
# 3                               Internet        2159
# 4                     Financial Services        1541
# ..                                   ...         ...
# 413                       Telekomunikace          11
# 414                   Alimenti e bevande          11
# 415           Arquitetura e planejamento          11
# 416                           Fotografie          11
# 417   Burgerlijke en sociale organisatie          11
#
# [418 rows x 2 columns]

# %% [markdown]
# # SQL Debugging

# %% [markdown]
# ## Debugging by Refactoring

# %% [markdown]
# Let's take a complex query about transitive relationships -- say, people who have experience (3+ "experience" rows) and have a common company, but one is in tech and one is in marketing.  This is essentially a "two-hop neighbor" query on a kind of graph (person p1 --> company <-- p2 where both p1 and p2 have certain constraints).

# %% [markdown]
# Suppose we tried to write all of this out, maybe like this.  It has a lot of the right form, e.g., we know we are looking for people `p1` and `p2`, it looks for people with at least 3 experiences, etc.  But it has no results!

# %%
conn.sql("""
  SELECT DISTINCT p1._id, p1.family_name, p1.given_name, p2._id, p2.family_name, p2.given_name
  FROM people p1 JOIN skills s ON p1._id = s._id JOIN experience e ON p1._id = e._id
     JOIN people p2 ON e._id = p2._id JOIN skills s2 ON p2._id = s2._id
  WHERE lower(s.skills) LIKE '%tech%' AND EXISTS (
    SELECT _id FROM experience e
    WHERE p1._id = e._id
    GROUP BY e._id
    HAVING COUNT(*) >= 3)
  AND lower(s2.skills) = 'Marketing' AND EXISTS (
    SELECT _id FROM experience e
    WHERE p2._id = e._id
    GROUP BY e._id
    HAVING COUNT(*) >= 3
  )
""").df()
# Out:
# Empty DataFrame
# Columns: [_id, family_name, given_name, _id_1, family_name_1, given_name_1]
# Index: []

# %% [markdown]
# What if we break into the two pieces first?

# %%
conn.sql("""
  SELECT DISTINCT _id, family_name, given_name, locality, skills, org
  FROM people p JOIN skills s USING (_id) JOIN experience USING (_id)
  WHERE lower(skills) LIKE '%tech%' AND EXISTS (
    SELECT _id FROM experience e
    WHERE p._id = e._id
    GROUP BY _id
    HAVING COUNT(*) >= 3)
""").df()
# Out:
#                  _id  family_name given_name                  locality  \
# 0        olive-shore       Ogilvy  Bertuccio      Greater Chicago Area
# 1        olive-shore       Ogilvy  Bertuccio      Greater Chicago Area
# 2        olive-shore       Ogilvy  Bertuccio      Greater Chicago Area
# 3        olive-shore       Ogilvy  Bertuccio      Greater Chicago Area
# 4        olive-shore       Ogilvy  Bertuccio      Greater Chicago Area
# ...              ...          ...        ...                       ...
# 2039  relaxed-ragged        Keith      Poole       Chennai Area, India
# 2040    zesty-collie  Livingstone  Leporello  Copenhagen Area, Denmark
# 2041    zesty-collie  Livingstone  Leporello  Copenhagen Area, Denmark
# 2042    zesty-collie  Livingstone  Leporello  Copenhagen Area, Denmark
# 2043    zesty-collie  Livingstone  Leporello  Copenhagen Area, Denmark
#
#                         skills                                      org
# 0           Technically Strong                                 Heineken
# 1           Technically Strong                       Cervejarias Kaiser
# 2           Technically Strong                    Viação Santa Catarina
# 3           Technically Strong  Federação de Cooperativas Agropecuárias
# 4           Technically Strong              Sonata Ind Apar Eletrônicos
# ...                        ...                                      ...
# 2039  Technological Innovation                      Pace Automation Ltd
# 2040         Technology Policy                                Accenture
# 2041         Technology Policy                                 Devoteam
# 2042         Technology Policy                       Rambøll Management
# 2043         Technology Policy             National IT & Telecom Agency
#
# [2044 rows x 6 columns]

# %%
conn.sql("""
  SELECT DISTINCT _id, family_name, given_name, skills, org
  FROM people p JOIN skills s USING (_id) JOIN experience USING (_id)
  WHERE skills = 'Marketing' AND EXISTS (
    SELECT _id FROM experience e
    WHERE p._id = e._id
    GROUP BY _id
    HAVING COUNT(*) >= 3)
""").df()
# Out:
#                   _id family_name given_name     skills  \
# 0       sour-database      Donald  Belvedere  Marketing
# 1       humid-paprika     Lindsay  Simonides  Marketing
# 2       humid-paprika     Lindsay  Simonides  Marketing
# 3       humid-paprika     Lindsay  Simonides  Marketing
# 4       humid-paprika     Lindsay  Simonides  Marketing
# ..                ...         ...        ...        ...
# 463  compact-firmware      Finlay    Jenkins  Marketing
# 464  compact-firmware      Finlay    Jenkins  Marketing
# 465  compact-firmware      Finlay    Jenkins  Marketing
# 466  compact-firmware      Finlay    Jenkins  Marketing
# 467     light-javelin      Mackay    Jenkins  Marketing
#
#                             org
# 0                        Steris
# 1     Amanda Stevens Consulting
# 2            Magellan Vacations
# 3          Botanical PaperWorks
# 4                RBC Royal Bank
# ..                          ...
# 463           SIDEA Consultores
# 464         Gobierno de Córdoba
# 465  CEDI Consulting & Training
# 466        Apex a SYKES Company
# 467         Savannah Sand Gnats
#
# [468 rows x 5 columns]

# %% [markdown]
# ### Question
#
# Those look good.  How would I join them together to actually solve the problem?

# %%
# TODO

# %% [markdown]
# ## Debugging over Samples

# %% [markdown]
# For really big datasets, you may find that it takes forever to run the query.  One approach is to *sample* results.
#
# *Caveat*: sampling independently from different tables that join is very risky -- each time we do this, the proportion of tuples in your query that join ("selectivity") goes down exponentially, because the real values are *correlated* but you are instead sampling *independently*.
#
# DuckDB addresses this by allowing you to *sample over a query result* instead of over the input tables.

# %%
conn.sql("""
  SELECT DISTINCT _id, family_name, given_name, skills, org
  FROM people p
  JOIN skills s USING (_id) JOIN experience USING (_id)
  WHERE skills = 'Marketing' AND EXISTS (
    SELECT _id FROM experience e
    WHERE p._id = e._id
    GROUP BY _id
    HAVING COUNT(*) >= 3)
   USING SAMPLE 10 PERCENT
""").df()
# Out:
#               _id family_name given_name     skills  \
# 0  pureed-caramel       Henry   Merriman  Marketing
# 1  pureed-caramel       Henry   Merriman  Marketing
# 2  pureed-caramel       Henry   Merriman  Marketing
# 3  pureed-caramel       Henry   Merriman  Marketing
# 4  pureed-caramel       Henry   Merriman  Marketing
# 5  pureed-caramel       Henry   Merriman  Marketing
# 6  pureed-caramel       Henry   Merriman  Marketing
# 7  pureed-caramel       Henry   Merriman  Marketing
# 8  pureed-caramel       Henry   Merriman  Marketing
#
#                                           org
# 0  Easy Internet Marketing ( Tribal Holding )
# 1                               Tribal People
# 2                     Easy Internet Marketing
# 3                            Grace Industries
# 4                    The Designer-III Company
# 5                        Joy Mining Machinery
# 6    Tribal Internet Solutions (Shanghai) LTD
# 7                              Matric Limited
# 8                     Circuit Cellar Magazine
