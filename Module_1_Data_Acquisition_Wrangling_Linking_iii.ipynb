# %% [markdown]
# <a href="https://colab.research.google.com/github/zackives/upenn-cis-2450/blob/main/Module_1_Data_Acquisition_Wrangling_Linking_iii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview of Part I of Big Data Analytics
#
# As we start our journey into Big Data Analytics, the first thing we need to do is **get the data** in the form we need for analysis!  We'll start with an overview of how to acquire and *wrangle* data.
#
# This notebook will be built incrementally to consider several tasks:
#
# * Acquiring data from files and remote sources
# * Information extraction over HTML content
# * A basic "vocabulary" of operators over tables (the relational algebra)
# * Basic manipulation using SQL in DuckDB
#
# * "Data wrangling" or integration:
#   * Cleaning and filtering data, using rules and based operations
#   * Linking data across dataframes or relations
#   * The need for approximate match and record linking
#   * Different techniques

# %% [markdown]
# ## The Motivating Question
# To illustrate the principles, we focus on the question of **how old company CEOs and founders** (in general, leaders) are.  The question was in part motivated by the following New York Times article:
#
# * Founders of Successful Tech Companies Are Mostly Middle-Aged: https://www.nytimes.com/2019/08/29/business/tech-start-up-founders-nest.html?searchResultPosition=2
#
# So let's test this hypothesis!

# %% [markdown]
# ## Initial Libraries
#
# We'll be using [DuckDB](https://duckdb.org/) as a means of managing our tables.  DuckDB works like a Python library, but manages a full SQL database (in files).  It also integrates very nicely with Pandas, so we'll use it in this course.

# %%
# !pip3 install duckdb
# Out:
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (0.10.3)

# %%
# !pip3 install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (4.9.4)

# %%
# %%writefile notebook-config.yaml
#
# grader_api_url: 'https://23whrwph9h.execute-api.us-east-1.amazonaws.com/default/Grader23'
# grader_api_key: 'flfkE736fA6Z8GxMDJe2q8Kfk8UDqjsG3GVqOFOa'
# Out:
# Writing notebook-config.yaml

# %%
# !pip3 install penngrader-client
# Out:
# Collecting penngrader-client
#   Downloading penngrader_client-0.5.2-py3-none-any.whl.metadata (15 kB)
# Collecting dill (from penngrader-client)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from penngrader-client) (6.0.2)
# Downloading penngrader_client-0.5.2-py3-none-any.whl (10 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: dill, penngrader-client
# Successfully installed dill-0.3.8 penngrader-client-0.5.2

# %% [markdown]
# For quiz credit you'll need to update your student ID here!

# %%
#PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO
#TO ASSIGN POINTS TO YOU IN OUR BACKEND
STUDENT_ID = 99999999 # YOUR PENN-ID GOES HERE AS AN INTEGER##PLEASE ENSURE YOUR PENN-ID IS ENTERED CORRECTLY. IF NOT, THE AUTOGRADER WON'T KNOW WHO

# %% [markdown]
# Quizzes will cumulatively count as HW9... Don't edit this...

# %%
# %set_env HW_ID=cis2450_fall24_HW9
# Out:
# env: HW_ID=cis2450_fall24_HW9

# %%
import os
from penngrader.grader import *

grader = PennGrader('notebook-config.yaml', os.environ['HW_ID'], STUDENT_ID, STUDENT_ID)
# Out:
# PennGrader initialized with Student ID: 99999999
#
# Make sure this correct or we will not be able to store your grade

# %%
# Imports we'll use through the notebook, collected here for simplicity

# For parsing dates and being able to compare
import datetime

# For fetching remote data
import urllib
import urllib.request

# Pandas dataframes and operations
import pandas as pd

# Numpy matrix and array operations
import numpy as np

# Sqlite is a simplistic database
import duckdb

# Data visualization
import matplotlib

# %% [markdown]
# # 1. Acquiring External Data
#
# To test our hypothesis, we might want:
#
# 1. A list of companies (and, for futher details, perhaps their lines of business)
# 2. A list of company CEOs
# 3. Ages of the CEOs
#
# We'll go through each of these using real data from the web.
#
# ### Reading Structured Data Sources
#
# Let's start by looking up data about companies.  We are using a dataset from: https://www.kaggle.com/datasets/peopledatalabssf/free-7-million-company-dataset?resource=download
#
# but we have a copy of it at an alternate site for convenience of downloading.

# %% [markdown]
# ## 1.1. External CSV Data
#
# Comma-separated values are generally easy to read. The main questions are column headings (which are in an optional row that isn't always provided) and datatypes (which might default to the wrong thing).

# %%
# !wget -nc https://storage.googleapis.com/penn-cis5450/companies_sorted.csv
# Out:
# --2024-08-26 22:45:18--  https://storage.googleapis.com/penn-cis5450/companies_sorted.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.101.207, 142.251.2.207, 142.250.141.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.101.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1085578742 (1.0G) [text/csv]
# Saving to: ‘companies_sorted.csv’
#
# companies_sorted.cs 100%[===================>]   1.01G  51.7MB/s    in 18s
#
# 2024-08-26 22:45:36 (57.3 MB/s) - ‘companies_sorted.csv’ saved [1085578742/1085578742]

# %%
# This reads remotely. To avoid multiple fetches, we'll instead..

# data = urllib.request.urlopen(\
#        'https://storage.googleapis.com/penn-cis5450/companies_sorted.csv')
# company_data_df = pd.read_csv(data)

## ... instead copy to a local file and read there...

company_data_df = pd.read_csv('companies_sorted.csv')

company_data_df
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...                               ...           ...
# 7173421         certiportvouchers.com        2011.0
# 7173422            blacktigerclub.com        2006.0
# 7173423                           NaN           NaN
# 7173424                           NaN           NaN
# 7173425  dynamiccontrolssolutions.com           NaN
#
#                                     industry size range  \
# 0        information technology and services     10001+
# 1        information technology and services     10001+
# 2        information technology and services     10001+
# 3                                   military     10001+
# 4                                 accounting     10001+
# ...                                      ...        ...
# 7173421  information technology and services     1 - 10
# 7173422         health, wellness and fitness     1 - 10
# 7173423               religious institutions     1 - 10
# 7173424                             research     1 - 10
# 7173425                           automotive     1 - 10
#
#                                        locality         country  \
# 0             new york, new york, united states   united states
# 1                    bombay, maharashtra, india           india
# 2                       dublin, dublin, ireland         ireland
# 3           alexandria, virginia, united states   united states
# 4        london, greater london, united kingdom  united kingdom
# ...                                         ...             ...
# 7173421                                     NaN             NaN
# 7173422                  peking, beijing, china           china
# 7173423      inverness, illinois, united states   united states
# 7173424          london, london, united kingdom  united kingdom
# 7173425          wixom, michigan, united states   united states
#
#                                               linkedin url  \
# 0                                 linkedin.com/company/ibm
# 1           linkedin.com/company/tata-consultancy-services
# 2                           linkedin.com/company/accenture
# 3                             linkedin.com/company/us-army
# 4                       linkedin.com/company/ernstandyoung
# ...                                                    ...
# 7173421            linkedin.com/company/certiport-vouchers
# 7173422         linkedin.com/company/black-tiger-club-hero
# 7173423    linkedin.com/company/catholic-bishop-of-chicago
# 7173424           linkedin.com/company/medexo-robotics-ltd
# 7173425  linkedin.com/company/dynamic-controls-solution...
#
#          current employee estimate  total employee estimate
# 0                           274047                   716906
# 1                           190771                   341369
# 2                           190689                   455768
# 3                           162163                   445958
# 4                           158363                   428960
# ...                            ...                      ...
# 7173421                          0                        1
# 7173422                          0                        6
# 7173423                          0                        1
# 7173424                          0                        2
# 7173425                          0                        1
#
# [7173426 rows x 11 columns]

# %% [markdown]
# Now let's use DuckDB to work with the dataframe.

# %%
# We can ask for the contents of a Pandas Dataframe through DuckDB, in the SQL language.
duckdb.sql('select * from company_data_df')
# Out:
# ┌────────────┬──────────────────────┬───┬──────────────────────┬──────────────────────┬──────────────────────┐
# │ Unnamed: 0 │         name         │ … │     linkedin url     │ current employee e…  │ total employee est…  │
# │   int64    │       varchar        │   │       varchar        │        int64         │        int64         │
# ├────────────┼──────────────────────┼───┼──────────────────────┼──────────────────────┼──────────────────────┤
# │    5872184 │ ibm                  │ … │ linkedin.com/compa…  │               274047 │               716906 │
# │    4425416 │ tata consultancy s…  │ … │ linkedin.com/compa…  │               190771 │               341369 │
# │      21074 │ accenture            │ … │ linkedin.com/compa…  │               190689 │               455768 │
# │    2309813 │ us army              │ … │ linkedin.com/compa…  │               162163 │               445958 │
# │    1558607 │ ey                   │ … │ linkedin.com/compa…  │               158363 │               428960 │
# │    3844889 │ hewlett-packard      │ … │ linkedin.com/compa…  │               127952 │               412952 │
# │    2959148 │ cognizant technolo…  │ … │ linkedin.com/compa…  │               122031 │               210020 │
# │    5944912 │ walmart              │ … │ linkedin.com/compa…  │               120753 │               272827 │
# │    3727010 │ microsoft            │ … │ linkedin.com/compa…  │               116196 │               276983 │
# │    3300741 │ at&t                 │ … │ linkedin.com/compa…  │               115188 │               269659 │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │    4782764 │ jönköpings kommun    │ … │ linkedin.com/compa…  │                 1118 │                 1964 │
# │    3432133 │ jmc projects india…  │ … │ linkedin.com/compa…  │                 1118 │                 2112 │
# │     910050 │ öbb                  │ … │ linkedin.com/compa…  │                 1118 │                 1546 │
# │    6444131 │ vaillant group       │ … │ linkedin.com/compa…  │                 1118 │                 2540 │
# │     916799 │ embracon administr…  │ … │ linkedin.com/compa…  │                 1118 │                 2240 │
# │    3585785 │ university of chic…  │ … │ linkedin.com/compa…  │                 1118 │                 3220 │
# │    2583172 │ pantaloon retail i…  │ … │ linkedin.com/compa…  │                 1118 │                 4723 │
# │    1406043 │ nv energy            │ … │ linkedin.com/compa…  │                 1118 │                 1834 │
# │     955441 │ mining               │ … │ linkedin.com/compa…  │                 1118 │                 1421 │
# │    5571765 │ university of stir…  │ … │ linkedin.com/compa…  │                 1118 │                 2680 │
# ├────────────┴──────────────────────┴───┴──────────────────────┴──────────────────────┴──────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                         11 columns (5 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 1.2. Storing Data Locally and Re-Loading it
#
# DuckDB nicely integrates with Pandas and Python. If you create a connection to a file, this results in the creation of a database stored within that file.
#
# Normally we need to `CREATE TABLE` with the table name and columns. But we can actually create the table to match the *schema* of the DataFrame, as follows.

# %%
con = duckdb.connect('local.db')
con.sql('create table if not exists company_data as select * from company_data_df')

# query the table
con.table("company_data").show()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌────────────┬──────────────────────┬───┬──────────────────────┬──────────────────────┬──────────────────────┐
# │ Unnamed: 0 │         name         │ … │     linkedin url     │ current employee e…  │ total employee est…  │
# │   int64    │       varchar        │   │       varchar        │        int64         │        int64         │
# ├────────────┼──────────────────────┼───┼──────────────────────┼──────────────────────┼──────────────────────┤
# │    5872184 │ ibm                  │ … │ linkedin.com/compa…  │               274047 │               716906 │
# │    4425416 │ tata consultancy s…  │ … │ linkedin.com/compa…  │               190771 │               341369 │
# │      21074 │ accenture            │ … │ linkedin.com/compa…  │               190689 │               455768 │
# │    2309813 │ us army              │ … │ linkedin.com/compa…  │               162163 │               445958 │
# │    1558607 │ ey                   │ … │ linkedin.com/compa…  │               158363 │               428960 │
# │    3844889 │ hewlett-packard      │ … │ linkedin.com/compa…  │               127952 │               412952 │
# │    2959148 │ cognizant technolo…  │ … │ linkedin.com/compa…  │               122031 │               210020 │
# │    5944912 │ walmart              │ … │ linkedin.com/compa…  │               120753 │               272827 │
# │    3727010 │ microsoft            │ … │ linkedin.com/compa…  │               116196 │               276983 │
# │    3300741 │ at&t                 │ … │ linkedin.com/compa…  │               115188 │               269659 │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │    4782764 │ jönköpings kommun    │ … │ linkedin.com/compa…  │                 1118 │                 1964 │
# │    3432133 │ jmc projects india…  │ … │ linkedin.com/compa…  │                 1118 │                 2112 │
# │     910050 │ öbb                  │ … │ linkedin.com/compa…  │                 1118 │                 1546 │
# │    6444131 │ vaillant group       │ … │ linkedin.com/compa…  │                 1118 │                 2540 │
# │     916799 │ embracon administr…  │ … │ linkedin.com/compa…  │                 1118 │                 2240 │
# │    3585785 │ university of chic…  │ … │ linkedin.com/compa…  │                 1118 │                 3220 │
# │    2583172 │ pantaloon retail i…  │ … │ linkedin.com/compa…  │                 1118 │                 4723 │
# │    1406043 │ nv energy            │ … │ linkedin.com/compa…  │                 1118 │                 1834 │
# │     955441 │ mining               │ … │ linkedin.com/compa…  │                 1118 │                 1421 │
# │    5571765 │ university of stir…  │ … │ linkedin.com/compa…  │                 1118 │                 2680 │
# ├────────────┴──────────────────────┴───┴──────────────────────┴──────────────────────┴──────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                         11 columns (5 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
company_data_df = con.table("company_data").df()

company_data_df
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...                               ...           ...
# 7173421         certiportvouchers.com        2011.0
# 7173422            blacktigerclub.com        2006.0
# 7173423                          None           NaN
# 7173424                          None           NaN
# 7173425  dynamiccontrolssolutions.com           NaN
#
#                                     industry size range  \
# 0        information technology and services     10001+
# 1        information technology and services     10001+
# 2        information technology and services     10001+
# 3                                   military     10001+
# 4                                 accounting     10001+
# ...                                      ...        ...
# 7173421  information technology and services     1 - 10
# 7173422         health, wellness and fitness     1 - 10
# 7173423               religious institutions     1 - 10
# 7173424                             research     1 - 10
# 7173425                           automotive     1 - 10
#
#                                        locality         country  \
# 0             new york, new york, united states   united states
# 1                    bombay, maharashtra, india           india
# 2                       dublin, dublin, ireland         ireland
# 3           alexandria, virginia, united states   united states
# 4        london, greater london, united kingdom  united kingdom
# ...                                         ...             ...
# 7173421                                    None            None
# 7173422                  peking, beijing, china           china
# 7173423      inverness, illinois, united states   united states
# 7173424          london, london, united kingdom  united kingdom
# 7173425          wixom, michigan, united states   united states
#
#                                               linkedin url  \
# 0                                 linkedin.com/company/ibm
# 1           linkedin.com/company/tata-consultancy-services
# 2                           linkedin.com/company/accenture
# 3                             linkedin.com/company/us-army
# 4                       linkedin.com/company/ernstandyoung
# ...                                                    ...
# 7173421            linkedin.com/company/certiport-vouchers
# 7173422         linkedin.com/company/black-tiger-club-hero
# 7173423    linkedin.com/company/catholic-bishop-of-chicago
# 7173424           linkedin.com/company/medexo-robotics-ltd
# 7173425  linkedin.com/company/dynamic-controls-solution...
#
#          current employee estimate  total employee estimate
# 0                           274047                   716906
# 1                           190771                   341369
# 2                           190689                   455768
# 3                           162163                   445958
# 4                           158363                   428960
# ...                            ...                      ...
# 7173421                          0                        1
# 7173422                          0                        6
# 7173423                          0                        1
# 7173424                          0                        2
# 7173425                          0                        1
#
# [7173426 rows x 11 columns]

# %% [markdown]
# ## 1.3. Companies' CEOs: a Web Table
#
# Now we need to figure out who the CEOs are for corporations.  One place to look is Wikipedia, which has an HTML table describing the CEOs.
#
# https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs
#
# Pandas actually makes it easy to read HTML tables...

# %%
# Now let's read an HTML table!

company_ceos_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs')[1]

company_ceos_df
# Out:
#                 Company             Executive                           Title  \
# 0             Accenture           Julie Sweet                          CEO[1]
# 1    Aditya Birla Group  Kumar Mangalam Birla                     Chairman[2]
# 2         Adobe Systems      Shantanu Narayen  Chairman, president and CEO[3]
# 3                Airbus       Guillaume Faury                          CEO[4]
# 4               Alibaba              Eddie Wu             Director and CEO[5]
# ..                  ...                   ...                             ...
# 130     Warner Brothers           Ann Sarnoff         Chairwoman and CEO[122]
# 131         WarnerMedia           Jason Kilar                        CEO[123]
# 132         Wells Fargo        Charles Scharf          CEO and president[124]
# 133  Whole Foods Market           John Mackey                        CEO[125]
# 134        Zillow Group           Rich Barton                        CEO[126]
#
#        Since                                              Notes     Updated
# 0       2019                    Succeeded Pierre Nanterme, died  2019-01-31
# 1    1995[2]   Part of the Birla family business house in India  2018-10-01
# 2       2007                                Formerly with Apple  2018-10-01
# 3       2012                            Succeeded Louis Gallois  2017-11-14
# 4    2023[6]                                                NaN  2024-07-19
# ..       ...                                                ...         ...
# 130     2019  First woman to hold the position at the compan...  2019-10-10
# 131     2020                    Previously with Hulu and Amazon  2020-11-19
# 132     2019              Succeeded John Stumpf, previously COO         NaN
# 133     1980                                         Co-founder  2017-11-11
# 134     2019  Co-founder and previously was Zillow's CEO for...  2018-12-10
#
# [135 rows x 6 columns]

# %%
con.sql('create table if not exists company_ceos as select * from company_ceos_df')

con.table('company_ceos').show()
# Out:
# ┌──────────────────────┬──────────────────────┬──────────────────────┬─────────┬──────────────────────────┬────────────┐
# │       Company        │      Executive       │        Title         │  Since  │          Notes           │  Updated   │
# │       varchar        │       varchar        │       varchar        │ varchar │         varchar          │  varchar   │
# ├──────────────────────┼──────────────────────┼──────────────────────┼─────────┼──────────────────────────┼────────────┤
# │ Accenture            │ Julie Sweet          │ CEO[1]               │ 2019    │ Succeeded Pierre Nante…  │ 2019-01-31 │
# │ Aditya Birla Group   │ Kumar Mangalam Birla │ Chairman[2]          │ 1995[2] │ Part of the Birla fami…  │ 2018-10-01 │
# │ Adobe Systems        │ Shantanu Narayen     │ Chairman, presiden…  │ 2007    │ Formerly with Apple      │ 2018-10-01 │
# │ Airbus               │ Guillaume Faury      │ CEO[4]               │ 2012    │ Succeeded Louis Gallois  │ 2017-11-14 │
# │ Alibaba              │ Eddie Wu             │ Director and CEO[5]  │ 2023[6] │ NULL                     │ 2024-07-19 │
# │ Amazon               │ Andy Jassy           │ CEO and president[7] │ 2021    │ NULL                     │ NULL       │
# │ Advanced Micro Dev…  │ Lisa Su              │ CEO and president[8] │ 2014    │ Formerly with Texas In…  │ 2018-10-01 │
# │ American Express     │ Stephen Squeri       │ Chairman and CEO[9]  │ 2018    │ Former vice chairman o…  │ 2018-10-01 │
# │ Anthem               │ Joseph R. Swedish    │ Chairman, presiden…  │ 2013    │ Previously with Centur…  │ 2018-10-01 │
# │ Apple                │ Tim Cook             │ CEO[11]              │ 2011    │ Replaced Steve Jobs      │ 2018-10-01 │
# │   ·                  │    ·                 │    ·                 │  ·      │          ·               │     ·      │
# │   ·                  │    ·                 │    ·                 │  ·      │          ·               │     ·      │
# │   ·                  │    ·                 │    ·                 │  ·      │          ·               │     ·      │
# │ Vodafone             │ Vittorio Colao       │ CEO[117]             │ 2008    │ Also director at Unile…  │ 2017-11-11 │
# │ Volkswagen Group     │ Herbert Diess        │ Chairman of the ma…  │ 2018    │ Succeeded Matthias Mül…  │ 2017-11-11 │
# │ Walt Disney Company  │ Robert Iger          │ CEO[119]             │ 2022    │ Previously led Disney …  │ 2020-03-02 │
# │ Walgreens Boots Al…  │ Stefano Pessina      │ Executive vice cha…  │ 2015    │ Holding company of Wal…  │ 2017-11-11 │
# │ Walmart              │ Doug McMillon        │ President and CEO[…  │ 2014    │ Previously lead for Sa…  │ 2017-11-11 │
# │ Warner Brothers      │ Ann Sarnoff          │ Chairwoman and CEO…  │ 2019    │ First woman to hold th…  │ 2019-10-10 │
# │ WarnerMedia          │ Jason Kilar          │ CEO[123]             │ 2020    │ Previously with Hulu a…  │ 2020-11-19 │
# │ Wells Fargo          │ Charles Scharf       │ CEO and president[…  │ 2019    │ Succeeded John Stumpf,…  │ NULL       │
# │ Whole Foods Market   │ John Mackey          │ CEO[125]             │ 1980    │ Co-founder               │ 2017-11-11 │
# │ Zillow Group         │ Rich Barton          │ CEO[126]             │ 2019    │ Co-founder and previou…  │ 2018-12-10 │
# ├──────────────────────┴──────────────────────┴──────────────────────┴─────────┴──────────────────────────┴────────────┤
# │ 135 rows (20 shown)                                                                                        6 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 1.4. The Problem Gets Harder... Extracting Fields from Tagged Data on the Web
#
# So far we have companies and CEOs.  But we don't have information on how old the CEOs are!
#
# For a solution, we're going to go back to Wikipedia -- this time looking at the web pages for the CEOs!
#
# This involves "crawling" the CEO pages, and "scraping" the relevant content.  In other words we have to do *information extraction*.  For this particular problem, we will do extraction over very regular parts of Wikipedia.
#
# We'll start by constructing a list of CEO web pages, from the Company CEO dataframe above.  For this, we need to take the names and do a bit of tweaking, for example adding underscores instead of spaces.
#
# (Later we'll see how to do this over more free-form text.)

# %%
crawl_list = []

for executive in company_ceos_df['Executive']:
  crawl_list.append('https://en.wikipedia.org/wiki/' + executive.replace(' ', '_'))

crawl_list
# Out:
# ['https://en.wikipedia.org/wiki/Julie_Sweet',
#  'https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla',
#  'https://en.wikipedia.org/wiki/Shantanu_Narayen',
#  'https://en.wikipedia.org/wiki/Guillaume_Faury',
#  'https://en.wikipedia.org/wiki/Eddie_Wu',
#  'https://en.wikipedia.org/wiki/Andy_Jassy',
#  'https://en.wikipedia.org/wiki/Lisa_Su',
#  'https://en.wikipedia.org/wiki/Stephen_Squeri',
#  'https://en.wikipedia.org/wiki/Joseph_R._Swedish',
#  'https://en.wikipedia.org/wiki/Tim_Cook',
#  'https://en.wikipedia.org/wiki/Lakshmi_Niwas_Mittal',
#  'https://en.wikipedia.org/wiki/John_Stankey',
#  'https://en.wikipedia.org/wiki/Charles_Woodburn',
#  'https://en.wikipedia.org/wiki/Tapan_Singhel',
#  'https://en.wikipedia.org/wiki/Carlos_Torres_Vila',
#  'https://en.wikipedia.org/wiki/Brian_Moynihan',
#  'https://en.wikipedia.org/wiki/C.S._Venkatakrishnan',
#  'https://en.wikipedia.org/wiki/Warren_Buffett',
#  'https://en.wikipedia.org/wiki/Hubert_Joly',
#  'https://en.wikipedia.org/wiki/Sunil_Bharti_Mittal',
#  'https://en.wikipedia.org/wiki/Stephen_A._Schwarzman',
#  'https://en.wikipedia.org/wiki/Mike_Henry',
#  'https://en.wikipedia.org/wiki/Oliver_Zipse',
#  'https://en.wikipedia.org/wiki/Dave_Calhoun',
#  'https://en.wikipedia.org/wiki/Rich_Lesser',
#  'https://en.wikipedia.org/wiki/Bob_Dudley',
#  'https://en.wikipedia.org/wiki/Hock_Tan',
#  'https://en.wikipedia.org/wiki/Denise_Morrison',
#  'https://en.wikipedia.org/wiki/Mark_Shuttleworth',
#  'https://en.wikipedia.org/wiki/Richard_Fairbank',
#  'https://en.wikipedia.org/wiki/Jim_Umpleby',
#  'https://en.wikipedia.org/wiki/Evan_Greenberg',
#  'https://en.wikipedia.org/wiki/Chuck_Robbins',
#  'https://en.wikipedia.org/wiki/Jane_Fraser',
#  'https://en.wikipedia.org/wiki/James_Quincey',
#  'https://en.wikipedia.org/wiki/Brian_L._Roberts',
#  'https://en.wikipedia.org/wiki/Thomas_Gottstein',
#  'https://en.wikipedia.org/wiki/Ola_Källenius',
#  'https://en.wikipedia.org/wiki/Michael_Dell',
#  'https://en.wikipedia.org/wiki/Ed_Bastian',
#  'https://en.wikipedia.org/wiki/Christian_Sewing',
#  'https://en.wikipedia.org/wiki/Tobias_Meyer',
#  'https://en.wikipedia.org/wiki/Edward_D._Breen',
#  'https://en.wikipedia.org/wiki/Devin_Wenig',
#  'https://en.wikipedia.org/wiki/Börje_Ekholm',
#  'https://en.wikipedia.org/wiki/Darren_Woods',
#  'https://en.wikipedia.org/wiki/Carmine_Di_Sibio',
#  'https://en.wikipedia.org/wiki/Mark_Zuckerberg',
#  'https://en.wikipedia.org/wiki/Frederick_W._Smith',
#  'https://en.wikipedia.org/wiki/Sergio_Marchionne',
#  'https://en.wikipedia.org/wiki/Abigail_Johnson',
#  'https://en.wikipedia.org/wiki/James_Hackett',
#  'https://en.wikipedia.org/wiki/Terry_Gou',
#  'https://en.wikipedia.org/wiki/Lachlan_Murdoch',
#  'https://en.wikipedia.org/wiki/Phebe_Novakovic',
#  'https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.',
#  'https://en.wikipedia.org/wiki/Mary_T._Barra',
#  'https://en.wikipedia.org/wiki/Emma_Walmsley',
#  'https://en.wikipedia.org/wiki/David_M._Solomon',
#  'https://en.wikipedia.org/wiki/Sundar_Pichai',
#  'https://en.wikipedia.org/wiki/C_Vijayakumar',
#  'https://en.wikipedia.org/wiki/Antonio_Neri',
#  'https://en.wikipedia.org/wiki/Darius_Adamczyk',
#  'https://en.wikipedia.org/wiki/Noel_Quinn',
#  'https://en.wikipedia.org/wiki/Arvind_Krishna',
#  'https://en.wikipedia.org/wiki/Salil_Parekh',
#  'https://en.wikipedia.org/wiki/Pat_Gelsinger',
#  'https://en.wikipedia.org/wiki/James_Dimon',
#  'https://en.wikipedia.org/wiki/Pieter_Elbers',
#  'https://en.wikipedia.org/wiki/Charles_G._Koch',
#  'https://en.wikipedia.org/wiki/Marillyn_Hewson',
#  'https://en.wikipedia.org/wiki/Steve_Rowe',
#  'https://en.wikipedia.org/wiki/Chris_Kempczinski',
#  'https://en.wikipedia.org/wiki/Bob_Sternfels',
#  'https://en.wikipedia.org/wiki/Steven_A._Kandarian',
#  'https://en.wikipedia.org/wiki/Isaac_Larian',
#  'https://en.wikipedia.org/wiki/Satya_Nadella',
#  'https://en.wikipedia.org/wiki/James_P._Gorman',
#  'https://en.wikipedia.org/wiki/Jeff_Shell',
#  'https://en.wikipedia.org/wiki/Robert_James_Thomson',
#  'https://en.wikipedia.org/wiki/Mark_Thompson',
#  'https://en.wikipedia.org/wiki/Mark_Parker',
#  'https://en.wikipedia.org/wiki/Pekka_Lundmark',
#  'https://en.wikipedia.org/wiki/Vasant_Narasimhan',
#  'https://en.wikipedia.org/wiki/Tatsumi_Kimishima',
#  'https://en.wikipedia.org/wiki/Safra_Catz',
#  'https://en.wikipedia.org/wiki/Mark_Hurd',
#  'https://en.wikipedia.org/wiki/Ramon_Laguarta',
#  'https://en.wikipedia.org/wiki/Albert_Bourla',
#  'https://en.wikipedia.org/wiki/David_S._Taylor',
#  'https://en.wikipedia.org/wiki/John_Strangfeld',
#  'https://en.wikipedia.org/wiki/Alan_Joyce',
#  'https://en.wikipedia.org/wiki/Anil_Ambani',
#  'https://en.wikipedia.org/wiki/Mukesh_Ambani',
#  'https://en.wikipedia.org/wiki/Luca_de_Meo',
#  'https://en.wikipedia.org/wiki/David_I._McKay',
#  'https://en.wikipedia.org/wiki/Ross_McEwan',
#  'https://en.wikipedia.org/wiki/Ben_van_Beurden',
#  "https://en.wikipedia.org/wiki/Michael_O'Leary",
#  'https://en.wikipedia.org/wiki/Douglas_L._Peterson',
#  'https://en.wikipedia.org/wiki/Oh-Hyun_Kwon',
#  'https://en.wikipedia.org/wiki/Christian_Klein',
#  'https://en.wikipedia.org/wiki/Herbert_Fisk_Johnson_III',
#  'https://en.wikipedia.org/wiki/Jean-Pascal_Tricoire',
#  'https://en.wikipedia.org/wiki/Peter_Harrison',
#  'https://en.wikipedia.org/wiki/Chua_Sock_Koong',
#  'https://en.wikipedia.org/wiki/Masayoshi_Son',
#  'https://en.wikipedia.org/wiki/Tony_Aquila',
#  'https://en.wikipedia.org/wiki/Robert_E._Jordan',
#  'https://en.wikipedia.org/wiki/J._Clifford_Hudson',
#  'https://en.wikipedia.org/wiki/Laxman_Narasimhan',
#  'https://en.wikipedia.org/wiki/Raymond_Kwok',
#  'https://en.wikipedia.org/wiki/William_H._Rogers_Jr.',
#  'https://en.wikipedia.org/wiki/Brian_Cornell',
#  'https://en.wikipedia.org/wiki/Rajesh_Gopinathan',
#  'https://en.wikipedia.org/wiki/Li_Dongsheng',
#  'https://en.wikipedia.org/wiki/Andy_Penn',
#  'https://en.wikipedia.org/wiki/Dave_Lewis',
#  'https://en.wikipedia.org/wiki/Elon_Musk',
#  'https://en.wikipedia.org/wiki/Alan_D._Schnitzer',
#  'https://en.wikipedia.org/wiki/Akio_Toyoda',
#  'https://en.wikipedia.org/wiki/Scott_Kirby',
#  'https://en.wikipedia.org/wiki/Ralph_Hamers',
#  'https://en.wikipedia.org/wiki/Hans_Vestberg',
#  'https://en.wikipedia.org/wiki/Robert_Bakish',
#  'https://en.wikipedia.org/wiki/Vittorio_Colao',
#  'https://en.wikipedia.org/wiki/Herbert_Diess',
#  'https://en.wikipedia.org/wiki/Robert_Iger',
#  'https://en.wikipedia.org/wiki/Stefano_Pessina',
#  'https://en.wikipedia.org/wiki/Doug_McMillon',
#  'https://en.wikipedia.org/wiki/Ann_Sarnoff',
#  'https://en.wikipedia.org/wiki/Jason_Kilar',
#  'https://en.wikipedia.org/wiki/Charles_Scharf',
#  'https://en.wikipedia.org/wiki/John_Mackey',
#  'https://en.wikipedia.org/wiki/Rich_Barton']

# %%
# Use urllib.urlopen to crawl all pages in crawl_list, and store the response of the page
# in list pages

pages = []

for url in crawl_list:
    page = url.split("/")[-1] #extract the person name at the end of the url

    # An issue: some of the accent characters won't work.  We need to convert them
    # into an HTML URL.  We'll split the URL, then use "parse.quote" to change
    # the structure, then re-form the URL
    url_list = list(urllib.parse.urlsplit(url))
    url_list[2] = urllib.parse.quote(url_list[2])
    url_ascii = urllib.parse.urlunsplit(url_list)
    try:
      response = urllib.request.urlopen((url_ascii))
      #Save page and url for later use.
      pages.append(response)
    except urllib.error.URLError as e:
      print(e.reason)

# %% [markdown]
# ## 1.5. Crawling: Populating the Table with Executives

# %%
# Use lxml.etree.HTML(...) on the HTML content of each page to get a DOM tree that
# can be processed via XPath to extract the bday information.  Store the CEO name,
# webpage, and the birthdate (born) in exec_df.

# We first check that the HTML content has a table of type `vcard`,
# and then extract the `bday` information.  If there is no birthdate, the datetime
# value is NaT (not a type).

from lxml import etree

rows = []
for page in pages:
  url = page.geturl()
  print (url)
  content = page.read().decode("utf-8")
  tree = etree.HTML(content)  #create a DOM tree of the page
  bday = tree.xpath('//table[contains(@class,"vcard")]//span[@class="bday"]/text()')
  if len(bday) > 0:
      name = url[url.rfind('/')+1:] # The part of the URL after the last /
      rows.append({'name': name, 'page': url,
                  'born': datetime.datetime.strptime(bday[0], '%Y-%m-%d')})
  else:
          rows.append({'name': url[url.rfind('/')+1:], 'page': url
                                    , 'born': np.datetime64('NaT')})

exec_df = pd.DataFrame(rows)
exec_df
# Out:
# https://en.wikipedia.org/wiki/Julie_Sweet
# https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# https://en.wikipedia.org/wiki/Shantanu_Narayen
# https://en.wikipedia.org/wiki/Guillaume_Faury
# https://en.wikipedia.org/wiki/Eddie_Wu
# https://en.wikipedia.org/wiki/Andy_Jassy
# https://en.wikipedia.org/wiki/Lisa_Su
# https://en.wikipedia.org/wiki/Stephen_Squeri
# https://en.wikipedia.org/wiki/Joseph_R._Swedish
# https://en.wikipedia.org/wiki/Tim_Cook
# https://en.wikipedia.org/wiki/Lakshmi_Niwas_Mittal
# https://en.wikipedia.org/wiki/John_Stankey
# https://en.wikipedia.org/wiki/Charles_Woodburn
# https://en.wikipedia.org/wiki/Tapan_Singhel
# https://en.wikipedia.org/wiki/Carlos_Torres_Vila
# https://en.wikipedia.org/wiki/Brian_Moynihan
# https://en.wikipedia.org/wiki/C.S._Venkatakrishnan
# https://en.wikipedia.org/wiki/Warren_Buffett
# https://en.wikipedia.org/wiki/Hubert_Joly
# https://en.wikipedia.org/wiki/Sunil_Bharti_Mittal
# https://en.wikipedia.org/wiki/Stephen_A._Schwarzman
# https://en.wikipedia.org/wiki/Mike_Henry
# https://en.wikipedia.org/wiki/Oliver_Zipse
# https://en.wikipedia.org/wiki/Dave_Calhoun
# https://en.wikipedia.org/wiki/Rich_Lesser
# https://en.wikipedia.org/wiki/Bob_Dudley
# https://en.wikipedia.org/wiki/Hock_Tan
# https://en.wikipedia.org/wiki/Denise_Morrison
# https://en.wikipedia.org/wiki/Mark_Shuttleworth
# https://en.wikipedia.org/wiki/Richard_Fairbank
# https://en.wikipedia.org/wiki/Jim_Umpleby
# https://en.wikipedia.org/wiki/Evan_Greenberg
# https://en.wikipedia.org/wiki/Chuck_Robbins
# https://en.wikipedia.org/wiki/Jane_Fraser
# https://en.wikipedia.org/wiki/James_Quincey
# https://en.wikipedia.org/wiki/Brian_L._Roberts
# https://en.wikipedia.org/wiki/Thomas_Gottstein
# https://en.wikipedia.org/wiki/Ola_K%C3%A4llenius
# https://en.wikipedia.org/wiki/Michael_Dell
# https://en.wikipedia.org/wiki/Ed_Bastian
# https://en.wikipedia.org/wiki/Christian_Sewing
# https://en.wikipedia.org/wiki/Tobias_Meyer
# https://en.wikipedia.org/wiki/Edward_D._Breen
# https://en.wikipedia.org/wiki/Devin_Wenig
# https://en.wikipedia.org/wiki/B%C3%B6rje_Ekholm
# https://en.wikipedia.org/wiki/Darren_Woods
# https://en.wikipedia.org/wiki/Carmine_Di_Sibio
# https://en.wikipedia.org/wiki/Mark_Zuckerberg
# https://en.wikipedia.org/wiki/Frederick_W._Smith
# https://en.wikipedia.org/wiki/Sergio_Marchionne
# https://en.wikipedia.org/wiki/Abigail_Johnson
# https://en.wikipedia.org/wiki/James_Hackett
# https://en.wikipedia.org/wiki/Terry_Gou
# https://en.wikipedia.org/wiki/Lachlan_Murdoch
# https://en.wikipedia.org/wiki/Phebe_Novakovic
# https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.
# https://en.wikipedia.org/wiki/Mary_T._Barra
# https://en.wikipedia.org/wiki/Emma_Walmsley
# https://en.wikipedia.org/wiki/David_M._Solomon
# https://en.wikipedia.org/wiki/Sundar_Pichai
# https://en.wikipedia.org/wiki/C_Vijayakumar
# https://en.wikipedia.org/wiki/Antonio_Neri
# https://en.wikipedia.org/wiki/Darius_Adamczyk
# https://en.wikipedia.org/wiki/Noel_Quinn
# https://en.wikipedia.org/wiki/Arvind_Krishna
# https://en.wikipedia.org/wiki/Salil_Parekh
# https://en.wikipedia.org/wiki/Pat_Gelsinger
# https://en.wikipedia.org/wiki/James_Dimon
# https://en.wikipedia.org/wiki/Pieter_Elbers
# https://en.wikipedia.org/wiki/Charles_G._Koch
# https://en.wikipedia.org/wiki/Marillyn_Hewson
# https://en.wikipedia.org/wiki/Steve_Rowe
# https://en.wikipedia.org/wiki/Chris_Kempczinski
# https://en.wikipedia.org/wiki/Bob_Sternfels
# https://en.wikipedia.org/wiki/Steven_A._Kandarian
# https://en.wikipedia.org/wiki/Isaac_Larian
# https://en.wikipedia.org/wiki/Satya_Nadella
# https://en.wikipedia.org/wiki/James_P._Gorman
# https://en.wikipedia.org/wiki/Jeff_Shell
# https://en.wikipedia.org/wiki/Robert_James_Thomson
# https://en.wikipedia.org/wiki/Mark_Thompson
# https://en.wikipedia.org/wiki/Mark_Parker
# https://en.wikipedia.org/wiki/Pekka_Lundmark
# https://en.wikipedia.org/wiki/Vasant_Narasimhan
# https://en.wikipedia.org/wiki/Tatsumi_Kimishima
# https://en.wikipedia.org/wiki/Safra_Catz
# https://en.wikipedia.org/wiki/Mark_Hurd
# https://en.wikipedia.org/wiki/Ramon_Laguarta
# https://en.wikipedia.org/wiki/Albert_Bourla
# https://en.wikipedia.org/wiki/David_S._Taylor
# https://en.wikipedia.org/wiki/John_Strangfeld
# https://en.wikipedia.org/wiki/Alan_Joyce
# https://en.wikipedia.org/wiki/Anil_Ambani
# https://en.wikipedia.org/wiki/Mukesh_Ambani
# https://en.wikipedia.org/wiki/Luca_de_Meo
# https://en.wikipedia.org/wiki/David_I._McKay
# https://en.wikipedia.org/wiki/Ross_McEwan
# https://en.wikipedia.org/wiki/Ben_van_Beurden
# https://en.wikipedia.org/wiki/Michael_O%27Leary
# https://en.wikipedia.org/wiki/Douglas_L._Peterson
# https://en.wikipedia.org/wiki/Oh-Hyun_Kwon
# https://en.wikipedia.org/wiki/Christian_Klein
# https://en.wikipedia.org/wiki/Herbert_Fisk_Johnson_III
# https://en.wikipedia.org/wiki/Jean-Pascal_Tricoire
# https://en.wikipedia.org/wiki/Peter_Harrison
# https://en.wikipedia.org/wiki/Chua_Sock_Koong
# https://en.wikipedia.org/wiki/Masayoshi_Son
# https://en.wikipedia.org/wiki/Tony_Aquila
# https://en.wikipedia.org/wiki/Robert_E._Jordan
# https://en.wikipedia.org/wiki/J._Clifford_Hudson
# https://en.wikipedia.org/wiki/Laxman_Narasimhan
# https://en.wikipedia.org/wiki/Raymond_Kwok
# https://en.wikipedia.org/wiki/William_H._Rogers_Jr.
# https://en.wikipedia.org/wiki/Brian_Cornell
# https://en.wikipedia.org/wiki/Rajesh_Gopinathan
# https://en.wikipedia.org/wiki/Li_Dongsheng
# https://en.wikipedia.org/wiki/Andy_Penn
# https://en.wikipedia.org/wiki/Dave_Lewis
# https://en.wikipedia.org/wiki/Elon_Musk
# https://en.wikipedia.org/wiki/Alan_D._Schnitzer
# https://en.wikipedia.org/wiki/Akio_Toyoda
# https://en.wikipedia.org/wiki/Scott_Kirby
# https://en.wikipedia.org/wiki/Ralph_Hamers
# https://en.wikipedia.org/wiki/Hans_Vestberg
# https://en.wikipedia.org/wiki/Robert_Bakish
# https://en.wikipedia.org/wiki/Vittorio_Colao
# https://en.wikipedia.org/wiki/Herbert_Diess
# https://en.wikipedia.org/wiki/Robert_Iger
# https://en.wikipedia.org/wiki/Stefano_Pessina
# https://en.wikipedia.org/wiki/Doug_McMillon
# https://en.wikipedia.org/wiki/Ann_Sarnoff
# https://en.wikipedia.org/wiki/Jason_Kilar
# https://en.wikipedia.org/wiki/Charles_Scharf
# https://en.wikipedia.org/wiki/John_Mackey
# https://en.wikipedia.org/wiki/Rich_Barton
#                      name                                               page  \
# 0             Julie_Sweet          https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_B...
# 2        Shantanu_Narayen     https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury      https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu             https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                ...
# 130           Ann_Sarnoff          https://en.wikipedia.org/wiki/Ann_Sarnoff
# 131           Jason_Kilar          https://en.wikipedia.org/wiki/Jason_Kilar
# 132        Charles_Scharf       https://en.wikipedia.org/wiki/Charles_Scharf
# 133           John_Mackey          https://en.wikipedia.org/wiki/John_Mackey
# 134           Rich_Barton          https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born
# 0                    NaT
# 1    1967-06-14 00:00:00
# 2    1963-05-27 00:00:00
# 3    1968-02-22 00:00:00
# 4                    NaT
# ..                   ...
# 130                  NaT
# 131  1971-04-26 00:00:00
# 132  1965-04-24 00:00:00
# 133                  NaT
# 134                  NaT
#
# [135 rows x 3 columns]

# %%
con.sql('create table if not exists executives as select * from exec_df')

con.table('executives').show()
# Out:
# ┌──────────────────────┬────────────────────────────────────────────────────┬─────────────────────┐
# │         name         │                        page                        │        born         │
# │       varchar        │                      varchar                       │      timestamp      │
# ├──────────────────────┼────────────────────────────────────────────────────┼─────────────────────┤
# │ Julie_Sweet          │ https://en.wikipedia.org/wiki/Julie_Sweet          │ NULL                │
# │ Kumar_Mangalam_Birla │ https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla │ 1967-06-14 00:00:00 │
# │ Shantanu_Narayen     │ https://en.wikipedia.org/wiki/Shantanu_Narayen     │ 1963-05-27 00:00:00 │
# │ Guillaume_Faury      │ https://en.wikipedia.org/wiki/Guillaume_Faury      │ 1968-02-22 00:00:00 │
# │ Eddie_Wu             │ https://en.wikipedia.org/wiki/Eddie_Wu             │ NULL                │
# │ Andy_Jassy           │ https://en.wikipedia.org/wiki/Andy_Jassy           │ 1968-01-13 00:00:00 │
# │ Lisa_Su              │ https://en.wikipedia.org/wiki/Lisa_Su              │ 1969-11-07 00:00:00 │
# │ Stephen_Squeri       │ https://en.wikipedia.org/wiki/Stephen_Squeri       │ NULL                │
# │ Joseph_R._Swedish    │ https://en.wikipedia.org/wiki/Joseph_R._Swedish    │ 1951-05-17 00:00:00 │
# │ Tim_Cook             │ https://en.wikipedia.org/wiki/Tim_Cook             │ 1960-11-01 00:00:00 │
# │    ·                 │                   ·                                │          ·          │
# │    ·                 │                   ·                                │          ·          │
# │    ·                 │                   ·                                │          ·          │
# │ Vittorio_Colao       │ https://en.wikipedia.org/wiki/Vittorio_Colao       │ 1961-10-03 00:00:00 │
# │ Herbert_Diess        │ https://en.wikipedia.org/wiki/Herbert_Diess        │ 1958-10-24 00:00:00 │
# │ Robert_Iger          │ https://en.wikipedia.org/wiki/Robert_Iger          │ 1951-02-10 00:00:00 │
# │ Stefano_Pessina      │ https://en.wikipedia.org/wiki/Stefano_Pessina      │ 1941-06-04 00:00:00 │
# │ Doug_McMillon        │ https://en.wikipedia.org/wiki/Doug_McMillon        │ 1966-10-17 00:00:00 │
# │ Ann_Sarnoff          │ https://en.wikipedia.org/wiki/Ann_Sarnoff          │ NULL                │
# │ Jason_Kilar          │ https://en.wikipedia.org/wiki/Jason_Kilar          │ 1971-04-26 00:00:00 │
# │ Charles_Scharf       │ https://en.wikipedia.org/wiki/Charles_Scharf       │ 1965-04-24 00:00:00 │
# │ John_Mackey          │ https://en.wikipedia.org/wiki/John_Mackey          │ NULL                │
# │ Rich_Barton          │ https://en.wikipedia.org/wiki/Rich_Barton          │ NULL                │
# ├──────────────────────┴────────────────────────────────────────────────────┴─────────────────────┤
# │ 135 rows (20 shown)                                                                   3 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# # 2.0 Data Transformation and Querying
#
# Looking at our data to clean via *projection*...
#
# Generally, we can extract one "narrower" table form another by using **double brackets**.

# %%
# Let's take a look at the data.  Here's a way of PROJECTING the exec_df dataframe into
# a smaller table

exec_df[['name', 'born']]
# Out:
#                      name                 born
# 0             Julie_Sweet                  NaT
# 1    Kumar_Mangalam_Birla  1967-06-14 00:00:00
# 2        Shantanu_Narayen  1963-05-27 00:00:00
# 3         Guillaume_Faury  1968-02-22 00:00:00
# 4                Eddie_Wu                  NaT
# ..                    ...                  ...
# 130           Ann_Sarnoff                  NaT
# 131           Jason_Kilar  1971-04-26 00:00:00
# 132        Charles_Scharf  1965-04-24 00:00:00
# 133           John_Mackey                  NaT
# 134           Rich_Barton                  NaT
#
# [135 rows x 2 columns]

# %%
# In SQL it's SELECT with the fields FROM the table
con.sql('select name, born from executives')
# Out:
# ┌──────────────────────┬─────────────────────┐
# │         name         │        born         │
# │       varchar        │      timestamp      │
# ├──────────────────────┼─────────────────────┤
# │ Julie_Sweet          │ NULL                │
# │ Kumar_Mangalam_Birla │ 1967-06-14 00:00:00 │
# │ Shantanu_Narayen     │ 1963-05-27 00:00:00 │
# │ Guillaume_Faury      │ 1968-02-22 00:00:00 │
# │ Eddie_Wu             │ NULL                │
# │ Andy_Jassy           │ 1968-01-13 00:00:00 │
# │ Lisa_Su              │ 1969-11-07 00:00:00 │
# │ Stephen_Squeri       │ NULL                │
# │ Joseph_R._Swedish    │ 1951-05-17 00:00:00 │
# │ Tim_Cook             │ 1960-11-01 00:00:00 │
# │    ·                 │          ·          │
# │    ·                 │          ·          │
# │    ·                 │          ·          │
# │ Vittorio_Colao       │ 1961-10-03 00:00:00 │
# │ Herbert_Diess        │ 1958-10-24 00:00:00 │
# │ Robert_Iger          │ 1951-02-10 00:00:00 │
# │ Stefano_Pessina      │ 1941-06-04 00:00:00 │
# │ Doug_McMillon        │ 1966-10-17 00:00:00 │
# │ Ann_Sarnoff          │ NULL                │
# │ Jason_Kilar          │ 1971-04-26 00:00:00 │
# │ Charles_Scharf       │ 1965-04-24 00:00:00 │
# │ John_Mackey          │ NULL                │
# │ Rich_Barton          │ NULL                │
# ├──────────────────────┴─────────────────────┤
# │ 135 rows (20 shown)              2 columns │
# └────────────────────────────────────────────┘

# %%
# If I use single brackets, I can extract a single column as a Series.
exec_df['name']
# Out:
# 0               Julie_Sweet
# 1      Kumar_Mangalam_Birla
# 2          Shantanu_Narayen
# 3           Guillaume_Faury
# 4                  Eddie_Wu
#                ...
# 130             Ann_Sarnoff
# 131             Jason_Kilar
# 132          Charles_Scharf
# 133             John_Mackey
# 134             Rich_Barton
# Name: name, Length: 135, dtype: object

# %%
# We can use SQL over the dataframe OR here
duckdb.sql('select name from exec_df')
# Out:
# ┌──────────────────────┐
# │         name         │
# │       varchar        │
# ├──────────────────────┤
# │ Julie_Sweet          │
# │ Kumar_Mangalam_Birla │
# │ Shantanu_Narayen     │
# │ Guillaume_Faury      │
# │ Eddie_Wu             │
# │ Andy_Jassy           │
# │ Lisa_Su              │
# │ Stephen_Squeri       │
# │ Joseph_R._Swedish    │
# │ Tim_Cook             │
# │    ·                 │
# │    ·                 │
# │    ·                 │
# │ Vittorio_Colao       │
# │ Herbert_Diess        │
# │ Robert_Iger          │
# │ Stefano_Pessina      │
# │ Doug_McMillon        │
# │ Ann_Sarnoff          │
# │ Jason_Kilar          │
# │ Charles_Scharf       │
# │ John_Mackey          │
# │ Rich_Barton          │
# ├──────────────────────┤
# │ 135 rows (20 shown)  │
# └──────────────────────┘

# %%
# Notice anything awry?

for person in exec_df['name']:
    print (person)
# Out:
# Julie_Sweet
# Kumar_Mangalam_Birla
# Shantanu_Narayen
# Guillaume_Faury
# Eddie_Wu
# Andy_Jassy
# Lisa_Su
# Stephen_Squeri
# Joseph_R._Swedish
# Tim_Cook
# Lakshmi_Niwas_Mittal
# John_Stankey
# Charles_Woodburn
# Tapan_Singhel
# Carlos_Torres_Vila
# Brian_Moynihan
# C.S._Venkatakrishnan
# Warren_Buffett
# Hubert_Joly
# Sunil_Bharti_Mittal
# Stephen_A._Schwarzman
# Mike_Henry
# Oliver_Zipse
# Dave_Calhoun
# Rich_Lesser
# Bob_Dudley
# Hock_Tan
# Denise_Morrison
# Mark_Shuttleworth
# Richard_Fairbank
# Jim_Umpleby
# Evan_Greenberg
# Chuck_Robbins
# Jane_Fraser
# James_Quincey
# Brian_L._Roberts
# Thomas_Gottstein
# Ola_K%C3%A4llenius
# Michael_Dell
# Ed_Bastian
# Christian_Sewing
# Tobias_Meyer
# Edward_D._Breen
# Devin_Wenig
# B%C3%B6rje_Ekholm
# Darren_Woods
# Carmine_Di_Sibio
# Mark_Zuckerberg
# Frederick_W._Smith
# Sergio_Marchionne
# Abigail_Johnson
# James_Hackett
# Terry_Gou
# Lachlan_Murdoch
# Phebe_Novakovic
# H._Lawrence_Culp_Jr.
# Mary_T._Barra
# Emma_Walmsley
# David_M._Solomon
# Sundar_Pichai
# C_Vijayakumar
# Antonio_Neri
# Darius_Adamczyk
# Noel_Quinn
# Arvind_Krishna
# Salil_Parekh
# Pat_Gelsinger
# James_Dimon
# Pieter_Elbers
# Charles_G._Koch
# Marillyn_Hewson
# Steve_Rowe
# Chris_Kempczinski
# Bob_Sternfels
# Steven_A._Kandarian
# Isaac_Larian
# Satya_Nadella
# James_P._Gorman
# Jeff_Shell
# Robert_James_Thomson
# Mark_Thompson
# Mark_Parker
# Pekka_Lundmark
# Vasant_Narasimhan
# Tatsumi_Kimishima
# Safra_Catz
# Mark_Hurd
# Ramon_Laguarta
# Albert_Bourla
# David_S._Taylor
# John_Strangfeld
# Alan_Joyce
# Anil_Ambani
# Mukesh_Ambani
# Luca_de_Meo
# David_I._McKay
# Ross_McEwan
# Ben_van_Beurden
# Michael_O%27Leary
# Douglas_L._Peterson
# Oh-Hyun_Kwon
# Christian_Klein
# Herbert_Fisk_Johnson_III
# Jean-Pascal_Tricoire
# Peter_Harrison
# Chua_Sock_Koong
# Masayoshi_Son
# Tony_Aquila
# Robert_E._Jordan
# J._Clifford_Hudson
# Laxman_Narasimhan
# Raymond_Kwok
# William_H._Rogers_Jr.
# Brian_Cornell
# Rajesh_Gopinathan
# Li_Dongsheng
# Andy_Penn
# Dave_Lewis
# Elon_Musk
# Alan_D._Schnitzer
# Akio_Toyoda
# Scott_Kirby
# Ralph_Hamers
# Hans_Vestberg
# Robert_Bakish
# Vittorio_Colao
# Herbert_Diess
# Robert_Iger
# Stefano_Pessina
# Doug_McMillon
# Ann_Sarnoff
# Jason_Kilar
# Charles_Scharf
# John_Mackey
# Rich_Barton

# %%
def to_space(x):
  return x.replace('_', ' ')

# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(to_space)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 130             Ann Sarnoff
# 131             Jason Kilar
# 132          Charles Scharf
# 133             John Mackey
# 134             Rich Barton
# Name: name, Length: 135, dtype: object

# %%
# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(lambda x: x.replace('_', ' '))
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 130             Ann Sarnoff
# 131             Jason Kilar
# 132          Charles Scharf
# 133             John Mackey
# 134             Rich Barton
# Name: name, Length: 135, dtype: object

# %%
# I can also use *apply* to call a function over the rows of a dataframe
exec_df.apply(lambda x: x['name'].replace('_', ' '), axis=1)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 130             Ann Sarnoff
# 131             Jason Kilar
# 132          Charles Scharf
# 133             John Mackey
# 134             Rich Barton
# Length: 135, dtype: object

# %%
# Let's clean the name by removing underscores...
exec_df['clean_name'] = exec_df['name'].apply(lambda x: x.replace('_', ' '))

exec_df
# Out:
#                      name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu              https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                 ...
# 130           Ann_Sarnoff           https://en.wikipedia.org/wiki/Ann_Sarnoff
# 131           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 132        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
# 133           John_Mackey           https://en.wikipedia.org/wiki/John_Mackey
# 134           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 4                    NaT              Eddie Wu
# ..                   ...                   ...
# 130                  NaT           Ann Sarnoff
# 131  1971-04-26 00:00:00           Jason Kilar
# 132  1965-04-24 00:00:00        Charles Scharf
# 133                  NaT           John Mackey
# 134                  NaT           Rich Barton
#
# [135 rows x 4 columns]

# %%
exec_df.rename(columns={'name': 'old_name'})
# Out:
#                  old_name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu              https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                 ...
# 130           Ann_Sarnoff           https://en.wikipedia.org/wiki/Ann_Sarnoff
# 131           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 132        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
# 133           John_Mackey           https://en.wikipedia.org/wiki/John_Mackey
# 134           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 4                    NaT              Eddie Wu
# ..                   ...                   ...
# 130                  NaT           Ann Sarnoff
# 131  1971-04-26 00:00:00           Jason Kilar
# 132  1965-04-24 00:00:00        Charles Scharf
# 133                  NaT           John Mackey
# 134                  NaT           Rich Barton
#
# [135 rows x 4 columns]

# %%
# We can do the same via SQL.  For the example we'll save the dataframe first...  we'll convert
# types to string first to avoid errors.

duckdb.sql("select name, replace(name, '_', ' ') as clean_name from exec_df")
# Out:
# ┌──────────────────────┬──────────────────────┐
# │         name         │      clean_name      │
# │       varchar        │       varchar        │
# ├──────────────────────┼──────────────────────┤
# │ Julie_Sweet          │ Julie Sweet          │
# │ Kumar_Mangalam_Birla │ Kumar Mangalam Birla │
# │ Shantanu_Narayen     │ Shantanu Narayen     │
# │ Guillaume_Faury      │ Guillaume Faury      │
# │ Eddie_Wu             │ Eddie Wu             │
# │ Andy_Jassy           │ Andy Jassy           │
# │ Lisa_Su              │ Lisa Su              │
# │ Stephen_Squeri       │ Stephen Squeri       │
# │ Joseph_R._Swedish    │ Joseph R. Swedish    │
# │ Tim_Cook             │ Tim Cook             │
# │    ·                 │    ·                 │
# │    ·                 │    ·                 │
# │    ·                 │    ·                 │
# │ Vittorio_Colao       │ Vittorio Colao       │
# │ Herbert_Diess        │ Herbert Diess        │
# │ Robert_Iger          │ Robert Iger          │
# │ Stefano_Pessina      │ Stefano Pessina      │
# │ Doug_McMillon        │ Doug McMillon        │
# │ Ann_Sarnoff          │ Ann Sarnoff          │
# │ Jason_Kilar          │ Jason Kilar          │
# │ Charles_Scharf       │ Charles Scharf       │
# │ John_Mackey          │ John Mackey          │
# │ Rich_Barton          │ Rich Barton          │
# ├──────────────────────┴──────────────────────┤
# │ 135 rows (20 shown)               2 columns │
# └─────────────────────────────────────────────┘

# %% [markdown]
# ## 2.1. Selecting a subset of the rows

# %%
# Here's a column

exec_df['clean_name']
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 130             Ann Sarnoff
# 131             Jason Kilar
# 132          Charles Scharf
# 133             John Mackey
# 134             Rich Barton
# Name: clean_name, Length: 135, dtype: object

# %%
# We can apply a test (predicate) to each column, returning a Series of boolean true/false values

exec_df['clean_name'] == 'Julie Sweet'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 130    False
# 131    False
# 132    False
# 133    False
# 134    False
# Name: clean_name, Length: 135, dtype: bool

# %%
# If we compose these, we'll get only those rows where the boolean condition was True

exec_df[exec_df['clean_name'] == 'Julie Sweet']
# Out:
#           name                                       page born   clean_name
# 0  Julie_Sweet  https://en.wikipedia.org/wiki/Julie_Sweet  NaT  Julie Sweet

# %% [markdown]
# SQL lets us use any case, but convention is to capitalize the SQL keywords such as `SELECT`, `FROM`, `WHERE` to aid in readability.  Also, we should use single-quotes for SQL strings, so we'll typically pass the SQL command in with double-quotes.

# %%
duckdb.sql("SELECT * FROM exec_df WHERE clean_name='Julie Sweet'")
# Out:
# ┌─────────────┬───────────────────────────────────────────┬───────────┬─────────────┐
# │    name     │                   page                    │   born    │ clean_name  │
# │   varchar   │                  varchar                  │ timestamp │   varchar   │
# ├─────────────┼───────────────────────────────────────────┼───────────┼─────────────┤
# │ Julie_Sweet │ https://en.wikipedia.org/wiki/Julie_Sweet │ NULL      │ Julie Sweet │
# └─────────────┴───────────────────────────────────────────┴───────────┴─────────────┘

# %%
exec_df[exec_df['clean_name'] == 'Julie Sweet'][['page']]
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %% [markdown]
# Here we'll use the triple-quote syntax for Python strings, which allows us to pass a multi-line string to SQL...

# %%
duckdb.sql("""SELECT clean_name
            FROM exec_df
            WHERE clean_name='Julie Sweet'""")
# Out:
# ┌─────────────┐
# │ clean_name  │
# │   varchar   │
# ├─────────────┤
# │ Julie Sweet │
# └─────────────┘

# %%
import numpy as np

exec_df.dropna(subset=['born'])
# Out:
#                      name                                                page  \
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 5              Andy_Jassy            https://en.wikipedia.org/wiki/Andy_Jassy
# 6                 Lisa_Su               https://en.wikipedia.org/wiki/Lisa_Su
# ..                    ...                                                 ...
# 127           Robert_Iger           https://en.wikipedia.org/wiki/Robert_Iger
# 128       Stefano_Pessina       https://en.wikipedia.org/wiki/Stefano_Pessina
# 129         Doug_McMillon         https://en.wikipedia.org/wiki/Doug_McMillon
# 131           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 132        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
#
#                     born            clean_name
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 5    1968-01-13 00:00:00            Andy Jassy
# 6    1969-11-07 00:00:00               Lisa Su
# ..                   ...                   ...
# 127  1951-02-10 00:00:00           Robert Iger
# 128  1941-06-04 00:00:00       Stefano Pessina
# 129  1966-10-17 00:00:00         Doug McMillon
# 131  1971-04-26 00:00:00           Jason Kilar
# 132  1965-04-24 00:00:00        Charles Scharf
#
# [80 rows x 4 columns]

# %%
duckdb.sql("""SELECT *
            FROM exec_df
            WHERE born IS NOT NULL""")
# Out:
# ┌──────────────────────┬──────────────────────────────────────────────────┬─────────────────────┬──────────────────────┐
# │         name         │                       page                       │        born         │      clean_name      │
# │       varchar        │                     varchar                      │      timestamp      │       varchar        │
# ├──────────────────────┼──────────────────────────────────────────────────┼─────────────────────┼──────────────────────┤
# │ Kumar_Mangalam_Birla │ https://en.wikipedia.org/wiki/Kumar_Mangalam_B…  │ 1967-06-14 00:00:00 │ Kumar Mangalam Birla │
# │ Shantanu_Narayen     │ https://en.wikipedia.org/wiki/Shantanu_Narayen   │ 1963-05-27 00:00:00 │ Shantanu Narayen     │
# │ Guillaume_Faury      │ https://en.wikipedia.org/wiki/Guillaume_Faury    │ 1968-02-22 00:00:00 │ Guillaume Faury      │
# │ Andy_Jassy           │ https://en.wikipedia.org/wiki/Andy_Jassy         │ 1968-01-13 00:00:00 │ Andy Jassy           │
# │ Lisa_Su              │ https://en.wikipedia.org/wiki/Lisa_Su            │ 1969-11-07 00:00:00 │ Lisa Su              │
# │ Joseph_R._Swedish    │ https://en.wikipedia.org/wiki/Joseph_R._Swedish  │ 1951-05-17 00:00:00 │ Joseph R. Swedish    │
# │ Tim_Cook             │ https://en.wikipedia.org/wiki/Tim_Cook           │ 1960-11-01 00:00:00 │ Tim Cook             │
# │ Lakshmi_Niwas_Mittal │ https://en.wikipedia.org/wiki/Lakshmi_Niwas_Mi…  │ 1950-06-15 00:00:00 │ Lakshmi Niwas Mittal │
# │ Charles_Woodburn     │ https://en.wikipedia.org/wiki/Charles_Woodburn   │ 1971-03-11 00:00:00 │ Charles Woodburn     │
# │ Tapan_Singhel        │ https://en.wikipedia.org/wiki/Tapan_Singhel      │ 1966-08-12 00:00:00 │ Tapan Singhel        │
# │      ·               │                     ·                            │          ·          │      ·               │
# │      ·               │                     ·                            │          ·          │      ·               │
# │      ·               │                     ·                            │          ·          │      ·               │
# │ Ralph_Hamers         │ https://en.wikipedia.org/wiki/Ralph_Hamers       │ 1966-05-25 00:00:00 │ Ralph Hamers         │
# │ Hans_Vestberg        │ https://en.wikipedia.org/wiki/Hans_Vestberg      │ 1965-06-23 00:00:00 │ Hans Vestberg        │
# │ Robert_Bakish        │ https://en.wikipedia.org/wiki/Robert_Bakish      │ 1963-12-14 00:00:00 │ Robert Bakish        │
# │ Vittorio_Colao       │ https://en.wikipedia.org/wiki/Vittorio_Colao     │ 1961-10-03 00:00:00 │ Vittorio Colao       │
# │ Herbert_Diess        │ https://en.wikipedia.org/wiki/Herbert_Diess      │ 1958-10-24 00:00:00 │ Herbert Diess        │
# │ Robert_Iger          │ https://en.wikipedia.org/wiki/Robert_Iger        │ 1951-02-10 00:00:00 │ Robert Iger          │
# │ Stefano_Pessina      │ https://en.wikipedia.org/wiki/Stefano_Pessina    │ 1941-06-04 00:00:00 │ Stefano Pessina      │
# │ Doug_McMillon        │ https://en.wikipedia.org/wiki/Doug_McMillon      │ 1966-10-17 00:00:00 │ Doug McMillon        │
# │ Jason_Kilar          │ https://en.wikipedia.org/wiki/Jason_Kilar        │ 1971-04-26 00:00:00 │ Jason Kilar          │
# │ Charles_Scharf       │ https://en.wikipedia.org/wiki/Charles_Scharf     │ 1965-04-24 00:00:00 │ Charles Scharf       │
# ├──────────────────────┴──────────────────────────────────────────────────┴─────────────────────┴──────────────────────┤
# │ 80 rows (20 shown)                                                                                         4 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 2.2. Joining Data
#
# We start with a simple join between company_ceos_df and exec_df and persist it to the database.  We then check how many companies did not have a match on CEO name.

# %%
exec_df[['clean_name', 'born']]
# Out:
#                clean_name                 born
# 0             Julie Sweet                  NaT
# 1    Kumar Mangalam Birla  1967-06-14 00:00:00
# 2        Shantanu Narayen  1963-05-27 00:00:00
# 3         Guillaume Faury  1968-02-22 00:00:00
# 4                Eddie Wu                  NaT
# ..                    ...                  ...
# 130           Ann Sarnoff                  NaT
# 131           Jason Kilar  1971-04-26 00:00:00
# 132        Charles Scharf  1965-04-24 00:00:00
# 133           John Mackey                  NaT
# 134           Rich Barton                  NaT
#
# [135 rows x 2 columns]

# %%
# Remove any duplicate executive entries

exec_df = exec_df.drop_duplicates()

# %%
company_ceos_df[['Executive', 'Company']]
# Out:
#                 Executive             Company
# 0             Julie Sweet           Accenture
# 1    Kumar Mangalam Birla  Aditya Birla Group
# 2        Shantanu Narayen       Adobe Systems
# 3         Guillaume Faury              Airbus
# 4                Eddie Wu             Alibaba
# ..                    ...                 ...
# 130           Ann Sarnoff     Warner Brothers
# 131           Jason Kilar         WarnerMedia
# 132        Charles Scharf         Wells Fargo
# 133           John Mackey  Whole Foods Market
# 134           Rich Barton        Zillow Group
#
# [135 rows x 2 columns]

# %%
company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'])
# Out:
#                 Executive             Company            clean_name  \
# 0             Julie Sweet           Accenture           Julie Sweet
# 1    Kumar Mangalam Birla  Aditya Birla Group  Kumar Mangalam Birla
# 2        Shantanu Narayen       Adobe Systems      Shantanu Narayen
# 3         Guillaume Faury              Airbus       Guillaume Faury
# 4                Eddie Wu             Alibaba              Eddie Wu
# ..                    ...                 ...                   ...
# 127           Ann Sarnoff     Warner Brothers           Ann Sarnoff
# 128           Jason Kilar         WarnerMedia           Jason Kilar
# 129        Charles Scharf         Wells Fargo        Charles Scharf
# 130           John Mackey  Whole Foods Market           John Mackey
# 131           Rich Barton        Zillow Group           Rich Barton
#
#                     born
# 0                    NaT
# 1    1967-06-14 00:00:00
# 2    1963-05-27 00:00:00
# 3    1968-02-22 00:00:00
# 4                    NaT
# ..                   ...
# 127                  NaT
# 128  1971-04-26 00:00:00
# 129  1965-04-24 00:00:00
# 130                  NaT
# 131                  NaT
#
# [132 rows x 4 columns]

# %% [markdown]
# We can `JOIN ON` in the `FROM` clause.

# %%
duckdb.sql("""
            SELECT Executive, Company, born
            FROM company_ceos_df JOIN exec_df ON Executive=clean_name
          """)
# Out:
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Julie Sweet          │ Accenture                │ NULL                │
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Shantanu Narayen     │ Adobe Systems            │ 1963-05-27 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Eddie Wu             │ Alibaba                  │ NULL                │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Lisa Su              │ Advanced Micro Devices   │ 1969-11-07 00:00:00 │
# │ Stephen Squeri       │ American Express         │ NULL                │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Ann Sarnoff          │ Warner Brothers          │ NULL                │
# │ Jason Kilar          │ WarnerMedia              │ 1971-04-26 00:00:00 │
# │ John Mackey          │ Whole Foods Market       │ NULL                │
# │ Rich Barton          │ Zillow Group             │ NULL                │
# │ Edward D. Breen      │ Dow Chemical Company     │ NULL                │
# │ Sundar Pichai        │ Google                   │ 1972-06-10 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 132 rows (20 shown)                                         3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Note there is another way you'll sometimes see, in older versions of SQL... Which is to put the join as a `WHERE` condition:

# %%
duckdb.sql("""
            SELECT Executive, Company, born
            FROM company_ceos_df, exec_df
            WHERE Executive=clean_name
          """)
# Out:
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Julie Sweet          │ Accenture                │ NULL                │
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Shantanu Narayen     │ Adobe Systems            │ 1963-05-27 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Eddie Wu             │ Alibaba                  │ NULL                │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Lisa Su              │ Advanced Micro Devices   │ 1969-11-07 00:00:00 │
# │ Stephen Squeri       │ American Express         │ NULL                │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Ann Sarnoff          │ Warner Brothers          │ NULL                │
# │ Jason Kilar          │ WarnerMedia              │ 1971-04-26 00:00:00 │
# │ John Mackey          │ Whole Foods Market       │ NULL                │
# │ Rich Barton          │ Zillow Group             │ NULL                │
# │ Edward D. Breen      │ Dow Chemical Company     │ NULL                │
# │ Sundar Pichai        │ Google                   │ 1972-06-10 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 132 rows (20 shown)                                         3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# OK, let's drop the cases where we don't have a CEO's birthday: these aren't useful!

# %%
# Shall we skip the cases where we don't have the birthday?
duckdb.sql("""
            SELECT Executive, Company, born
            FROM company_ceos_df JOIN exec_df ON Executive=clean_name
            WHERE born is not null
          """)
# Out:
# ┌──────────────────────┬─────────────────────────────────┬─────────────────────┐
# │      Executive       │             Company             │        born         │
# │       varchar        │             varchar             │      timestamp      │
# ├──────────────────────┼─────────────────────────────────┼─────────────────────┤
# │ Kumar Mangalam Birla │ Aditya Birla Group              │ 1967-06-14 00:00:00 │
# │ Shantanu Narayen     │ Adobe Systems                   │ 1963-05-27 00:00:00 │
# │ Guillaume Faury      │ Airbus                          │ 1968-02-22 00:00:00 │
# │ Andy Jassy           │ Amazon                          │ 1968-01-13 00:00:00 │
# │ Lisa Su              │ Advanced Micro Devices          │ 1969-11-07 00:00:00 │
# │ Joseph R. Swedish    │ Anthem                          │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                           │ 1960-11-01 00:00:00 │
# │ Lakshmi Niwas Mittal │ Arcelor Mittal                  │ 1950-06-15 00:00:00 │
# │ Charles Woodburn     │ BAE Systems                     │ 1971-03-11 00:00:00 │
# │ Tapan Singhel        │ Bajaj Allianz General Insurance │ 1966-08-12 00:00:00 │
# │       ·              │           ·                     │          ·          │
# │       ·              │           ·                     │          ·          │
# │       ·              │           ·                     │          ·          │
# │ Hans Vestberg        │ Verizon Communications          │ 1965-06-23 00:00:00 │
# │ Robert Bakish        │ ViacomCBS                       │ 1963-12-14 00:00:00 │
# │ Vittorio Colao       │ Vodafone                        │ 1961-10-03 00:00:00 │
# │ Herbert Diess        │ Volkswagen Group                │ 1958-10-24 00:00:00 │
# │ Robert Iger          │ Walt Disney Company             │ 1951-02-10 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance        │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                         │ 1966-10-17 00:00:00 │
# │ Jason Kilar          │ WarnerMedia                     │ 1971-04-26 00:00:00 │
# │ Sundar Pichai        │ Google                          │ 1972-06-10 00:00:00 │
# │ Charles Scharf       │ Wells Fargo                     │ 1965-04-24 00:00:00 │
# ├──────────────────────┴─────────────────────────────────┴─────────────────────┤
# │ 79 rows (20 shown)                                                 3 columns │
# └──────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## 2.4. Finding the misses in the join with OUTER JOINs.
#
# Note that the join above resulted in 174 rows.  However, there are more rows in company_ceos_df so we are missing some companies.  We can see which are missed using a LEFT OUTERJOIN (aka LEFT JOIN); setting "indicator= True" allows us to see which tuples in company_ceos_df failed to find a match (left_only, e.g. row 24 and 172).

# %%
pd.set_option('display.max_rows', 200)
display(company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="left", indicator=True))
# Out:
#                     Executive                          Company  \
# 0                 Julie Sweet                        Accenture
# 1        Kumar Mangalam Birla               Aditya Birla Group
# 2            Shantanu Narayen                    Adobe Systems
# 3             Guillaume Faury                           Airbus
# 4                    Eddie Wu                          Alibaba
# 5                  Andy Jassy                           Amazon
# 6                     Lisa Su           Advanced Micro Devices
# 7              Stephen Squeri                 American Express
# 8           Joseph R. Swedish                           Anthem
# 9                    Tim Cook                            Apple
# 10       Lakshmi Niwas Mittal                   Arcelor Mittal
# 11               John Stankey                             AT&T
# 12           Charles Woodburn                      BAE Systems
# 13              Tapan Singhel  Bajaj Allianz General Insurance
# 14         Carlos Torres Vila  Banco Bilbao Vizcaya Argentaria
# 15             Brian Moynihan                  Bank of America
# 16       C.S. Venkatakrishnan                         Barclays
# 17             Warren Buffett               Berkshire Hathaway
# 18                Hubert Joly                         Best Buy
# 19        Sunil Bharti Mittal               Bharti Enterprises
# 20      Stephen A. Schwarzman                 Blackstone Group
# 21                 Mike Henry                              BHP
# 22               Oliver Zipse                              BMW
# 23               Dave Calhoun                           Boeing
# 24                Rich Lesser          Boston Consulting Group
# 25                 Bob Dudley                               BP
# 26                   Hock Tan                         Broadcom
# 27            Denise Morrison            Campbell Soup Company
# 28          Mark Shuttleworth                        Canonical
# 29           Richard Fairbank            Capital One Financial
# 30                Jim Umpleby                      Caterpillar
# 31             Evan Greenberg                            Chubb
# 32              Chuck Robbins                    Cisco Systems
# 33                Jane Fraser                        Citigroup
# 34              James Quincey                        Coca-Cola
# 35           Brian L. Roberts                          Comcast
# 36           Thomas Gottstein                    Credit Suisse
# 37              Ola Källenius                       Daimler AG
# 38               Michael Dell                             Dell
# 39                 Ed Bastian                  Delta Air Lines
# 40           Christian Sewing                    Deutsche Bank
# 41               Tobias Meyer                        DHL Group
# 42            Edward D. Breen             Dow Chemical Company
# 43                Devin Wenig                             eBay
# 44               Börje Ekholm                         Ericsson
# 45               Darren Woods                       ExxonMobil
# 46           Carmine Di Sibio                    Ernst & Young
# 47            Mark Zuckerberg                         Facebook
# 48         Frederick W. Smith                            FedEx
# 49          Sergio Marchionne                             Fiat
# 50            Abigail Johnson             Fidelity Investments
# 51              James Hackett                             Ford
# 52                  Terry Gou                          Foxconn
# 53            Lachlan Murdoch                  Fox Corporation
# 54            Phebe Novakovic                 General Dynamics
# 55       H. Lawrence Culp Jr.                 General Electric
# 56              Mary T. Barra                   General Motors
# 57              Emma Walmsley                  GlaxoSmithKline
# 58           David M. Solomon                    Goldman Sachs
# 59              Sundar Pichai                           Google
# 60              C Vijayakumar                 HCL Technologies
# 61               Antonio Neri       Hewlett Packard Enterprise
# 62            Darius Adamczyk                        Honeywell
# 63                 Noel Quinn                             HSBC
# 64             Arvind Krishna                              IBM
# 65               Salil Parekh                          Infosys
# 66              Pat Gelsinger                            Intel
# 67                James Dimon                  JP Morgan Chase
# 68              Pieter Elbers                              KLM
# 69            Charles G. Koch                  Koch Industries
# 70            Marillyn Hewson                  Lockheed Martin
# 71                 Steve Rowe                  Marks & Spencer
# 72          Chris Kempczinski                       McDonald's
# 73              Bob Sternfels               McKinsey & Company
# 74        Steven A. Kandarian                          MetLife
# 75               Isaac Larian                MGA Entertainment
# 76              Satya Nadella                        Microsoft
# 77            James P. Gorman                   Morgan Stanley
# 78                 Jeff Shell                     NBCUniversal
# 79       Robert James Thomson                        News Corp
# 80              Mark Thompson           New York Times Company
# 81                Mark Parker                             Nike
# 82             Pekka Lundmark                            Nokia
# 83          Vasant Narasimhan                         Novartis
# 84          Tatsumi Kimishima                         Nintendo
# 85                 Safra Catz               Oracle Corporation
# 86                  Mark Hurd               Oracle Corporation
# 87             Ramon Laguarta                          PepsiCo
# 88              Albert Bourla                           Pfizer
# 89            David S. Taylor                 Procter & Gamble
# 90            John Strangfeld             Prudential Financial
# 91                 Alan Joyce                           Qantas
# 92                Anil Ambani                   Reliance Group
# 93              Mukesh Ambani              Reliance Industries
# 94                Luca de Meo                          Renault
# 95             David I. McKay             Royal Bank of Canada
# 96                Ross McEwan           Royal Bank of Scotland
# 97            Ben van Beurden                Royal Dutch Shell
# 98            Michael O'Leary                          Ryanair
# 99        Douglas L. Peterson                       S&P Global
# 100              Oh-Hyun Kwon                          Samsung
# 101           Christian Klein                              SAP
# 102  Herbert Fisk Johnson III                       SC Johnson
# 103      Jean-Pascal Tricoire               Schneider Electric
# 104            Peter Harrison                        Schroders
# 105           Chua Sock Koong                          Singtel
# 106             Masayoshi Son                         SoftBank
# 107               Tony Aquila                  Solera Holdings
# 108          Robert E. Jordan               Southwest Airlines
# 109        J. Clifford Hudson                Sonic Corporation
# 110         Laxman Narasimhan                        Starbucks
# 111              Raymond Kwok          Sun Hung Kai Properties
# 112     William H. Rogers Jr.                   SunTrust Banks
# 113             Brian Cornell               Target Corporation
# 114         Rajesh Gopinathan        Tata Consultancy Services
# 115              Li Dongsheng                  TCL Corporation
# 116                 Andy Penn                          Telstra
# 117                Dave Lewis                            Tesco
# 118                 Elon Musk                            Tesla
# 119         Alan D. Schnitzer          The Travelers Companies
# 120               Akio Toyoda                           Toyota
# 121               Scott Kirby                  United Airlines
# 122              Ralph Hamers                              UBS
# 123             Hans Vestberg           Verizon Communications
# 124             Robert Bakish                        ViacomCBS
# 125            Vittorio Colao                         Vodafone
# 126             Herbert Diess                 Volkswagen Group
# 127               Robert Iger              Walt Disney Company
# 128           Stefano Pessina         Walgreens Boots Alliance
# 129             Doug McMillon                          Walmart
# 130               Ann Sarnoff                  Warner Brothers
# 131               Jason Kilar                      WarnerMedia
# 132            Charles Scharf                      Wells Fargo
# 133               John Mackey               Whole Foods Market
# 134               Rich Barton                     Zillow Group
#
#                    clean_name                 born     _merge
# 0                 Julie Sweet                  NaT       both
# 1        Kumar Mangalam Birla  1967-06-14 00:00:00       both
# 2            Shantanu Narayen  1963-05-27 00:00:00       both
# 3             Guillaume Faury  1968-02-22 00:00:00       both
# 4                    Eddie Wu                  NaT       both
# 5                  Andy Jassy  1968-01-13 00:00:00       both
# 6                     Lisa Su  1969-11-07 00:00:00       both
# 7              Stephen Squeri                  NaT       both
# 8           Joseph R. Swedish  1951-05-17 00:00:00       both
# 9                    Tim Cook  1960-11-01 00:00:00       both
# 10       Lakshmi Niwas Mittal  1950-06-15 00:00:00       both
# 11               John Stankey                  NaT       both
# 12           Charles Woodburn  1971-03-11 00:00:00       both
# 13              Tapan Singhel  1966-08-12 00:00:00       both
# 14         Carlos Torres Vila                  NaT       both
# 15             Brian Moynihan  1959-10-09 00:00:00       both
# 16       C.S. Venkatakrishnan                  NaT       both
# 17             Warren Buffett  1930-08-30 00:00:00       both
# 18                Hubert Joly  1959-08-11 00:00:00       both
# 19        Sunil Bharti Mittal  1957-10-23 00:00:00       both
# 20      Stephen A. Schwarzman  1947-02-14 00:00:00       both
# 21                 Mike Henry                  NaT       both
# 22               Oliver Zipse  1964-02-07 00:00:00       both
# 23               Dave Calhoun  1957-04-18 00:00:00       both
# 24                Rich Lesser                  NaT       both
# 25                 Bob Dudley  1955-09-14 00:00:00       both
# 26                   Hock Tan                  NaT       both
# 27            Denise Morrison  1954-01-13 00:00:00       both
# 28          Mark Shuttleworth  1973-09-18 00:00:00       both
# 29           Richard Fairbank  1950-09-18 00:00:00       both
# 30                Jim Umpleby                  NaT       both
# 31             Evan Greenberg                  NaT       both
# 32              Chuck Robbins                  NaT       both
# 33                Jane Fraser                  NaT       both
# 34              James Quincey  1965-01-08 00:00:00       both
# 35           Brian L. Roberts  1959-06-28 00:00:00       both
# 36           Thomas Gottstein                  NaT       both
# 37                        NaN                  NaN  left_only
# 38               Michael Dell  1965-02-23 00:00:00       both
# 39                 Ed Bastian  1957-06-06 00:00:00       both
# 40           Christian Sewing  1970-04-24 00:00:00       both
# 41               Tobias Meyer                  NaT       both
# 42            Edward D. Breen                  NaT       both
# 43                Devin Wenig                  NaT       both
# 44                        NaN                  NaN  left_only
# 45               Darren Woods  1965-12-16 00:00:00       both
# 46           Carmine Di Sibio  1963-03-23 00:00:00       both
# 47            Mark Zuckerberg  1984-05-14 00:00:00       both
# 48         Frederick W. Smith  1944-08-11 00:00:00       both
# 49          Sergio Marchionne                  NaT       both
# 50            Abigail Johnson  1961-12-19 00:00:00       both
# 51              James Hackett                  NaT       both
# 52                  Terry Gou  1950-10-18 00:00:00       both
# 53            Lachlan Murdoch  1971-09-08 00:00:00       both
# 54            Phebe Novakovic                  NaT       both
# 55       H. Lawrence Culp Jr.                  NaT       both
# 56              Mary T. Barra  1961-12-24 00:00:00       both
# 57              Emma Walmsley                  NaT       both
# 58           David M. Solomon                  NaT       both
# 59              Sundar Pichai  1972-06-10 00:00:00       both
# 60              C Vijayakumar                  NaT       both
# 61               Antonio Neri  1576-02-29 00:00:00       both
# 62            Darius Adamczyk  1966-02-08 00:00:00       both
# 63                 Noel Quinn                  NaT       both
# 64             Arvind Krishna  1962-11-23 00:00:00       both
# 65               Salil Parekh  1964-06-05 00:00:00       both
# 66              Pat Gelsinger  1961-03-05 00:00:00       both
# 67                James Dimon  1956-03-13 00:00:00       both
# 68              Pieter Elbers  1970-05-11 00:00:00       both
# 69            Charles G. Koch  1935-11-01 00:00:00       both
# 70            Marillyn Hewson  1953-12-27 00:00:00       both
# 71                 Steve Rowe  1965-01-19 00:00:00       both
# 72          Chris Kempczinski                  NaT       both
# 73              Bob Sternfels                  NaT       both
# 74        Steven A. Kandarian                  NaT       both
# 75               Isaac Larian  1954-03-28 00:00:00       both
# 76              Satya Nadella  1967-08-19 00:00:00       both
# 77            James P. Gorman  1958-07-14 00:00:00       both
# 78                 Jeff Shell                  NaT       both
# 79       Robert James Thomson  1961-03-11 00:00:00       both
# 80              Mark Thompson                  NaT       both
# 81                Mark Parker  1955-10-21 00:00:00       both
# 82             Pekka Lundmark  1963-12-09 00:00:00       both
# 83          Vasant Narasimhan  1976-08-26 00:00:00       both
# 84          Tatsumi Kimishima  1950-04-21 00:00:00       both
# 85                 Safra Catz                  NaT       both
# 86                  Mark Hurd  1957-01-01 00:00:00       both
# 87             Ramon Laguarta                  NaT       both
# 88              Albert Bourla  1961-10-21 00:00:00       both
# 89            David S. Taylor  1958-04-20 00:00:00       both
# 90            John Strangfeld                  NaT       both
# 91                 Alan Joyce                  NaT       both
# 92                Anil Ambani  1959-06-04 00:00:00       both
# 93              Mukesh Ambani  1957-04-19 00:00:00       both
# 94                Luca de Meo  1967-06-13 00:00:00       both
# 95             David I. McKay                  NaT       both
# 96                Ross McEwan  1957-07-16 00:00:00       both
# 97            Ben van Beurden  1958-04-23 00:00:00       both
# 98                        NaN                  NaN  left_only
# 99        Douglas L. Peterson                  NaT       both
# 100              Oh-Hyun Kwon                  NaT       both
# 101           Christian Klein  1980-05-04 00:00:00       both
# 102  Herbert Fisk Johnson III  1958-05-19 00:00:00       both
# 103      Jean-Pascal Tricoire  1963-05-11 00:00:00       both
# 104            Peter Harrison                  NaT       both
# 105           Chua Sock Koong                  NaT       both
# 106             Masayoshi Son  1957-08-11 00:00:00       both
# 107               Tony Aquila                  NaT       both
# 108          Robert E. Jordan                  NaT       both
# 109        J. Clifford Hudson                  NaT       both
# 110         Laxman Narasimhan  1967-05-15 00:00:00       both
# 111              Raymond Kwok                  NaT       both
# 112     William H. Rogers Jr.                  NaT       both
# 113             Brian Cornell                  NaT       both
# 114         Rajesh Gopinathan                  NaT       both
# 115              Li Dongsheng                  NaT       both
# 116                 Andy Penn                  NaT       both
# 117                Dave Lewis                  NaT       both
# 118                 Elon Musk  1971-06-28 00:00:00       both
# 119         Alan D. Schnitzer                  NaT       both
# 120               Akio Toyoda  1956-05-03 00:00:00       both
# 121               Scott Kirby  1967-08-13 00:00:00       both
# 122              Ralph Hamers  1966-05-25 00:00:00       both
# 123             Hans Vestberg  1965-06-23 00:00:00       both
# 124             Robert Bakish  1963-12-14 00:00:00       both
# 125            Vittorio Colao  1961-10-03 00:00:00       both
# 126             Herbert Diess  1958-10-24 00:00:00       both
# 127               Robert Iger  1951-02-10 00:00:00       both
# 128           Stefano Pessina  1941-06-04 00:00:00       both
# 129             Doug McMillon  1966-10-17 00:00:00       both
# 130               Ann Sarnoff                  NaT       both
# 131               Jason Kilar  1971-04-26 00:00:00       both
# 132            Charles Scharf  1965-04-24 00:00:00       both
# 133               John Mackey                  NaT       both
# 134               Rich Barton                  NaT       both

# %%
pd.set_option('display.max_rows', 50)
result_df = company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="outer", indicator=True)

result_df[result_df['_merge'] != 'both']
# Out:
#            Executive     Company          clean_name                 born  \
# 37     Ola Källenius  Daimler AG                 NaN                  NaN
# 44      Börje Ekholm    Ericsson                 NaN                  NaN
# 98   Michael O'Leary     Ryanair                 NaN                  NaN
# 135              NaN         NaN  Ola K%C3%A4llenius  1969-06-11 00:00:00
# 136              NaN         NaN   B%C3%B6rje Ekholm                  NaT
# 137              NaN         NaN   Michael O%27Leary                  NaT
#
#          _merge
# 37    left_only
# 44    left_only
# 98    left_only
# 135  right_only
# 136  right_only
# 137  right_only

# %% [markdown]
# We can also do this in SQL (there is no indicator but we can test for NULL):

# %%
duckdb.sql("""
            SELECT Executive, Company, clean_name, born
            FROM company_ceos_df FULL JOIN exec_df ON Executive=clean_name
            WHERE clean_name is null or Company is null
          """)
# Out:
# ┌─────────────────┬────────────┬────────────────────┬─────────────────────┐
# │    Executive    │  Company   │     clean_name     │        born         │
# │     varchar     │  varchar   │      varchar       │      timestamp      │
# ├─────────────────┼────────────┼────────────────────┼─────────────────────┤
# │ NULL            │ NULL       │ Ola K%C3%A4llenius │ 1969-06-11 00:00:00 │
# │ NULL            │ NULL       │ B%C3%B6rje Ekholm  │ NULL                │
# │ NULL            │ NULL       │ Michael O%27Leary  │ NULL                │
# │ Michael O'Leary │ Ryanair    │ NULL               │ NULL                │
# │ Ola Källenius   │ Daimler AG │ NULL               │ NULL                │
# │ Börje Ekholm    │ Ericsson   │ NULL               │ NULL                │
# └─────────────────┴────────────┴────────────────────┴─────────────────────┘

# %% [markdown]
# ## 2.3. Composing Joins
#
# Of course, we can join the results of a join with another table -- representing a *composition*!

# %% [markdown]
# Let's join with company data!

# %%
con.sql("""SELECT Executive, Company, born from company_ceos
            JOIN executives ON Executive=replace(name, '_', ' ')
            JOIN company_data cd ON Company=cd.name
            WHERE born is not null""")
# Out:
# ┌───────────┬─────────┬───────────┐
# │ Executive │ Company │   born    │
# │  varchar  │ varchar │ timestamp │
# ├───────────┴─────────┴───────────┤
# │             0 rows              │
# └─────────────────────────────────┘

# %% [markdown]
# Hmm, what is wrong here?

# %%
con.sql('SELECT * from company_data')
# Out:
# ┌────────────┬──────────────────────┬───┬──────────────────────┬──────────────────────┬──────────────────────┐
# │ Unnamed: 0 │         name         │ … │     linkedin url     │ current employee e…  │ total employee est…  │
# │   int64    │       varchar        │   │       varchar        │        int64         │        int64         │
# ├────────────┼──────────────────────┼───┼──────────────────────┼──────────────────────┼──────────────────────┤
# │    5872184 │ ibm                  │ … │ linkedin.com/compa…  │               274047 │               716906 │
# │    4425416 │ tata consultancy s…  │ … │ linkedin.com/compa…  │               190771 │               341369 │
# │      21074 │ accenture            │ … │ linkedin.com/compa…  │               190689 │               455768 │
# │    2309813 │ us army              │ … │ linkedin.com/compa…  │               162163 │               445958 │
# │    1558607 │ ey                   │ … │ linkedin.com/compa…  │               158363 │               428960 │
# │    3844889 │ hewlett-packard      │ … │ linkedin.com/compa…  │               127952 │               412952 │
# │    2959148 │ cognizant technolo…  │ … │ linkedin.com/compa…  │               122031 │               210020 │
# │    5944912 │ walmart              │ … │ linkedin.com/compa…  │               120753 │               272827 │
# │    3727010 │ microsoft            │ … │ linkedin.com/compa…  │               116196 │               276983 │
# │    3300741 │ at&t                 │ … │ linkedin.com/compa…  │               115188 │               269659 │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │       ·    │  ·                   │ · │          ·           │                   ·  │                   ·  │
# │    4782764 │ jönköpings kommun    │ … │ linkedin.com/compa…  │                 1118 │                 1964 │
# │    3432133 │ jmc projects india…  │ … │ linkedin.com/compa…  │                 1118 │                 2112 │
# │     910050 │ öbb                  │ … │ linkedin.com/compa…  │                 1118 │                 1546 │
# │    6444131 │ vaillant group       │ … │ linkedin.com/compa…  │                 1118 │                 2540 │
# │     916799 │ embracon administr…  │ … │ linkedin.com/compa…  │                 1118 │                 2240 │
# │    3585785 │ university of chic…  │ … │ linkedin.com/compa…  │                 1118 │                 3220 │
# │    2583172 │ pantaloon retail i…  │ … │ linkedin.com/compa…  │                 1118 │                 4723 │
# │    1406043 │ nv energy            │ … │ linkedin.com/compa…  │                 1118 │                 1834 │
# │     955441 │ mining               │ … │ linkedin.com/compa…  │                 1118 │                 1421 │
# │    5571765 │ university of stir…  │ … │ linkedin.com/compa…  │                 1118 │                 2680 │
# ├────────────┴──────────────────────┴───┴──────────────────────┴──────────────────────┴──────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                         11 columns (5 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Notice the case for `name`?

# %%
con.sql("""SELECT Executive, Company, born from company_ceos
            JOIN executives ON Executive=replace(name, '_', ' ')
            JOIN company_data cd ON lower(Company)=lower(cd.name)
            WHERE born is not null
            ORDER BY Company""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Lisa Su              │ Advanced Micro Devices   │ 1969-11-07 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │    ·                 │   ·                      │          ·          │
# │ Hans Vestberg        │ Verizon Communications   │ 1965-06-23 00:00:00 │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 145 rows (20 shown)                                         3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Hmm, there are duplicates!  This is because of fields in the `company_data` table that we don't care about. We can remove the duplicates via `SELECT DISTINCT`.

# %%
con.sql("""SELECT DISTINCT Executive, Company, born from company_ceos
            JOIN executives ON Executive=replace(name, '_', ' ')
            JOIN company_data cd ON lower(Company)=lower(cd.name)
            WHERE born is not null
            ORDER BY Company""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ┌──────────────────────┬──────────────────────────┬─────────────────────┐
# │      Executive       │         Company          │        born         │
# │       varchar        │         varchar          │      timestamp      │
# ├──────────────────────┼──────────────────────────┼─────────────────────┤
# │ Kumar Mangalam Birla │ Aditya Birla Group       │ 1967-06-14 00:00:00 │
# │ Lisa Su              │ Advanced Micro Devices   │ 1969-11-07 00:00:00 │
# │ Guillaume Faury      │ Airbus                   │ 1968-02-22 00:00:00 │
# │ Andy Jassy           │ Amazon                   │ 1968-01-13 00:00:00 │
# │ Joseph R. Swedish    │ Anthem                   │ 1951-05-17 00:00:00 │
# │ Tim Cook             │ Apple                    │ 1960-11-01 00:00:00 │
# │ Charles Woodburn     │ BAE Systems              │ 1971-03-11 00:00:00 │
# │ Oliver Zipse         │ BMW                      │ 1964-02-07 00:00:00 │
# │ Bob Dudley           │ BP                       │ 1955-09-14 00:00:00 │
# │ Brian Moynihan       │ Bank of America          │ 1959-10-09 00:00:00 │
# │     ·                │   ·                      │          ·          │
# │     ·                │   ·                      │          ·          │
# │     ·                │   ·                      │          ·          │
# │ Elon Musk            │ Tesla                    │ 1971-06-28 00:00:00 │
# │ Akio Toyoda          │ Toyota                   │ 1956-05-03 00:00:00 │
# │ Ralph Hamers         │ UBS                      │ 1966-05-25 00:00:00 │
# │ Scott Kirby          │ United Airlines          │ 1967-08-13 00:00:00 │
# │ Hans Vestberg        │ Verizon Communications   │ 1965-06-23 00:00:00 │
# │ Vittorio Colao       │ Vodafone                 │ 1961-10-03 00:00:00 │
# │ Stefano Pessina      │ Walgreens Boots Alliance │ 1941-06-04 00:00:00 │
# │ Doug McMillon        │ Walmart                  │ 1966-10-17 00:00:00 │
# │ Robert Iger          │ Walt Disney Company      │ 1951-02-10 00:00:00 │
# │ Charles Scharf       │ Wells Fargo              │ 1965-04-24 00:00:00 │
# ├──────────────────────┴──────────────────────────┴─────────────────────┤
# │ 66 rows (20 shown)                                          3 columns │
# └───────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# Can we do all of this in Pandas? Of course!
#
# First, we need to lowercase the company names.

# %%
company_ceos_df['company_lc'] = company_ceos_df['Company'].apply(lambda x: x.lower())

# %% [markdown]
# Notice this is slower than DuckDB?

# %%
company_ceos_df.merge(exec_df.dropna(),
                      left_on=['Executive'],
                      right_on=['clean_name']).\
                      merge(company_data_df,
                            left_on='company_lc',
                            right_on='name')[['Executive','Company','born']].drop_duplicates().sort_values('Company')
# Out:
#                 Executive                   Company                 born
# 0    Kumar Mangalam Birla        Aditya Birla Group  1967-06-14 00:00:00
# 5                 Lisa Su    Advanced Micro Devices  1969-11-07 00:00:00
# 1         Guillaume Faury                    Airbus  1968-02-22 00:00:00
# 3              Andy Jassy                    Amazon  1968-01-13 00:00:00
# 6       Joseph R. Swedish                    Anthem  1951-05-17 00:00:00
# ..                    ...                       ...                  ...
# 136        Vittorio Colao                  Vodafone  1961-10-03 00:00:00
# 139       Stefano Pessina  Walgreens Boots Alliance  1941-06-04 00:00:00
# 140         Doug McMillon                   Walmart  1966-10-17 00:00:00
# 138           Robert Iger       Walt Disney Company  1951-02-10 00:00:00
# 142        Charles Scharf               Wells Fargo  1965-04-24 00:00:00
#
# [66 rows x 3 columns]

# %% [markdown]
# # 3.0: Validating and Cleaning Data
#
# How do we know our data is good?  We can create rules that trigger when the data fails some particular set of **constraints**.

# %%
# Test with validation rules

replace_item = ''

failed = False
for name in exec_df['clean_name']:
  if not name.replace(' ', replace_item).\
          replace('.', replace_item).\
          replace('\'',replace_item).\
          replace('-',replace_item).isalpha():
    print ("Illegal name %s"%name)
    failed = True

if failed:
  print('Found illegal names!')
# Out:
# Illegal name Ola K%C3%A4llenius
# Illegal name B%C3%B6rje Ekholm
# Illegal name Michael O%27Leary
# Found illegal names!

# %% [markdown]
# ## 3.1. Data Cleaning: Fixing the Errors
#
# One approach we could take is to realize that these are all strings in which accented characters are specially coded for use in (Wikipedia) URLs.  For instance, %C3 is a hex character code for an accented "u".  We can use a function called `unqote` to fix this...

# %%
from urllib.parse import unquote

exec_df['clean_name'].apply(unquote)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 130             Ann Sarnoff
# 131             Jason Kilar
# 132          Charles Scharf
# 133             John Mackey
# 134             Rich Barton
# Name: clean_name, Length: 135, dtype: object

# %% [markdown]
# ## 3.2. More Generally: Data Validation Tools
#
# Are there tools to help us validate data?  Of course!  We see an [example](https://validators.readthedocs.io/en/latest/) of one such tool, simply called `validators`, below.  There are many others in the data cleaning literature.

# %%
# !pip install validators
# Out:
# Collecting validators
#   Downloading validators-0.33.0-py3-none-any.whl.metadata (3.8 kB)
# Downloading validators-0.33.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: validators
# Successfully installed validators-0.33.0

# %%
import validators.url

# Are all of the URLs valid?
exec_df['page'].apply(validators.url)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 130    True
# 131    True
# 132    True
# 133    True
# 134    True
# Name: page, Length: 135, dtype: bool

# %% [markdown]
# ## 3.3. Validation against a master list
#
# We can also compare against "master" lists (in tables).  For example, company info about stock ticker symbols can be compared against the full list of symbols; states and countries can be compared against definitive lists.
#
# Suppose we want to confirm that `company_info_df`, which includes companies' home countries, has valid country codes.

# %%
data = urllib.request.urlopen(\
       'https://gist.github.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv')

company_info_df = pd.read_csv(data)

# %%
company_info_df[['name','country_code']]
# Out:
#                                 name country_code
# 0                           #waywire          USA
# 1                 &TV Communications          USA
# 2                  'Rock' Your Paper          EST
# 3                  (In)Touch Network          GBR
# 4                         +n (PlusN)          USA
# ...                              ...          ...
# 47753                          Zzish          GBR
# 47754  ZZNode Science and Technology          CHN
# 47755          Zzzzapp Wireless ltd.          HRV
# 47756                  [a]list games          NaN
# 47757                          [x+1]          USA
#
# [47758 rows x 2 columns]

# %% [markdown]
# Some of these are NaNs -- let's drop them...

# %% [markdown]
# From someone's Github content, here's a nice list of all countries and region codes.

# %%
countries_df = pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv")

display(countries_df)
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
validated = company_info_df[['name','country_code']].dropna().merge(countries_df, left_on=['country_code'], right_on=['alpha-3'],
                      how='left', indicator=True)

validated[validated['_merge'] != 'both']
# Out:
#                         name_x country_code name_y alpha-2 alpha-3  \
# 38              123ContactForm          ROM    NaN     NaN     NaN
# 567               Access Point          ROM    NaN     NaN     NaN
# 3526                  Avito.ru          ROM    NaN     NaN     NaN
# 3600          Axigen Messaging          ROM    NaN     NaN     NaN
# 4694               BitDefender          ROM    NaN     NaN     NaN
# 4898                   Blogvio          ROM    NaN     NaN     NaN
# 5216            Boommy Fashion          ROM    NaN     NaN     NaN
# 7618                  Client24          ROM    NaN     NaN     NaN
# 8953         CreditCardsOnline          ROM    NaN     NaN     NaN
# 9991             DesignFace IT          ROM    NaN     NaN     NaN
# 10091                DialMyApp          ROM    NaN     NaN     NaN
# 10385         Divine Cosmetics          ROM    NaN     NaN     NaN
# 10711                DRESSBOOM          ROM    NaN     NaN     NaN
# 11321                     EDUS          ROM    NaN     NaN     NaN
# 11434                    eLama          ROM    NaN     NaN     NaN
# 12133  Erbix - Beetux Software          ROM    NaN     NaN     NaN
# 12350              Eventmag.ru          ROM    NaN     NaN     NaN
# 12862           FamilySpace.RU          ROM    NaN     NaN     NaN
# 13365                   Fishki          ROM    NaN     NaN     NaN
# 14940                  Glazeon          ROM    NaN     NaN     NaN
# 17604                  Incuron          ROM    NaN     NaN     NaN
# 20000           Kommerstate.ru          ROM    NaN     NaN     NaN
# 21075               liveMag.ro          ROM    NaN     NaN     NaN
# 23210                Minutizer          ROM    NaN     NaN     NaN
# 26191                  OnAir3G          ROM    NaN     NaN     NaN
# 28274        Platypus Platform          ROM    NaN     NaN     NaN
# 28889                PressLabs          ROM    NaN     NaN     NaN
# 29064           Probki Iz okna          ROM    NaN     NaN     NaN
# 30460                RedHelper          ROM    NaN     NaN     NaN
# 30704   Renovatio IT Solutions          ROM    NaN     NaN     NaN
# 33474                Skin Scan          ROM    NaN     NaN     NaN
# 33482     Skitsanos Automotive          ROM    NaN     NaN     NaN
# 33663             Smart Museum          ROM    NaN     NaN     NaN
# 35409            Style Jukebox          ROM    NaN     NaN     NaN
# 37533               Tjobs S.A.          ROM    NaN     NaN     NaN
# 38583              TxtFeedback          ROM    NaN     NaN     NaN
# 38652                    uBank          ROM    NaN     NaN     NaN
# 39131              UseTogether          ROM    NaN     NaN     NaN
# 39792                  Vidimax          ROM    NaN     NaN     NaN
# 40442            Wable Systems          ROM    NaN     NaN     NaN
#
#        country-code iso_3166-2 region sub-region intermediate-region  \
# 38              NaN        NaN    NaN        NaN                 NaN
# 567             NaN        NaN    NaN        NaN                 NaN
# 3526            NaN        NaN    NaN        NaN                 NaN
# 3600            NaN        NaN    NaN        NaN                 NaN
# 4694            NaN        NaN    NaN        NaN                 NaN
# 4898            NaN        NaN    NaN        NaN                 NaN
# 5216            NaN        NaN    NaN        NaN                 NaN
# 7618            NaN        NaN    NaN        NaN                 NaN
# 8953            NaN        NaN    NaN        NaN                 NaN
# 9991            NaN        NaN    NaN        NaN                 NaN
# 10091           NaN        NaN    NaN        NaN                 NaN
# 10385           NaN        NaN    NaN        NaN                 NaN
# 10711           NaN        NaN    NaN        NaN                 NaN
# 11321           NaN        NaN    NaN        NaN                 NaN
# 11434           NaN        NaN    NaN        NaN                 NaN
# 12133           NaN        NaN    NaN        NaN                 NaN
# 12350           NaN        NaN    NaN        NaN                 NaN
# 12862           NaN        NaN    NaN        NaN                 NaN
# 13365           NaN        NaN    NaN        NaN                 NaN
# 14940           NaN        NaN    NaN        NaN                 NaN
# 17604           NaN        NaN    NaN        NaN                 NaN
# 20000           NaN        NaN    NaN        NaN                 NaN
# 21075           NaN        NaN    NaN        NaN                 NaN
# 23210           NaN        NaN    NaN        NaN                 NaN
# 26191           NaN        NaN    NaN        NaN                 NaN
# 28274           NaN        NaN    NaN        NaN                 NaN
# 28889           NaN        NaN    NaN        NaN                 NaN
# 29064           NaN        NaN    NaN        NaN                 NaN
# 30460           NaN        NaN    NaN        NaN                 NaN
# 30704           NaN        NaN    NaN        NaN                 NaN
# 33474           NaN        NaN    NaN        NaN                 NaN
# 33482           NaN        NaN    NaN        NaN                 NaN
# 33663           NaN        NaN    NaN        NaN                 NaN
# 35409           NaN        NaN    NaN        NaN                 NaN
# 37533           NaN        NaN    NaN        NaN                 NaN
# 38583           NaN        NaN    NaN        NaN                 NaN
# 38652           NaN        NaN    NaN        NaN                 NaN
# 39131           NaN        NaN    NaN        NaN                 NaN
# 39792           NaN        NaN    NaN        NaN                 NaN
# 40442           NaN        NaN    NaN        NaN                 NaN
#
#        region-code  sub-region-code  intermediate-region-code     _merge
# 38             NaN              NaN                       NaN  left_only
# 567            NaN              NaN                       NaN  left_only
# 3526           NaN              NaN                       NaN  left_only
# 3600           NaN              NaN                       NaN  left_only
# 4694           NaN              NaN                       NaN  left_only
# 4898           NaN              NaN                       NaN  left_only
# 5216           NaN              NaN                       NaN  left_only
# 7618           NaN              NaN                       NaN  left_only
# 8953           NaN              NaN                       NaN  left_only
# 9991           NaN              NaN                       NaN  left_only
# 10091          NaN              NaN                       NaN  left_only
# 10385          NaN              NaN                       NaN  left_only
# 10711          NaN              NaN                       NaN  left_only
# 11321          NaN              NaN                       NaN  left_only
# 11434          NaN              NaN                       NaN  left_only
# 12133          NaN              NaN                       NaN  left_only
# 12350          NaN              NaN                       NaN  left_only
# 12862          NaN              NaN                       NaN  left_only
# 13365          NaN              NaN                       NaN  left_only
# 14940          NaN              NaN                       NaN  left_only
# 17604          NaN              NaN                       NaN  left_only
# 20000          NaN              NaN                       NaN  left_only
# 21075          NaN              NaN                       NaN  left_only
# 23210          NaN              NaN                       NaN  left_only
# 26191          NaN              NaN                       NaN  left_only
# 28274          NaN              NaN                       NaN  left_only
# 28889          NaN              NaN                       NaN  left_only
# 29064          NaN              NaN                       NaN  left_only
# 30460          NaN              NaN                       NaN  left_only
# 30704          NaN              NaN                       NaN  left_only
# 33474          NaN              NaN                       NaN  left_only
# 33482          NaN              NaN                       NaN  left_only
# 33663          NaN              NaN                       NaN  left_only
# 35409          NaN              NaN                       NaN  left_only
# 37533          NaN              NaN                       NaN  left_only
# 38583          NaN              NaN                       NaN  left_only
# 38652          NaN              NaN                       NaN  left_only
# 39131          NaN              NaN                       NaN  left_only
# 39792          NaN              NaN                       NaN  left_only
# 40442          NaN              NaN                       NaN  left_only

# %% [markdown]
# ## 3.4. Record Linking: Working around the Errors
#
# Rather than figuring out how to clean these characters, we'll instead look at doing approximate matching.

# %% [markdown]
# Now we'll need to import some similarity matching code, to do approximate match between the original names and those returned by Wikipedia

# %%
# !pip3 install git+https://github.com/anhaidgroup/py_stringsimjoin.git@rel_0_3_6
# Out:
# Collecting git+https://github.com/anhaidgroup/py_stringsimjoin.git@rel_0_3_6
#   Cloning https://github.com/anhaidgroup/py_stringsimjoin.git (to revision rel_0_3_6) to /tmp/pip-req-build-lb_nu7a6
#   Running command git clone --filter=blob:none --quiet https://github.com/anhaidgroup/py_stringsimjoin.git /tmp/pip-req-build-lb_nu7a6
#   Running command git checkout -b rel_0_3_6 --track origin/rel_0_3_6
#   Switched to a new branch 'rel_0_3_6'
#   Branch 'rel_0_3_6' set up to track remote branch 'rel_0_3_6' from 'origin'.
#   Resolved https://github.com/anhaidgroup/py_stringsimjoin.git to commit d3ab2b31a8f9515e11bfa7abf9c33722cf6c9938
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from py-stringsimjoin==0.3.6) (1.4.2)
# Requirement already satisfied: pandas>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from py-stringsimjoin==0.3.6) (2.1.4)
# Collecting PyPrind>=2.9.3 (from py-stringsimjoin==0.3.6)
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting py_stringmatching>=0.2.1 (from py-stringsimjoin==0.3.6)
#   Downloading py-stringmatching-0.4.6.tar.gz (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.6/849.6 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from py-stringsimjoin==0.3.6) (1.16.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (2024.1)
# Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Building wheels for collected packages: py-stringsimjoin, py_stringmatching
#   Building wheel for py-stringsimjoin (setup.py) ... done
#   Created wheel for py-stringsimjoin: filename=py_stringsimjoin-0.3.6-cp310-cp310-linux_x86_64.whl size=5282980 sha256=4810e9566d57474106398c8239b31995bd5a536e5604ba4c3dc7fc2c12f2a652
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x3d5lk0f/wheels/77/a3/25/9e3d48e1153936ceb5fdcf5b8f467808777e55a95810fcf426
#   Building wheel for py_stringmatching (setup.py) ... done
#   Created wheel for py_stringmatching: filename=py_stringmatching-0.4.6-cp310-cp310-linux_x86_64.whl size=2833921 sha256=638f8e612856fd6ee8d5f910432d02c4886b07f38e87d3402d9f80e9ee29b219
#   Stored in directory: /root/.cache/pip/wheels/1b/5e/38/021a861f6d28ed354e033a029507cb8ed841454da833021bbb
# Successfully built py-stringsimjoin py_stringmatching
# Installing collected packages: PyPrind, py_stringmatching, py-stringsimjoin
# Successfully installed PyPrind-2.11.3 py-stringsimjoin-0.3.6 py_stringmatching-0.4.6

# %% [markdown]
# You'll need to restart your kernel after this one...

# %%
# !pip3 install linktransformer
# Out:
# Collecting linktransformer
#   Downloading linktransformer-0.1.15-py3-none-any.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.10/dist-packages (from linktransformer) (1.3.2)
# Collecting faiss-cpu==1.8.0 (from linktransformer)
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting hdbscan==0.8.36 (from linktransformer)
#   Downloading hdbscan-0.8.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting networkx==3.1 (from linktransformer)
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting torch==2.3.0 (from linktransformer)
#   Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting sentence-transformers==2.3.1 (from linktransformer)
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl.metadata (11 kB)
# Collecting transformers==4.41.1 (from linktransformer)
#   Downloading transformers-4.41.1-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.3 MB/s eta 0:00:00
# Collecting wandb==0.17.0 (from linktransformer)
#   Downloading wandb-0.17.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting numpy==1.24.4 (from linktransformer)
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting pandas==2.0.3 (from linktransformer)
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting openai==1.30.4 (from linktransformer)
#   Downloading openai-1.30.4-py3-none-any.whl.metadata (21 kB)
# Collecting openpyxl==3.1.2 (from linktransformer)
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting datasets==2.19.1 (from linktransformer)
#   Downloading datasets-2.19.1-py3-none-any.whl.metadata (19 kB)
# Collecting accelerate==0.30.1 (from linktransformer)
#   Downloading accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# Collecting evaluate==0.4.2 (from linktransformer)
#   Downloading evaluate-0.4.2-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->linktransformer) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->linktransformer) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->linktransformer) (6.0.2)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->linktransformer) (0.23.5)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.30.1->linktransformer) (0.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.1->linktransformer) (3.15.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.1->linktransformer) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.1->linktransformer) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.1->linktransformer) (0.3.8)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.1->linktransformer) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.1->linktransformer) (4.66.5)
# Collecting xxhash (from datasets==2.19.1->linktransformer)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets==2.19.1->linktransformer)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.3.1,>=2023.1.0 (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets==2.19.1->linktransformer)
#   Downloading fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.1->linktransformer) (3.10.5)
# Collecting cython<3,>=0.27 (from hdbscan==0.8.36->linktransformer)
#   Downloading Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan==0.8.36->linktransformer) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan==0.8.36->linktransformer) (1.4.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.30.4->linktransformer) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai==1.30.4->linktransformer) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai==1.30.4->linktransformer)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.30.4->linktransformer) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai==1.30.4->linktransformer) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai==1.30.4->linktransformer) (4.12.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl==3.1.2->linktransformer) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->linktransformer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->linktransformer) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->linktransformer) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.2->linktransformer) (3.5.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.3.1->linktransformer) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.3.1->linktransformer) (0.1.99)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.3.1->linktransformer) (9.4.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->linktransformer) (1.13.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.3.0->linktransformer) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.0->linktransformer)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.0 (from torch==2.3.0->linktransformer)
#   Downloading triton-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.1->linktransformer) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.1->linktransformer) (0.19.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb==0.17.0->linktransformer) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.17.0->linktransformer)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb==0.17.0->linktransformer)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb==0.17.0->linktransformer) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.17.0->linktransformer) (3.20.3)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.17.0->linktransformer)
#   Downloading sentry_sdk-2.13.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting setproctitle (from wandb==0.17.0->linktransformer)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.17.0->linktransformer) (71.0.4)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->linktransformer)
#   Downloading nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.30.4->linktransformer) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.30.4->linktransformer) (1.2.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb==0.17.0->linktransformer) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.1->linktransformer) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.1->linktransformer) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.1->linktransformer) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.1->linktransformer) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.1->linktransformer) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.1->linktransformer) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.1->linktransformer) (4.0.3)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb==0.17.0->linktransformer)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.30.4->linktransformer) (2024.7.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.30.4->linktransformer)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.30.4->linktransformer)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.30.4->linktransformer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.30.4->linktransformer) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.1->linktransformer) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.1->linktransformer) (2.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.3.0->linktransformer) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.3.0->linktransformer) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.17.0->linktransformer)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading linktransformer-0.1.15-py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 44.4 MB/s eta 0:00:00
# Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 15.2 MB/s eta 0:00:00
# Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 25.8 MB/s eta 0:00:00
# Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.1 MB/s eta 0:00:00
# Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 21.1 MB/s eta 0:00:00
# Downloading hdbscan-0.8.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 43.2 MB/s eta 0:00:00
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 35.8 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 27.5 MB/s eta 0:00:00
# Downloading openai-1.30.4-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 19.8 MB/s eta 0:00:00
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 8.8 MB/s eta 0:00:00
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 32.0 MB/s eta 0:00:00
# Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 6.5 MB/s eta 0:00:00
# Downloading torch-2.3.0-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.0 MB/s eta 0:00:00
# Downloading transformers-4.41.1-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 24.6 MB/s eta 0:00:00
# Downloading wandb-0.17.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 22.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 410.6/410.6 MB 61.0 MB/s eta 0:00:01
# ERROR: Operation cancelled by user

# %%
# Approximate string matching, see
import py_stringsimjoin as ssj
import py_stringmatching as sm

import linktransformer as lt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-71-d04a65346fe4> in <cell line: 5>()
#       3 import py_stringmatching as sm
#       4
# ----> 5 import linktransformer as lt
#
# ModuleNotFoundError: No module named 'linktransformer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# We are going to match the strings approximately, via "n-grams" or "q-grams" (sequences of n or q characters)
# Here it's five-grams

tok = sm.QgramTokenizer(qval=5,return_set=True)

# %%
# Now let's do a similarity join

# We'll reset the index, so there is a unique index field in the company_ceos_df dataframe
company_ceos_df.reset_index(inplace=True)

output_pairs = ssj.jaccard_join(company_ceos_df, exec_df, 'index', 'page', 'Executive', 'clean_name', tok, 0.35,
                                l_out_attrs=['Executive'], r_out_attrs=['name'])

output_pairs[output_pairs['_sim_score'] < 1.0]

# %%
# At last! Company info + CEO info, together!

total = company_ceos_df.merge(output_pairs,left_on=['Executive'],right_on=['l_Executive']).\
        merge(exec_df.dropna(),left_on=['r_page'],right_on=['page']).\
        merge(company_data_df, left_on='company_lc', right_on='name', how="left")

total

# %%
# Let's get ready to plot

# %matplotlib inline

# %%
total

# %% [markdown]
# ## Exercises

# %% [markdown]
# # 4.0 Simple Analysis of Linked Data: Grouping and Analytics
#
# The `groupby` command allows us to coalesce data by groups.  In Pandas a Group is a special object with a set of rows.  We can see this with the `get_group` command.

# %%
total[['born','Company','Executive']].drop_duplicates().sort_values('born')

# %%
total[['born','Company','Executive']].drop_duplicates().groupby(by='born').get_group(datetime.datetime.strptime('1935-11-01', '%Y-%m-%d'))[['Company','Executive','born']]

# %% [markdown]
# We can apply computations, such as `count`, to the items in the group.  Values that are empty (NaN) do not count (no pun intended).

# %%
total[['born','Company','Executive']].drop_duplicates().groupby(by='born').count()

# %%
# We can do this in SQL too...

# By default, SQL will include the Nan value (called NULL in SQL).  If we want to exclude it,
# we need to include WHERE ... IS NOT NULL.

duckdb.sql("""SELECT born, count(Company)
            FROM total
            WHERE born IS NOT NULL
            GROUP BY born""")
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# <ipython-input-177-085ec233dfa4> in <cell line: 6>()
#       4 # we need to include WHERE ... IS NOT NULL.
#       5
# ----> 6 duckdb.sql("""SELECT born, count(Company)
#       7             FROM total
#       8             WHERE born IS NOT NULL
#
# /usr/local/lib/python3.10/dist-packages/duckdb/__init__.py in sql(query, **kwargs)
#     455     else:
#     456         conn = duckdb.connect(":default:")
# --> 457     return conn.sql(query, **kwargs)
#     458 _exported_symbols.append('sql')
#     459
#
# CatalogException: Catalog Error: Table with name total does not exist!
# Did you mean "temp.information_schema.tables"?

# %%
total2 = total.dropna()
total2['born'] = total2['born'].astype('datetime64[ns]')

# %%
# Let's look at when the CEOs were born

birthdays = total2.groupby(by='born').count()[['Executive']]
birthdays.index = pd.to_datetime(birthdays.index, unit='s')

birthdays

# %% [markdown]
# We can actually use `resample` over dates, with a parameter, to group eg by decade (10 years, where A is the code for year):

# %%
birthdays.resample('10A').count().plot(kind='bar')

# %% [markdown]
# Maybe that's a little weird.  Can we do something more along the lines of what we expect, i.e., "1920s, 1930s, ..."?

# %%
# Get rid of the nulls!
bdays = total[['born']].dropna()

bdays = bdays.applymap(lambda bday: str(int(bday.year / 10) * 10) + 's')

bdays.reset_index().groupby('born').count().plot(kind='bar')

# %% [markdown]
# # An Exercise
#
# Is there a correlation between the kind of company and the age of the CEO?
#
# Does the company's line of business matter?
